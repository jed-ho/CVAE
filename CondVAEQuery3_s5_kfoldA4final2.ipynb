# %% [markdown]
# # Demonstration of anomaly detection with CVAE using DASHlink data
#
# **Author: Milad Memarzadeh (milad.memarzadeh@nasa.gov)**

# %% [markdown]
# # Import Libraries

# %%
import os
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
import torch.nn.functional as F

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support, roc_curve, precision_recall_curve, average_precision_score
from sklearn.utils import shuffle
from source.modelsCondVAE import *
from source.utilsCondVAEs5 import *
from itertools import combinations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
k_folds = 5
train_learning_rate = 1e-4
finetune_learning_rate = 1e-5
train_num_epochs = 50
finetune_num_epochs = 5

latent_dim = 10
batch_size = 64
window_size = 10

# %% [markdown]
# # Load and preprocess data

# %%
if os.name == 'nt':
    data_dir = 'C:/Users/jed95/Documents/GitHub/anomaly_detection/dataset/yahoo_s5/A4Benchmark/'
else:
    data_dir = '/home/adlink3/Downloads/yahoo_s5/A4Benchmark/'
save_dir="./A4/"
file_list = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.csv')]


df_list = []
for file in file_list:
    df = pd.read_csv(file)
    df_list.append(df)

data = pd.concat(df_list, ignore_index=True)
print("Data shape:", data.shape)
# Out:
# Data shape: (168000, 9)

# %%
print("Missing values:", data.isnull().sum())
data.dropna(inplace=True)
# Out:
# Missing values: timestamps      0
# value           0
# anomaly         0
# changepoint     0
# trend           0
# noise           0
# seasonality1    0
# seasonality2    0
# seasonality3    0
# dtype: int64

# %%
scaler = MinMaxScaler()
data['value'] = scaler.fit_transform(data['value'].values.reshape(-1, 1))

# %% [markdown]
# # Create Sequences

# %%
def create_sequences(values, labels, window_size, step=1):
    sequences = []
    seq_labels = []
    for i in range(0, len(values) - window_size + 1, step):
        seq = values[i:i + window_size]
        # If any label in the sequence is anomalous (e.g., 1), set the sequence label as anomalous
        label = 1 if any(labels[i:i + window_size]) else 0
        sequences.append(seq)
        seq_labels.append(label)
    return np.array(sequences), np.array(seq_labels)


sequences, seq_labels = create_sequences(data['value'].values, data['anomaly'].values, window_size=window_size)
print("Sequences shape:", sequences.shape)
print("Sequence labels shape:", seq_labels.shape)
# Out:
# Sequences shape: (167991, 10)
# Sequence labels shape: (167991,)

# %% [markdown]
# # Split data into labeled and unlabeled sets

# %%
normal_indices = np.where(seq_labels == 0)[0]
anomalous_indices = np.where(seq_labels == 1)[0]

normal_sequences = sequences[normal_indices]
normal_labels = seq_labels[normal_indices]

anomalous_sequences = sequences[anomalous_indices]
anomalous_labels = seq_labels[anomalous_indices]
print(normal_sequences.shape)
print(anomalous_sequences.shape)
# Out:
# (159855, 10)
# (8136, 10)

# %%
X_train_normal, X_test_normal, y_train_normal, y_test_normal = train_test_split(
    normal_sequences, normal_labels, test_size=0.6, random_state=42, stratify=normal_labels)
X_train_normal, X_val_normal, y_train_normal, y_val_normal = train_test_split(
    X_train_normal, y_train_normal, test_size=0.5, random_state=42, stratify=y_train_normal)


X_train_anomalous, X_test_anomalous, y_train_anomalous, y_test_anomalous = train_test_split(
    anomalous_sequences, anomalous_labels, test_size=0.6, random_state=42, stratify=anomalous_labels)
X_train_anomalous, X_val_anomalous, y_train_anomalous, y_val_anomalous = train_test_split(
    X_train_anomalous, y_train_anomalous, test_size=0.5, random_state=42, stratify=y_train_anomalous)

# %%
X_train = np.concatenate([X_train_normal, X_train_anomalous], axis=0)
y_train = np.concatenate([y_train_normal, y_train_anomalous], axis=0)

X_val = np.concatenate([X_val_normal, X_val_anomalous], axis=0)
y_val = np.concatenate([y_val_normal, y_val_anomalous], axis=0)

X_test = np.concatenate([X_test_normal, X_test_anomalous], axis=0)
y_test = np.concatenate([y_test_normal, y_test_anomalous], axis=0)
print("Training data shape:", X_train.shape, y_train.shape)
print("Validation data shape:", X_val.shape, y_val.shape)
print("Test data shape:", X_test.shape, y_test.shape)
# Out:
# Training data shape: (33598, 10) (33598,)
# Validation data shape: (33598, 10) (33598,)
# Test data shape: (100795, 10) (100795,)

# %%
X_train, y_train = shuffle(X_train, y_train, random_state=42)
X_val, y_val = shuffle(X_val, y_val, random_state=42)
X_test, y_test = shuffle(X_test, y_test, random_state=42)

# %% [markdown]
# # Convert Data to Tensors

# %%
X_train_tensor = torch.tensor(X_train).float()
y_train_tensor = torch.tensor(y_train).long()

X_val_tensor = torch.tensor(X_val).float()
y_val_tensor = torch.tensor(y_val).long()

X_test_tensor = torch.tensor(X_test).float()
y_test_tensor = torch.tensor(y_test).long()

# %% [markdown]
# # Create Data Loaders for Labeled and Unlabeled Data

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels  # Now labels are provided for all data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = self.data[idx]
        y = self.labels[idx]
        return X, y

# %%
train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False) #TODO adjust Shuffle training data? 
full_train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)

val_dataset = TimeSeriesDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TimeSeriesDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Instantiate and Train the Conditional VAE

# %%
def evaluate_model(model, data_loader):
    model.eval()
    total_loss = 0
    total_correct = 0
    total_samples = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for data, target in data_loader:
            data = data.to(device)
            target = target.to(device)

            # Forward pass
            x_rec, class_logits = model(data)
            
            # Compute classification loss
            loss = criterion(class_logits, target)
            total_loss += loss.item() * data.size(0)

            # Compute accuracy
            preds = class_logits.argmax(dim=1)
            total_correct += (preds == target).sum().item()
            total_samples += data.size(0)

    avg_loss = total_loss / total_samples
    avg_acc = total_correct / total_samples

    return avg_loss, avg_acc

# %%
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
num_param = 1    # Since we have univariate time series
num_classes = 2 
scale_flag = 0   # Use Sigmoid activation in the decoder

results = {}

print('Starting k-fold cross-validation...')
time_start = time.time()
for fold, (train_idx, val2_idx) in enumerate(skf.split(np.zeros(len(y_train_tensor)), y_train_tensor.cpu().numpy())):
    print(f'Fold {fold+1}/{k_folds}')
    model_name="CondVAE_model"+str(fold+1)
    # Create data loaders for the current fold
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val2_subsampler = torch.utils.data.SubsetRandomSampler(val2_idx)
    
    train_loader = DataLoader(full_train_dataset, batch_size=batch_size, sampler=train_subsampler)
    val2_loader = DataLoader(full_train_dataset, batch_size=batch_size, sampler=val2_subsampler)
    
    model = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
    optimizer = optim.Adam(model.parameters(), lr=train_learning_rate)
    
    model = train_model(
    model,
    optimizer,
    train_loader,
    num_epochs=train_num_epochs,
    save=True,
    save_dir=save_dir,
    model_name=model_name)
    
    # Evaluate the model on validation data
    val_loss, val_acc = evaluate_model(model, val2_loader)
    
    # Save the results for this fold
    results[fold] = {'val_loss': val_loss, 'val_acc': val_acc}
    
    print(f'Fold {fold+1} Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}')

time_end = time.time()
print(f'Total time taken for k-fold cross-validation: {time_end - time_start} seconds')
buffer = io.BytesIO()
torch.save(model.state_dict(), buffer)
# Out:
# Starting k-fold cross-validation...
# Fold 1/5
# Epoch [1/50], Total Loss: 140.7950, Rec Loss: 45.5644, KL Div: 1.5938, Class Loss: 93.6367
# Epoch [2/50], Total Loss: 128.2000, Rec Loss: 45.2571, KL Div: 0.0398, Class Loss: 82.9030
# Epoch [3/50], Total Loss: 127.6586, Rec Loss: 45.1434, KL Div: 0.0421, Class Loss: 82.4730
# Epoch [4/50], Total Loss: 127.1419, Rec Loss: 45.1939, KL Div: 0.0610, Class Loss: 81.8869
# Epoch [5/50], Total Loss: 126.5949, Rec Loss: 45.1305, KL Div: 0.0701, Class Loss: 81.3944
# Epoch [6/50], Total Loss: 126.0317, Rec Loss: 45.0954, KL Div: 0.0772, Class Loss: 80.8591
# Epoch [7/50], Total Loss: 125.3438, Rec Loss: 45.1092, KL Div: 0.0479, Class Loss: 80.1867
# Epoch [8/50], Total Loss: 124.8714, Rec Loss: 45.0823, KL Div: 0.0529, Class Loss: 79.7363
# Epoch [9/50], Total Loss: 123.9738, Rec Loss: 45.0832, KL Div: 0.0616, Class Loss: 78.8290
# Epoch [10/50], Total Loss: 122.7257, Rec Loss: 45.0644, KL Div: 0.0513, Class Loss: 77.6100
# Epoch [11/50], Total Loss: 121.3323, Rec Loss: 45.0521, KL Div: 0.0563, Class Loss: 76.2239
# Epoch [12/50], Total Loss: 119.6212, Rec Loss: 45.0540, KL Div: 0.0585, Class Loss: 74.5087
# Epoch [13/50], Total Loss: 117.1534, Rec Loss: 45.0630, KL Div: 0.0406, Class Loss: 72.0498
# Epoch [14/50], Total Loss: 114.5105, Rec Loss: 45.0530, KL Div: 0.0285, Class Loss: 69.4291
# Epoch [15/50], Total Loss: 111.5066, Rec Loss: 45.0416, KL Div: 0.0267, Class Loss: 66.4383
# Epoch [16/50], Total Loss: 108.7710, Rec Loss: 45.0352, KL Div: 0.0286, Class Loss: 63.7072
# Epoch [17/50], Total Loss: 105.7486, Rec Loss: 45.0350, KL Div: 0.0263, Class Loss: 60.6873
# Epoch [18/50], Total Loss: 102.4703, Rec Loss: 45.0544, KL Div: 0.0241, Class Loss: 57.3919
# Epoch [19/50], Total Loss: 99.0374, Rec Loss: 45.0226, KL Div: 0.0248, Class Loss: 53.9900
# Epoch [20/50], Total Loss: 97.3537, Rec Loss: 45.0248, KL Div: 0.0236, Class Loss: 52.3054
# Epoch [21/50], Total Loss: 93.9966, Rec Loss: 45.0449, KL Div: 0.0202, Class Loss: 48.9316
# Epoch [22/50], Total Loss: 92.5577, Rec Loss: 45.0278, KL Div: 0.0191, Class Loss: 47.5108
# Epoch [23/50], Total Loss: 90.4482, Rec Loss: 45.0136, KL Div: 0.0185, Class Loss: 45.4162
# Epoch [24/50], Total Loss: 88.8510, Rec Loss: 45.0138, KL Div: 0.0185, Class Loss: 43.8187
# Epoch [25/50], Total Loss: 87.3309, Rec Loss: 45.0203, KL Div: 0.0181, Class Loss: 42.2925
# Epoch [26/50], Total Loss: 85.7125, Rec Loss: 45.0365, KL Div: 0.0173, Class Loss: 40.6587
# Epoch [27/50], Total Loss: 85.3484, Rec Loss: 45.0261, KL Div: 0.0168, Class Loss: 40.3054
# Epoch [28/50], Total Loss: 83.9008, Rec Loss: 45.0277, KL Div: 0.0155, Class Loss: 38.8576
# Epoch [29/50], Total Loss: 83.1469, Rec Loss: 45.0172, KL Div: 0.0154, Class Loss: 38.1144
# Epoch [30/50], Total Loss: 82.8499, Rec Loss: 45.0211, KL Div: 0.0158, Class Loss: 37.8129
# Epoch [31/50], Total Loss: 83.3649, Rec Loss: 45.0160, KL Div: 0.0162, Class Loss: 38.3327
# Epoch [32/50], Total Loss: 80.8457, Rec Loss: 45.0221, KL Div: 0.0145, Class Loss: 35.8091
# Epoch [33/50], Total Loss: 80.4853, Rec Loss: 45.0140, KL Div: 0.0145, Class Loss: 35.4567
# Epoch [34/50], Total Loss: 80.4907, Rec Loss: 45.0070, KL Div: 0.0144, Class Loss: 35.4692
# Epoch [35/50], Total Loss: 80.3617, Rec Loss: 44.9972, KL Div: 0.0138, Class Loss: 35.3506
# Epoch [36/50], Total Loss: 79.9084, Rec Loss: 45.0067, KL Div: 0.0131, Class Loss: 34.8887
# Epoch [37/50], Total Loss: 78.3870, Rec Loss: 45.0121, KL Div: 0.0134, Class Loss: 33.3615
# Epoch [38/50], Total Loss: 79.4689, Rec Loss: 44.9990, KL Div: 0.0134, Class Loss: 34.4565
# Epoch [39/50], Total Loss: 78.4927, Rec Loss: 45.0020, KL Div: 0.0125, Class Loss: 33.4782
# Epoch [40/50], Total Loss: 77.3317, Rec Loss: 45.0060, KL Div: 0.0123, Class Loss: 32.3134
# Epoch [41/50], Total Loss: 79.2744, Rec Loss: 45.0022, KL Div: 0.0122, Class Loss: 34.2600
# Epoch [42/50], Total Loss: 76.8545, Rec Loss: 44.9927, KL Div: 0.0111, Class Loss: 31.8506
# Epoch [43/50], Total Loss: 77.0337, Rec Loss: 44.9976, KL Div: 0.0114, Class Loss: 32.0248
# Epoch [44/50], Total Loss: 76.7846, Rec Loss: 45.0047, KL Div: 0.0109, Class Loss: 31.7691
# Epoch [45/50], Total Loss: 75.9629, Rec Loss: 45.0079, KL Div: 0.0104, Class Loss: 30.9446
# Epoch [46/50], Total Loss: 76.4859, Rec Loss: 45.0069, KL Div: 0.0104, Class Loss: 31.4686
# Epoch [47/50], Total Loss: 76.0993, Rec Loss: 44.9960, KL Div: 0.0105, Class Loss: 31.0928
# Epoch [48/50], Total Loss: 75.8399, Rec Loss: 44.9797, KL Div: 0.0099, Class Loss: 30.8502
# Epoch [49/50], Total Loss: 76.2769, Rec Loss: 45.0023, KL Div: 0.0104, Class Loss: 31.2641
# Epoch [50/50], Total Loss: 75.8045, Rec Loss: 44.9815, KL Div: 0.0106, Class Loss: 30.8124
# Time elapsed:  67.8632743358612
# Fold 1 Validation Loss: 0.0725, Validation Accuracy: 0.9738
# Fold 2/5
# Epoch [1/50], Total Loss: 145.6922, Rec Loss: 45.8807, KL Div: 1.6188, Class Loss: 98.1926
# Epoch [2/50], Total Loss: 128.5931, Rec Loss: 45.5427, KL Div: 0.0377, Class Loss: 83.0126
# Epoch [3/50], Total Loss: 128.2500, Rec Loss: 45.4999, KL Div: 0.0614, Class Loss: 82.6887
# Epoch [4/50], Total Loss: 127.5926, Rec Loss: 45.4464, KL Div: 0.0709, Class Loss: 82.0753
# Epoch [5/50], Total Loss: 126.9266, Rec Loss: 45.4642, KL Div: 0.1047, Class Loss: 81.3577
# Epoch [6/50], Total Loss: 126.1660, Rec Loss: 45.4142, KL Div: 0.0827, Class Loss: 80.6691
# Epoch [7/50], Total Loss: 125.1788, Rec Loss: 45.4120, KL Div: 0.0509, Class Loss: 79.7159
# Epoch [8/50], Total Loss: 124.3234, Rec Loss: 45.3863, KL Div: 0.0502, Class Loss: 78.8868
# Epoch [9/50], Total Loss: 123.0672, Rec Loss: 45.3926, KL Div: 0.0349, Class Loss: 77.6398
# Epoch [10/50], Total Loss: 121.1662, Rec Loss: 45.3707, KL Div: 0.0398, Class Loss: 75.7558
# Epoch [11/50], Total Loss: 118.9934, Rec Loss: 45.3692, KL Div: 0.0432, Class Loss: 73.5810
# Epoch [12/50], Total Loss: 116.3667, Rec Loss: 45.3564, KL Div: 0.0441, Class Loss: 70.9662
# Epoch [13/50], Total Loss: 113.1866, Rec Loss: 45.3752, KL Div: 0.0405, Class Loss: 67.7709
# Epoch [14/50], Total Loss: 108.9659, Rec Loss: 45.3412, KL Div: 0.0265, Class Loss: 63.5982
# Epoch [15/50], Total Loss: 106.5915, Rec Loss: 45.3402, KL Div: 0.0317, Class Loss: 61.2196
# Epoch [16/50], Total Loss: 103.2241, Rec Loss: 45.3495, KL Div: 0.0321, Class Loss: 57.8425
# Epoch [17/50], Total Loss: 100.3277, Rec Loss: 45.3308, KL Div: 0.0228, Class Loss: 54.9741
# Epoch [18/50], Total Loss: 97.5777, Rec Loss: 45.3234, KL Div: 0.0191, Class Loss: 52.2352
# Epoch [19/50], Total Loss: 96.4518, Rec Loss: 45.2925, KL Div: 0.0194, Class Loss: 51.1399
# Epoch [20/50], Total Loss: 93.2347, Rec Loss: 45.3552, KL Div: 0.0168, Class Loss: 47.8627
# Epoch [21/50], Total Loss: 91.5872, Rec Loss: 45.3119, KL Div: 0.0170, Class Loss: 46.2583
# Epoch [22/50], Total Loss: 90.5971, Rec Loss: 45.3122, KL Div: 0.0186, Class Loss: 45.2663
# Epoch [23/50], Total Loss: 88.8683, Rec Loss: 45.3128, KL Div: 0.0195, Class Loss: 43.5359
# Epoch [24/50], Total Loss: 87.5495, Rec Loss: 45.3199, KL Div: 0.0180, Class Loss: 42.2117
# Epoch [25/50], Total Loss: 85.7405, Rec Loss: 45.2974, KL Div: 0.0187, Class Loss: 40.4243
# Epoch [26/50], Total Loss: 84.9950, Rec Loss: 45.3101, KL Div: 0.0185, Class Loss: 39.6664
# Epoch [27/50], Total Loss: 83.7974, Rec Loss: 45.3269, KL Div: 0.0174, Class Loss: 38.4530
# Epoch [28/50], Total Loss: 82.0337, Rec Loss: 45.3135, KL Div: 0.0166, Class Loss: 36.7036
# Epoch [29/50], Total Loss: 82.6757, Rec Loss: 45.3032, KL Div: 0.0165, Class Loss: 37.3559
# Epoch [30/50], Total Loss: 82.9965, Rec Loss: 45.3171, KL Div: 0.0161, Class Loss: 37.6633
# Epoch [31/50], Total Loss: 80.7174, Rec Loss: 45.3068, KL Div: 0.0146, Class Loss: 35.3960
# Epoch [32/50], Total Loss: 80.6845, Rec Loss: 45.3177, KL Div: 0.0148, Class Loss: 35.3520
# Epoch [33/50], Total Loss: 81.3338, Rec Loss: 45.3069, KL Div: 0.0133, Class Loss: 36.0135
# Epoch [34/50], Total Loss: 79.5840, Rec Loss: 45.3125, KL Div: 0.0127, Class Loss: 34.2589
# Epoch [35/50], Total Loss: 78.2394, Rec Loss: 45.2985, KL Div: 0.0120, Class Loss: 32.9289
# Epoch [36/50], Total Loss: 78.4311, Rec Loss: 45.3007, KL Div: 0.0116, Class Loss: 33.1187
# Epoch [37/50], Total Loss: 78.2351, Rec Loss: 45.3025, KL Div: 0.0109, Class Loss: 32.9217
# Epoch [38/50], Total Loss: 79.2338, Rec Loss: 45.2882, KL Div: 0.0108, Class Loss: 33.9348
# Epoch [39/50], Total Loss: 78.2260, Rec Loss: 45.3047, KL Div: 0.0106, Class Loss: 32.9108
# Epoch [40/50], Total Loss: 77.8931, Rec Loss: 45.3009, KL Div: 0.0099, Class Loss: 32.5822
# Epoch [41/50], Total Loss: 77.4810, Rec Loss: 45.2982, KL Div: 0.0091, Class Loss: 32.1737
# Epoch [42/50], Total Loss: 76.9685, Rec Loss: 45.2960, KL Div: 0.0091, Class Loss: 31.6634
# Epoch [43/50], Total Loss: 75.8842, Rec Loss: 45.2949, KL Div: 0.0099, Class Loss: 30.5793
# Epoch [44/50], Total Loss: 78.0165, Rec Loss: 45.2912, KL Div: 0.0098, Class Loss: 32.7154
# Epoch [45/50], Total Loss: 75.0764, Rec Loss: 45.2977, KL Div: 0.0098, Class Loss: 29.7689
# Epoch [46/50], Total Loss: 75.9116, Rec Loss: 45.3075, KL Div: 0.0093, Class Loss: 30.5948
# Epoch [47/50], Total Loss: 75.4625, Rec Loss: 45.3037, KL Div: 0.0095, Class Loss: 30.1494
# Epoch [48/50], Total Loss: 76.8819, Rec Loss: 45.2947, KL Div: 0.0098, Class Loss: 31.5774
# Epoch [49/50], Total Loss: 75.3788, Rec Loss: 45.2974, KL Div: 0.0088, Class Loss: 30.0726
# Epoch [50/50], Total Loss: 75.2217, Rec Loss: 45.2958, KL Div: 0.0093, Class Loss: 29.9166
# Time elapsed:  75.75637626647949
# Fold 2 Validation Loss: 0.1469, Validation Accuracy: 0.9671
# Fold 3/5
# Epoch [1/50], Total Loss: 145.8198, Rec Loss: 45.4250, KL Div: 2.0072, Class Loss: 98.3876
# Epoch [2/50], Total Loss: 128.2278, Rec Loss: 45.1890, KL Div: 0.0299, Class Loss: 83.0088
# Epoch [3/50], Total Loss: 127.8715, Rec Loss: 45.1509, KL Div: 0.0406, Class Loss: 82.6801
# Epoch [4/50], Total Loss: 127.3194, Rec Loss: 45.1037, KL Div: 0.0613, Class Loss: 82.1545
# Epoch [5/50], Total Loss: 126.5417, Rec Loss: 45.0695, KL Div: 0.0752, Class Loss: 81.3970
# Epoch [6/50], Total Loss: 125.8892, Rec Loss: 45.0866, KL Div: 0.0564, Class Loss: 80.7462
# Epoch [7/50], Total Loss: 125.2776, Rec Loss: 45.0707, KL Div: 0.0451, Class Loss: 80.1617
# Epoch [8/50], Total Loss: 124.4825, Rec Loss: 45.0724, KL Div: 0.0427, Class Loss: 79.3674
# Epoch [9/50], Total Loss: 123.4174, Rec Loss: 45.0524, KL Div: 0.0401, Class Loss: 78.3249
# Epoch [10/50], Total Loss: 121.9474, Rec Loss: 45.0439, KL Div: 0.0311, Class Loss: 76.8724
# Epoch [11/50], Total Loss: 120.9126, Rec Loss: 45.0480, KL Div: 0.0454, Class Loss: 75.8192
# Epoch [12/50], Total Loss: 118.4802, Rec Loss: 45.0559, KL Div: 0.0326, Class Loss: 73.3917
# Epoch [13/50], Total Loss: 115.9845, Rec Loss: 45.0314, KL Div: 0.0288, Class Loss: 70.9243
# Epoch [14/50], Total Loss: 113.2484, Rec Loss: 45.0369, KL Div: 0.0318, Class Loss: 68.1797
# Epoch [15/50], Total Loss: 110.0911, Rec Loss: 45.0214, KL Div: 0.0269, Class Loss: 65.0428
# Epoch [16/50], Total Loss: 106.9856, Rec Loss: 45.0011, KL Div: 0.0310, Class Loss: 61.9534
# Epoch [17/50], Total Loss: 104.5498, Rec Loss: 45.0110, KL Div: 0.0323, Class Loss: 59.5065
# Epoch [18/50], Total Loss: 101.7613, Rec Loss: 45.0345, KL Div: 0.0242, Class Loss: 56.7025
# Epoch [19/50], Total Loss: 99.5252, Rec Loss: 45.0197, KL Div: 0.0208, Class Loss: 54.4847
# Epoch [20/50], Total Loss: 97.4764, Rec Loss: 44.9886, KL Div: 0.0163, Class Loss: 52.4714
# Epoch [21/50], Total Loss: 95.0904, Rec Loss: 44.9954, KL Div: 0.0156, Class Loss: 50.0793
# Epoch [22/50], Total Loss: 93.3855, Rec Loss: 44.9889, KL Div: 0.0175, Class Loss: 48.3791
# Epoch [23/50], Total Loss: 91.3223, Rec Loss: 44.9962, KL Div: 0.0156, Class Loss: 46.3105
# Epoch [24/50], Total Loss: 89.6639, Rec Loss: 44.9901, KL Div: 0.0169, Class Loss: 44.6569
# Epoch [25/50], Total Loss: 88.2834, Rec Loss: 44.9809, KL Div: 0.0185, Class Loss: 43.2840
# Epoch [26/50], Total Loss: 87.1156, Rec Loss: 44.9887, KL Div: 0.0186, Class Loss: 42.1084
# Epoch [27/50], Total Loss: 86.1345, Rec Loss: 45.0030, KL Div: 0.0185, Class Loss: 41.1130
# Epoch [28/50], Total Loss: 85.3590, Rec Loss: 44.9903, KL Div: 0.0164, Class Loss: 40.3524
# Epoch [29/50], Total Loss: 84.1424, Rec Loss: 44.9745, KL Div: 0.0167, Class Loss: 39.1512
# Epoch [30/50], Total Loss: 82.8768, Rec Loss: 44.9890, KL Div: 0.0150, Class Loss: 37.8728
# Epoch [31/50], Total Loss: 83.7606, Rec Loss: 44.9765, KL Div: 0.0138, Class Loss: 38.7703
# Epoch [32/50], Total Loss: 83.6075, Rec Loss: 44.9968, KL Div: 0.0132, Class Loss: 38.5975
# Epoch [33/50], Total Loss: 81.6760, Rec Loss: 44.9950, KL Div: 0.0115, Class Loss: 36.6695
# Epoch [34/50], Total Loss: 80.2414, Rec Loss: 44.9899, KL Div: 0.0111, Class Loss: 35.2404
# Epoch [35/50], Total Loss: 80.7439, Rec Loss: 44.9887, KL Div: 0.0100, Class Loss: 35.7452
# Epoch [36/50], Total Loss: 79.6670, Rec Loss: 44.9772, KL Div: 0.0097, Class Loss: 34.6801
# Epoch [37/50], Total Loss: 81.1054, Rec Loss: 44.9824, KL Div: 0.0093, Class Loss: 36.1137
# Epoch [38/50], Total Loss: 79.3239, Rec Loss: 44.9696, KL Div: 0.0094, Class Loss: 34.3450
# Epoch [39/50], Total Loss: 80.5477, Rec Loss: 44.9744, KL Div: 0.0101, Class Loss: 35.5632
# Epoch [40/50], Total Loss: 79.3463, Rec Loss: 44.9689, KL Div: 0.0100, Class Loss: 34.3673
# Epoch [41/50], Total Loss: 78.6746, Rec Loss: 44.9681, KL Div: 0.0100, Class Loss: 33.6966
# Epoch [42/50], Total Loss: 77.6575, Rec Loss: 44.9730, KL Div: 0.0097, Class Loss: 32.6748
# Epoch [43/50], Total Loss: 76.8382, Rec Loss: 44.9834, KL Div: 0.0095, Class Loss: 31.8453
# Epoch [44/50], Total Loss: 79.4817, Rec Loss: 44.9735, KL Div: 0.0095, Class Loss: 34.4988
# Epoch [45/50], Total Loss: 78.1362, Rec Loss: 44.9887, KL Div: 0.0093, Class Loss: 33.1382
# Epoch [46/50], Total Loss: 77.0156, Rec Loss: 44.9783, KL Div: 0.0089, Class Loss: 32.0284
# Epoch [47/50], Total Loss: 76.9711, Rec Loss: 44.9782, KL Div: 0.0092, Class Loss: 31.9837
# Epoch [48/50], Total Loss: 77.4688, Rec Loss: 44.9753, KL Div: 0.0088, Class Loss: 32.4848
# Epoch [49/50], Total Loss: 76.6013, Rec Loss: 44.9865, KL Div: 0.0089, Class Loss: 31.6059
# Epoch [50/50], Total Loss: 76.3863, Rec Loss: 44.9707, KL Div: 0.0082, Class Loss: 31.4074
# Time elapsed:  72.32382726669312
# Fold 3 Validation Loss: 0.0733, Validation Accuracy: 0.9746
# Fold 4/5
# Epoch [1/50], Total Loss: 148.7126, Rec Loss: 45.7726, KL Div: 1.5059, Class Loss: 101.4341
# Epoch [2/50], Total Loss: 128.5418, Rec Loss: 45.4715, KL Div: 0.0186, Class Loss: 83.0518
# Epoch [3/50], Total Loss: 128.0382, Rec Loss: 45.4350, KL Div: 0.0165, Class Loss: 82.5867
# Epoch [4/50], Total Loss: 127.6120, Rec Loss: 45.3877, KL Div: 0.0219, Class Loss: 82.2024
# Epoch [5/50], Total Loss: 127.0372, Rec Loss: 45.3615, KL Div: 0.0268, Class Loss: 81.6489
# Epoch [6/50], Total Loss: 126.4826, Rec Loss: 45.3332, KL Div: 0.0247, Class Loss: 81.1247
# Epoch [7/50], Total Loss: 125.8154, Rec Loss: 45.3200, KL Div: 0.0209, Class Loss: 80.4744
# Epoch [8/50], Total Loss: 125.2247, Rec Loss: 45.3131, KL Div: 0.0167, Class Loss: 79.8950
# Epoch [9/50], Total Loss: 124.5414, Rec Loss: 45.3099, KL Div: 0.0160, Class Loss: 79.2154
# Epoch [10/50], Total Loss: 123.5045, Rec Loss: 45.2906, KL Div: 0.0205, Class Loss: 78.1933
# Epoch [11/50], Total Loss: 122.3974, Rec Loss: 45.2935, KL Div: 0.0222, Class Loss: 77.0817
# Epoch [12/50], Total Loss: 120.4067, Rec Loss: 45.2333, KL Div: 0.0198, Class Loss: 75.1536
# Epoch [13/50], Total Loss: 118.2796, Rec Loss: 45.2755, KL Div: 0.0231, Class Loss: 72.9811
# Epoch [14/50], Total Loss: 115.4938, Rec Loss: 45.2626, KL Div: 0.0242, Class Loss: 70.2070
# Epoch [15/50], Total Loss: 112.4206, Rec Loss: 45.2823, KL Div: 0.0235, Class Loss: 67.1147
# Epoch [16/50], Total Loss: 108.6646, Rec Loss: 45.2579, KL Div: 0.0183, Class Loss: 63.3884
# Epoch [17/50], Total Loss: 105.6413, Rec Loss: 45.2799, KL Div: 0.0159, Class Loss: 60.3455
# Epoch [18/50], Total Loss: 103.1956, Rec Loss: 45.2507, KL Div: 0.0168, Class Loss: 57.9281
# Epoch [19/50], Total Loss: 100.1586, Rec Loss: 45.2457, KL Div: 0.0155, Class Loss: 54.8974
# Epoch [20/50], Total Loss: 97.6375, Rec Loss: 45.2535, KL Div: 0.0155, Class Loss: 52.3684
# Epoch [21/50], Total Loss: 95.5957, Rec Loss: 45.2519, KL Div: 0.0165, Class Loss: 50.3273
# Epoch [22/50], Total Loss: 93.4358, Rec Loss: 45.2574, KL Div: 0.0146, Class Loss: 48.1638
# Epoch [23/50], Total Loss: 92.3043, Rec Loss: 45.2456, KL Div: 0.0157, Class Loss: 47.0430
# Epoch [24/50], Total Loss: 89.8896, Rec Loss: 45.2470, KL Div: 0.0160, Class Loss: 44.6267
# Epoch [25/50], Total Loss: 88.3822, Rec Loss: 45.2424, KL Div: 0.0155, Class Loss: 43.1244
# Epoch [26/50], Total Loss: 87.5732, Rec Loss: 45.2315, KL Div: 0.0159, Class Loss: 42.3257
# Epoch [27/50], Total Loss: 85.8236, Rec Loss: 45.2396, KL Div: 0.0157, Class Loss: 40.5683
# Epoch [28/50], Total Loss: 84.9007, Rec Loss: 45.2435, KL Div: 0.0154, Class Loss: 39.6418
# Epoch [29/50], Total Loss: 84.2123, Rec Loss: 45.2313, KL Div: 0.0151, Class Loss: 38.9659
# Epoch [30/50], Total Loss: 82.5685, Rec Loss: 45.2348, KL Div: 0.0156, Class Loss: 37.3181
# Epoch [31/50], Total Loss: 81.9266, Rec Loss: 45.2287, KL Div: 0.0155, Class Loss: 36.6824
# Epoch [32/50], Total Loss: 81.1616, Rec Loss: 45.2303, KL Div: 0.0139, Class Loss: 35.9174
# Epoch [33/50], Total Loss: 81.9058, Rec Loss: 45.2176, KL Div: 0.0141, Class Loss: 36.6742
# Epoch [34/50], Total Loss: 80.4496, Rec Loss: 45.2182, KL Div: 0.0134, Class Loss: 35.2180
# Epoch [35/50], Total Loss: 80.2501, Rec Loss: 45.2235, KL Div: 0.0129, Class Loss: 35.0137
# Epoch [36/50], Total Loss: 81.1692, Rec Loss: 45.2246, KL Div: 0.0129, Class Loss: 35.9318
# Epoch [37/50], Total Loss: 79.6664, Rec Loss: 45.2333, KL Div: 0.0124, Class Loss: 34.4208
# Epoch [38/50], Total Loss: 79.0948, Rec Loss: 45.2159, KL Div: 0.0121, Class Loss: 33.8668
# Epoch [39/50], Total Loss: 78.4719, Rec Loss: 45.2247, KL Div: 0.0125, Class Loss: 33.2347
# Epoch [40/50], Total Loss: 77.5533, Rec Loss: 45.2173, KL Div: 0.0118, Class Loss: 32.3243
# Epoch [41/50], Total Loss: 77.4803, Rec Loss: 45.2302, KL Div: 0.0113, Class Loss: 32.2388
# Epoch [42/50], Total Loss: 77.6764, Rec Loss: 45.2255, KL Div: 0.0117, Class Loss: 32.4392
# Epoch [43/50], Total Loss: 78.7268, Rec Loss: 45.2314, KL Div: 0.0114, Class Loss: 33.4840
# Epoch [44/50], Total Loss: 76.7195, Rec Loss: 45.2304, KL Div: 0.0113, Class Loss: 31.4779
# Epoch [45/50], Total Loss: 77.7263, Rec Loss: 45.2187, KL Div: 0.0114, Class Loss: 32.4962
# Epoch [46/50], Total Loss: 76.5030, Rec Loss: 45.2183, KL Div: 0.0115, Class Loss: 31.2732
# Epoch [47/50], Total Loss: 76.3435, Rec Loss: 45.2173, KL Div: 0.0121, Class Loss: 31.1141
# Epoch [48/50], Total Loss: 76.0676, Rec Loss: 45.2195, KL Div: 0.0115, Class Loss: 30.8366
# Epoch [49/50], Total Loss: 76.2085, Rec Loss: 45.2316, KL Div: 0.0110, Class Loss: 30.9658
# Epoch [50/50], Total Loss: 75.6886, Rec Loss: 45.2148, KL Div: 0.0104, Class Loss: 30.4635
# Time elapsed:  72.0656144618988
# Fold 4 Validation Loss: 0.0667, Validation Accuracy: 0.9795
# Fold 5/5
# Epoch [1/50], Total Loss: 138.6332, Rec Loss: 45.9857, KL Div: 0.9799, Class Loss: 91.6676
# Epoch [2/50], Total Loss: 128.8586, Rec Loss: 45.6813, KL Div: 0.0510, Class Loss: 83.1263
# Epoch [3/50], Total Loss: 128.1948, Rec Loss: 45.6641, KL Div: 0.0628, Class Loss: 82.4679
# Epoch [4/50], Total Loss: 127.3829, Rec Loss: 45.6308, KL Div: 0.0997, Class Loss: 81.6524
# Epoch [5/50], Total Loss: 126.4511, Rec Loss: 45.5915, KL Div: 0.0938, Class Loss: 80.7658
# Epoch [6/50], Total Loss: 125.3014, Rec Loss: 45.5818, KL Div: 0.0919, Class Loss: 79.6277
# Epoch [7/50], Total Loss: 123.9091, Rec Loss: 45.5993, KL Div: 0.0695, Class Loss: 78.2403
# Epoch [8/50], Total Loss: 122.4778, Rec Loss: 45.5515, KL Div: 0.0937, Class Loss: 76.8326
# Epoch [9/50], Total Loss: 119.8659, Rec Loss: 45.5550, KL Div: 0.0920, Class Loss: 74.2189
# Epoch [10/50], Total Loss: 117.1818, Rec Loss: 45.5449, KL Div: 0.1020, Class Loss: 71.5349
# Epoch [11/50], Total Loss: 113.5932, Rec Loss: 45.5220, KL Div: 0.0573, Class Loss: 68.0139
# Epoch [12/50], Total Loss: 109.0383, Rec Loss: 45.5110, KL Div: 0.0349, Class Loss: 63.4923
# Epoch [13/50], Total Loss: 105.7119, Rec Loss: 45.5056, KL Div: 0.0380, Class Loss: 60.1683
# Epoch [14/50], Total Loss: 101.5259, Rec Loss: 45.4948, KL Div: 0.0357, Class Loss: 55.9954
# Epoch [15/50], Total Loss: 97.6514, Rec Loss: 45.5050, KL Div: 0.0318, Class Loss: 52.1146
# Epoch [16/50], Total Loss: 95.8760, Rec Loss: 45.5171, KL Div: 0.0343, Class Loss: 50.3246
# Epoch [17/50], Total Loss: 93.2194, Rec Loss: 45.5033, KL Div: 0.0294, Class Loss: 47.6867
# Epoch [18/50], Total Loss: 92.2419, Rec Loss: 45.4985, KL Div: 0.0294, Class Loss: 46.7140
# Epoch [19/50], Total Loss: 89.1285, Rec Loss: 45.5078, KL Div: 0.0231, Class Loss: 43.5976
# Epoch [20/50], Total Loss: 87.6297, Rec Loss: 45.4940, KL Div: 0.0206, Class Loss: 42.1151
# Epoch [21/50], Total Loss: 86.6032, Rec Loss: 45.4936, KL Div: 0.0196, Class Loss: 41.0899
# Epoch [22/50], Total Loss: 85.3114, Rec Loss: 45.4836, KL Div: 0.0191, Class Loss: 39.8087
# Epoch [23/50], Total Loss: 84.0590, Rec Loss: 45.4875, KL Div: 0.0184, Class Loss: 38.5531
# Epoch [24/50], Total Loss: 82.0930, Rec Loss: 45.4860, KL Div: 0.0181, Class Loss: 36.5889
# Epoch [25/50], Total Loss: 81.2496, Rec Loss: 45.4813, KL Div: 0.0186, Class Loss: 35.7496
# Epoch [26/50], Total Loss: 81.4797, Rec Loss: 45.4866, KL Div: 0.0188, Class Loss: 35.9743
# Epoch [27/50], Total Loss: 80.3116, Rec Loss: 45.4855, KL Div: 0.0189, Class Loss: 34.8072
# Epoch [28/50], Total Loss: 79.9481, Rec Loss: 45.4773, KL Div: 0.0169, Class Loss: 34.4539
# Epoch [29/50], Total Loss: 79.8158, Rec Loss: 45.4880, KL Div: 0.0166, Class Loss: 34.3112
# Epoch [30/50], Total Loss: 79.2635, Rec Loss: 45.4772, KL Div: 0.0155, Class Loss: 33.7708
# Epoch [31/50], Total Loss: 78.7655, Rec Loss: 45.4789, KL Div: 0.0145, Class Loss: 33.2720
# Epoch [32/50], Total Loss: 77.7944, Rec Loss: 45.4711, KL Div: 0.0140, Class Loss: 32.3092
# Epoch [33/50], Total Loss: 77.3742, Rec Loss: 45.4740, KL Div: 0.0136, Class Loss: 31.8866
# Epoch [34/50], Total Loss: 76.9317, Rec Loss: 45.4643, KL Div: 0.0131, Class Loss: 31.4543
# Epoch [35/50], Total Loss: 77.0174, Rec Loss: 45.4652, KL Div: 0.0132, Class Loss: 31.5390
# Epoch [36/50], Total Loss: 77.8579, Rec Loss: 45.4677, KL Div: 0.0131, Class Loss: 32.3771
# Epoch [37/50], Total Loss: 76.4631, Rec Loss: 45.4715, KL Div: 0.0122, Class Loss: 30.9794
# Epoch [38/50], Total Loss: 76.1664, Rec Loss: 45.4763, KL Div: 0.0113, Class Loss: 30.6788
# Epoch [39/50], Total Loss: 75.2051, Rec Loss: 45.4782, KL Div: 0.0108, Class Loss: 29.7162
# Epoch [40/50], Total Loss: 75.1814, Rec Loss: 45.4641, KL Div: 0.0106, Class Loss: 29.7067
# Epoch [41/50], Total Loss: 75.0340, Rec Loss: 45.4600, KL Div: 0.0110, Class Loss: 29.5630
# Epoch [42/50], Total Loss: 75.0399, Rec Loss: 45.4759, KL Div: 0.0103, Class Loss: 29.5536
# Epoch [43/50], Total Loss: 73.6915, Rec Loss: 45.4728, KL Div: 0.0101, Class Loss: 28.2086
# Epoch [44/50], Total Loss: 76.8842, Rec Loss: 45.4656, KL Div: 0.0110, Class Loss: 31.4076
# Epoch [45/50], Total Loss: 74.3421, Rec Loss: 45.4582, KL Div: 0.0098, Class Loss: 28.8741
# Epoch [46/50], Total Loss: 73.4490, Rec Loss: 45.4589, KL Div: 0.0101, Class Loss: 27.9800
# Epoch [47/50], Total Loss: 73.3471, Rec Loss: 45.4563, KL Div: 0.0094, Class Loss: 27.8814
# Epoch [48/50], Total Loss: 74.4569, Rec Loss: 45.4486, KL Div: 0.0098, Class Loss: 28.9984
# Epoch [49/50], Total Loss: 75.1073, Rec Loss: 45.4657, KL Div: 0.0102, Class Loss: 29.6314
# Epoch [50/50], Total Loss: 72.8836, Rec Loss: 45.4559, KL Div: 0.0101, Class Loss: 27.4176
# Time elapsed:  60.322097063064575
# Fold 5 Validation Loss: 0.0682, Validation Accuracy: 0.9753

# %%
def plot_training_loss(model_name, save_dir):
    training_traj = np.load(save_dir+model_name+"_training_loss.npz")

    total_loss = training_traj['training_total_loss']
    rec_loss = training_traj['training_rec_loss']
    kl_loss = training_traj['training_kl_loss']
    class_loss = training_traj['training_class_loss']
    plt.figure(figsize=(16, 16))
    plt.suptitle(model_name, fontsize=16)
    plt.subplot(2, 2, 1)
    plt.title("Total Loss", fontsize=12)
    plt.plot(range(len(total_loss)), total_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(2, 2, 2)
    plt.title("Reconstruction Loss", fontsize=12)
    plt.plot(range(len(total_loss)), rec_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(2, 2, 3)
    plt.title("KL Loss", fontsize=12)
    plt.plot(range(len(total_loss)), kl_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(2, 2, 4)
    plt.title("Classification Loss", fontsize=12)
    plt.plot(range(len(total_loss)), class_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    
for fold in range(k_folds):
    plot_training_loss("CondVAE_model"+str(fold+1), save_dir)

# %%
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Normal", "Anomalous"]).plot(cmap=plt.cm.Blues)

# %% [markdown]
# # Initialize 3 new models for fine-tuning

# %%
buffer.seek(0) 
model_medium = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_medium.load_state_dict(torch.load(buffer))
model_medium = model_medium.to(device)

buffer.seek(0)
model_strong = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_strong.load_state_dict(torch.load(buffer))
model_strong = model_strong.to(device)
buffer.seek(0)
model_random = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_random.load_state_dict(torch.load(buffer))
model_random = model_random.to(device)

# %% [markdown]
# # Verify the 3 new models

# %%
# Initialize a flag
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Initialize a flag
models_identical = True
original_state_dict = model_random.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Initialize a flag
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_strong.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Out:
# The saved and loaded models are identical.
# The saved and loaded models are identical.
# The saved and loaded models are identical.

# %% [markdown]
# # Evaluate the Model and Detect Anomalies

# %%
def compute_anomaly_scores(model, data_loader):
    model.eval()
    rec_errors = []
    anomaly_probs = []
    true_labels = []
    predictions = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.unsqueeze(1).to(device)
            y_batch = y_batch.to(device)

            x_rec, class_logits = model(X_batch)
            y_probs = F.softmax(class_logits, dim=1)

            # Reconstruction error
            rec_error = torch.mean((X_batch - x_rec) ** 2, dim=[1, 2])

            # Classification probability for anomaly class
            anomaly_prob = y_probs[:, 1]

            # Combine scores
            #anomaly_score = rec_error * anomaly_prob
            rec_errors.extend(rec_error.cpu().numpy())
            anomaly_probs.extend(anomaly_prob.cpu().numpy())
            true_labels.extend(y_batch.cpu().numpy())
            predictions.extend(torch.argmax(class_logits, dim=1).cpu().numpy())

    return np.array(rec_errors), np.array(anomaly_probs), np.array(true_labels), np.array(predictions)

# Compute anomaly scores
train_rec_errors, train_anomaly_probs, train_true_labels, train_predictions = compute_anomaly_scores(model, train_loader)
val_rec_errors, val_anomaly_probs, val_true_labels, val_predictions = compute_anomaly_scores(model, val_loader)
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model, test_loader)

plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 83.94%, recall = 65.94% and F1-score = 73.86%

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_anomaly_probs)), val_anomaly_probs, alpha=0.7, c=(val_true_labels!=val_predictions), cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(val_rec_errors, val_anomaly_probs, alpha=0.7, c=(val_true_labels==val_predictions), cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores with Reconstruction Errors")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(val_anomaly_probs, vert=False)
plt.title("Box Plot of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.show()

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(val_anomaly_probs, bins=20, alpha=0.7, edgecolor='black')
plt.title("Histogram of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_true_labels, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (true labels)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_predictions, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (predictions)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_anomaly_probs, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (anomalous probability)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(val_rec_errors, vert=False)
plt.title("Box Plot of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.show()

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(val_rec_errors, bins=20, alpha=0.7, edgecolor='black')
plt.title("Histogram of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Retrain

# %%
# Determine thresholds
#lower_percentile = 62.5
#upper_percentile = 37.5
#lower_threshold = np.percentile(val_anomaly_probs, lower_percentile)
#upper_threshold = np.percentile(val_anomaly_probs, upper_percentile)


# Select medium-score data
medium_score_indices = np.where((val_anomaly_probs >= 0.05) & (val_anomaly_probs <= 0.95))[0]
X_medium = X_val[medium_score_indices]
y_medium = y_val[medium_score_indices]
print("Medium-score data shape:", X_medium.shape, y_medium.shape)
X_medium_tensor = torch.tensor(X_medium).float()
y_medium_tensor = torch.tensor(y_medium).long()
# data loader
medium_dataset = TimeSeriesDataset(X_medium_tensor, y_medium_tensor)
medium_loader = DataLoader(medium_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Medium-score data shape: (2898, 10) (2898,)

# %%
# Determine thresholds
#lower_percentile = 12.5
#upper_percentile = 87.5
#lower_threshold = np.percentile(val_anomaly_probs, lower_percentile)
#upper_threshold = np.percentile(val_anomaly_probs, upper_percentile)

# Select strong-score data
strong_score_indices = np.where((val_anomaly_probs <= 0.01) | (val_anomaly_probs >= 0.99))[0]
X_strong = X_val[strong_score_indices]
y_strong = y_val[strong_score_indices]
print("Strong-score data shape:", X_strong.shape, y_strong.shape)
X_strong_tensor = torch.tensor(X_strong).float()
y_strong_tensor = torch.tensor(y_strong).long()
# data loader
strong_dataset = TimeSeriesDataset(X_strong_tensor, y_strong_tensor)
strong_loader = DataLoader(strong_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Strong-score data shape: (19817, 10) (19817,)

# %%
# Optional: Set a random seed for reproducibility
np.random.seed(42)

# Define the fraction of data to select
sample_fraction = 0.25
total_samples = len(val_anomaly_probs)
sample_size = int(sample_fraction * total_samples)

# Randomly select unique indices without replacement
random_score_indices = np.random.choice(total_samples, size=sample_size, replace=False)

# Select the corresponding data and labels
X_random = X_val[random_score_indices]
y_random = y_val[random_score_indices]
print("Random data shape:", X_random.shape, y_random.shape)
# Convert to PyTorch tensors
X_random_tensor = torch.tensor(X_random).float()
y_random_tensor = torch.tensor(y_random).long()

# Create the dataset and data loader
random_dataset = TimeSeriesDataset(X_random_tensor, y_random_tensor)
random_loader = DataLoader(random_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Random data shape: (8399, 10) (8399,)

# %%
# Finetune the model
model_name = "model_medium"
optimizer = optim.Adam(model_medium.parameters(), lr=finetune_learning_rate)
#optimizer = optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-7)
model_medium = train_model(model_medium, optimizer, medium_loader, num_epochs=finetune_num_epochs, model_name=
                           model_name, save_dir=save_dir, save=True)
plot_training_loss(model_name, save_dir)
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Out:
# Epoch [1/5], Total Loss: 25.3745, Rec Loss: 5.1948, KL Div: 0.0041, Class Loss: 20.1755
# Epoch [2/5], Total Loss: 24.1558, Rec Loss: 5.1737, KL Div: 0.0040, Class Loss: 18.9782
# Epoch [3/5], Total Loss: 23.6274, Rec Loss: 5.1582, KL Div: 0.0038, Class Loss: 18.4654
# Epoch [4/5], Total Loss: 23.3355, Rec Loss: 5.1450, KL Div: 0.0037, Class Loss: 18.1868
# Epoch [5/5], Total Loss: 23.1842, Rec Loss: 5.1295, KL Div: 0.0036, Class Loss: 18.0512
# Time elapsed:  0.5299375057220459
# Mismatch found at layer: encoder.fc_layers.0.weight
# The models are not identical.

# %%
optimizer = optim.Adam(model_strong.parameters(), lr=finetune_learning_rate)
model_name = "model_strong"
model_strong = train_model(model_strong, optimizer, strong_loader, num_epochs=finetune_num_epochs, model_name=model_name)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/5], Total Loss: 35.7991, Rec Loss: 34.1254, KL Div: 0.0051, Class Loss: 1.6686
# Epoch [2/5], Total Loss: 35.4741, Rec Loss: 34.1114, KL Div: 0.0045, Class Loss: 1.3582
# Epoch [3/5], Total Loss: 35.3945, Rec Loss: 34.1271, KL Div: 0.0044, Class Loss: 1.2630
# Epoch [4/5], Total Loss: 35.3205, Rec Loss: 34.1100, KL Div: 0.0044, Class Loss: 1.2061
# Epoch [5/5], Total Loss: 35.2676, Rec Loss: 34.1098, KL Div: 0.0043, Class Loss: 1.1535
# Time elapsed:  3.4022810459136963

# %%
model_name = "model_random"
optimizer = optim.Adam(model_random.parameters(), lr=finetune_learning_rate)
model_random = train_model(model_random, optimizer, random_loader, num_epochs=finetune_num_epochs, model_name=model_name)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/5], Total Loss: 22.2938, Rec Loss: 14.3995, KL Div: 0.0034, Class Loss: 7.8909
# Epoch [2/5], Total Loss: 21.7620, Rec Loss: 14.3894, KL Div: 0.0031, Class Loss: 7.3695
# Epoch [3/5], Total Loss: 21.6397, Rec Loss: 14.4018, KL Div: 0.0030, Class Loss: 7.2349
# Epoch [4/5], Total Loss: 21.5683, Rec Loss: 14.4024, KL Div: 0.0029, Class Loss: 7.1630
# Epoch [5/5], Total Loss: 21.5039, Rec Loss: 14.3944, KL Div: 0.0029, Class Loss: 7.1067
# Time elapsed:  1.4000747203826904

# %%
# Combine data
expanded_medium_data = np.concatenate((X_train, X_medium), axis=0)
expanded_medium_labels = np.concatenate((y_train, y_medium), axis=0)
X_expanded_medium_tensor = torch.tensor(expanded_medium_data).float()
y_expanded_medium_tensor = torch.tensor(expanded_medium_labels).long()
# Create new dataset and loader
expanded_medium_dataset = TimeSeriesDataset(X_expanded_medium_tensor, y_expanded_medium_tensor)
expanded_medium_loader = DataLoader(expanded_medium_dataset, batch_size=batch_size, shuffle=False)
model2_medium = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)

# Define optimizer
model_name = "model2_medium"
optimizer = optim.Adam(model2_medium.parameters(), lr=train_learning_rate)
model2_medium = train_model(model2_medium, optimizer, expanded_medium_loader, num_epochs=train_num_epochs, model_name=model_name)
plot_training_loss(model_name, save_dir)

# %%
expanded_strong_data = np.concatenate((X_train, X_strong), axis=0)
expanded_strong_labels = np.concatenate((y_train, y_strong), axis=0)
X_expanded_strong_tensor = torch.tensor(expanded_strong_data).float()
y_expanded_strong_tensor = torch.tensor(expanded_strong_labels).long()
# Create new dataset and loader
expanded_strong_dataset = TimeSeriesDataset(X_expanded_strong_tensor, y_expanded_strong_tensor)
expanded_strong_loader = DataLoader(expanded_strong_dataset, batch_size=batch_size, shuffle=False)
model2_strong = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)

# Define optimizer
model_name = "model2_strong"
optimizer = optim.Adam(model2_strong.parameters(), lr=train_learning_rate)
model2_strong = train_model(model2_strong, optimizer, expanded_strong_loader, num_epochs=train_num_epochs, model_name="model2_strong")
plot_training_loss(model_name, save_dir)

# %%
expanded_random_data = np.concatenate((X_train, X_random), axis=0)
expanded_random_labels = np.concatenate((y_train, y_random), axis=0)
X_expanded_random_tensor = torch.tensor(expanded_random_data).float()
y_expanded_random_tensor = torch.tensor(expanded_random_labels).long()
# Create new dataset and loader
expanded_random_dataset = TimeSeriesDataset(X_expanded_random_tensor, y_expanded_random_tensor)
expanded_random_loader = DataLoader(expanded_random_dataset, batch_size=batch_size, shuffle=False)
model2_random = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)

# Define optimizer
model_name = "model2_random"
optimizer = optim.Adam(model2_random.parameters(), lr=train_learning_rate)
model2_random = train_model(model2_random, optimizer, expanded_random_loader, num_epochs=train_num_epochs, model_name="model2_random")
plot_training_loss(model_name, save_dir)

# %%
# Assuming you have already defined and initialized your models:
# model, model_medium, model_random, model_strong

# Dictionary of models with their names for easy reference
models = {
    'model': model,
    'model_medium': model_medium,
    'model_random': model_random,
    'model_strong': model_strong,
    'model2_medium': model2_medium,
    'model2_random': model2_random,
    'model2_strong': model2_strong
}

# Generate all possible unique pairs of models
model_pairs = list(combinations(models.items(), 2))

# Lists to keep track of identical and different model pairs
identical_pairs = []
different_pairs = []

# Function to compare two models
def compare_models(model1, model2, name1, name2):
    state_dict1 = model1.state_dict()
    state_dict2 = model2.state_dict()
    
    # First, check if both models have the same set of keys (layers)
    keys1 = set(state_dict1.keys())
    keys2 = set(state_dict2.keys())
    
    if keys1 != keys2:
        missing_in_1 = keys2 - keys1
        missing_in_2 = keys1 - keys2
        if missing_in_1:
            
            print(f"Model '{name1}' is missing layers: {missing_in_1}")
        if missing_in_2:
            
            print(f"Model '{name2}' is missing layers: {missing_in_2}")
        return False  # Layers mismatch implies models are different
    
    # Compare each parameter tensor
    for key in state_dict1:
        param1 = state_dict1[key]
        param2 = state_dict2[key]
        
        if not torch.equal(param1, param2):
            #print(f"Mismatch found in layer '{key}' between '{name1}' and '{name2}'.")
            return False  # Found a mismatch
    
    return True  # All parameters match

# Iterate through each pair and compare
for (name1, model1), (name2, model2_medium) in model_pairs:
    print(f"Comparing '{name1}' with '{name2}':")
    are_identical = compare_models(model1, model2_medium, name1, name2)
    
    if are_identical:
        identical_pairs.append((name1, name2))
        print(f"--> '{name1}' and '{name2}' are IDENTICAL.\n")
    else:
        different_pairs.append((name1, name2))
        print(f"--> '{name1}' and '{name2}' are DIFFERENT.\n")

# Summary of results
print("=== Comparison Summary ===\n")

if identical_pairs:
    print("Identical Model Pairs:")
    for name1, name2 in identical_pairs:
        print(f" - {name1} and {name2}")
else:
    print("No identical model pairs found.")

print()

if different_pairs:
    print("Different Model Pairs:")
    for name1, name2 in different_pairs:
        print(f" - {name1} and {name2}")
else:
    print("No different model pairs found.")
# Out:
# Comparing 'model' with 'model_medium':
# --> 'model' and 'model_medium' are DIFFERENT.
#
# Comparing 'model' with 'model_random':
# --> 'model' and 'model_random' are DIFFERENT.
#
# Comparing 'model' with 'model_strong':
# --> 'model' and 'model_strong' are DIFFERENT.
#
# Comparing 'model' with 'model2_medium':
# --> 'model' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model' with 'model2_random':
# --> 'model' and 'model2_random' are DIFFERENT.
#
# Comparing 'model' with 'model2_strong':
# --> 'model' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model_medium' with 'model_random':
# --> 'model_medium' and 'model_random' are DIFFERENT.
#
# Comparing 'model_medium' with 'model_strong':
# --> 'model_medium' and 'model_strong' are DIFFERENT.
#
# Comparing 'model_medium' with 'model2_medium':
# --> 'model_medium' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model_medium' with 'model2_random':
# --> 'model_medium' and 'model2_random' are DIFFERENT.
#
# Comparing 'model_medium' with 'model2_strong':
# --> 'model_medium' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model_random' with 'model_strong':
# --> 'model_random' and 'model_strong' are DIFFERENT.
#
# Comparing 'model_random' with 'model2_medium':
# --> 'model_random' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model_random' with 'model2_random':
# --> 'model_random' and 'model2_random' are DIFFERENT.
#
# Comparing 'model_random' with 'model2_strong':
# --> 'model_random' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model_strong' with 'model2_medium':
# --> 'model_strong' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model_strong' with 'model2_random':
# --> 'model_strong' and 'model2_random' are DIFFERENT.
#
# Comparing 'model_strong' with 'model2_strong':
# --> 'model_strong' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model2_medium' with 'model2_random':
# --> 'model2_medium' and 'model2_random' are DIFFERENT.
#
# Comparing 'model2_medium' with 'model2_strong':
# --> 'model2_medium' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model2_random' with 'model2_strong':
# --> 'model2_random' and 'model2_strong' are DIFFERENT.
#
# === Comparison Summary ===
#
# No identical model pairs found.
#
# Different Model Pairs:
#  - model and model_medium
#  - model and model_random
#  - model and model_strong
#  - model and model2_medium
#  - model and model2_random
#  - model and model2_strong
#  - model_medium and model_random
#  - model_medium and model_strong
#  - model_medium and model2_medium
#  - model_medium and model2_random
#  - model_medium and model2_strong
#  - model_random and model_strong
#  - model_random and model2_medium
#  - model_random and model2_random
#  - model_random and model2_strong
#  - model_strong and model2_medium
#  - model_strong and model2_random
#  - model_strong and model2_strong
#  - model2_medium and model2_random
#  - model2_medium and model2_strong
#  - model2_random and model2_strong

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_medium, test_loader)

plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 82.92%, recall = 76.85% and F1-score = 79.77%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_strong, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 88.18%, recall = 47.52% and F1-score = 61.76%

# %%
cm = confusion_matrix(test_true_labels, test_predictions)
print(cm)
# Out:
# [[95602   311]
#  [ 2562  2320]]

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_random, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 85.9%, recall = 66.61% and F1-score = 75.03%

# %%
cm = confusion_matrix(test_true_labels, test_predictions)
print(cm)
# Out:
# [[95379   534]
#  [ 1630  3252]]

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_medium, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 0.0%, recall = 0.0% and F1-score = 0.0%
# /home/adlink3/anaconda3/envs/cvae/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_strong, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 0.0%, recall = 0.0% and F1-score = 0.0%
# /home/adlink3/anaconda3/envs/cvae/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_random, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 0.0%, recall = 0.0% and F1-score = 0.0%
# /home/adlink3/anaconda3/envs/cvae/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
