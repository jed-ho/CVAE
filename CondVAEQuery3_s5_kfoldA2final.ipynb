# %% [markdown]
# # Demonstration of anomaly detection with CVAE using DASHlink data
#
# **Author: Milad Memarzadeh (milad.memarzadeh@nasa.gov)**

# %% [markdown]
# # Import Libraries

# %%
import os
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
import torch.nn.functional as F

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, precision_recall_fscore_support, roc_curve, precision_recall_curve, average_precision_score
from sklearn.utils import shuffle
from source.modelsCondVAE import *
from source.utilsCondVAEs5 import *
from itertools import combinations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
k_folds = 5
train_learning_rate = 1e-4 #1e-3
finetune_learning_rate = 1e-5 #1e-4
train_num_epochs = 50 #10
finetune_num_epochs = 5

latent_dim = 10
batch_size = 64
window_size = 10

# %% [markdown]
# # Load and preprocess data

# %%
if os.name == 'nt':
    data_dir = 'C:/Users/jed95/Documents/GitHub/anomaly_detection/dataset/yahoo_s5/A2Benchmark/'
else:
    data_dir = '/home/adlink3/Downloads/yahoo_s5/A2Benchmark/'

file_list = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.csv')]


df_list = []
for file in file_list:
    df = pd.read_csv(file)
    df_list.append(df)

data = pd.concat(df_list, ignore_index=True)
print("Data shape:", data.shape)
# Out:
# Data shape: (142100, 3)

# %%
print("Missing values:", data.isnull().sum())
data.dropna(inplace=True)
# Out:
# Missing values: timestamp     0
# value         0
# is_anomaly    0
# dtype: int64

# %%
scaler = MinMaxScaler()
data['value'] = scaler.fit_transform(data['value'].values.reshape(-1, 1))

# %% [markdown]
# # Create Sequences

# %%
def create_sequences(values, labels, window_size, step=1):
    sequences = []
    seq_labels = []
    for i in range(0, len(values) - window_size + 1, step):
        seq = values[i:i + window_size]
        # If any label in the sequence is anomalous (e.g., 1), set the sequence label as anomalous
        label = 1 if any(labels[i:i + window_size]) else 0
        sequences.append(seq)
        seq_labels.append(label)
    return np.array(sequences), np.array(seq_labels)


sequences, seq_labels = create_sequences(data['value'].values, data['is_anomaly'].values, window_size=window_size)
print("Sequences shape:", sequences.shape)
print("Sequence labels shape:", seq_labels.shape)
# Out:
# Sequences shape: (142091, 10)
# Sequence labels shape: (142091,)

# %% [markdown]
# # Split data into labeled and unlabeled sets

# %%
# Get indices for normal and anomalous sequences
normal_indices = np.where(seq_labels == 0)[0]
anomalous_indices = np.where(seq_labels == 1)[0]

# Extract normal and anomalous sequences
normal_sequences = sequences[normal_indices]
normal_labels = seq_labels[normal_indices]

anomalous_sequences = sequences[anomalous_indices]
anomalous_labels = seq_labels[anomalous_indices]
print(normal_sequences.shape)
print(anomalous_sequences.shape)
# Out:
# (139825, 10)
# (2266, 10)

# %%
# Split normal data
X_train_normal, X_test_normal, y_train_normal, y_test_normal = train_test_split(
    normal_sequences, normal_labels, test_size=0.6, random_state=42, stratify=normal_labels)
X_train_normal, X_val_normal, y_train_normal, y_val_normal = train_test_split(
    X_train_normal, y_train_normal, test_size=0.5, random_state=42, stratify=y_train_normal)

# Split anomalous data
X_train_anomalous, X_test_anomalous, y_train_anomalous, y_test_anomalous = train_test_split(
    anomalous_sequences, anomalous_labels, test_size=0.6, random_state=42, stratify=anomalous_labels)
X_train_anomalous, X_val_anomalous, y_train_anomalous, y_val_anomalous = train_test_split(
    X_train_anomalous, y_train_anomalous, test_size=0.5, random_state=42, stratify=y_train_anomalous)

# %%
# Combine training data
X_train = np.concatenate([X_train_normal, X_train_anomalous], axis=0)
y_train = np.concatenate([y_train_normal, y_train_anomalous], axis=0)
# Combine validation data
X_val = np.concatenate([X_val_normal, X_val_anomalous], axis=0)
y_val = np.concatenate([y_val_normal, y_val_anomalous], axis=0)
# Combine test data
X_test = np.concatenate([X_test_normal, X_test_anomalous], axis=0)
y_test = np.concatenate([y_test_normal, y_test_anomalous], axis=0)
print("Training data shape:", X_train.shape, y_train.shape)
print("Validation data shape:", X_val.shape, y_val.shape)
print("Test data shape:", X_test.shape, y_test.shape)
# Out:
# Training data shape: (28418, 10) (28418,)
# Validation data shape: (28418, 10) (28418,)
# Test data shape: (85255, 10) (85255,)

# %%
# Shuffle data

X_train, y_train = shuffle(X_train, y_train, random_state=42)
X_val, y_val = shuffle(X_val, y_val, random_state=42)
X_test, y_test = shuffle(X_test, y_test, random_state=42)

# %% [markdown]
# # Convert Data to Tensors

# %%
# Convert training data to tensors
X_train_tensor = torch.tensor(X_train).float()
y_train_tensor = torch.tensor(y_train).long()
# Convert validation data to tensors
X_val_tensor = torch.tensor(X_val).float()
y_val_tensor = torch.tensor(y_val).long()
# Convert test data to tensors
X_test_tensor = torch.tensor(X_test).float()
y_test_tensor = torch.tensor(y_test).long()

# %% [markdown]
# # Create Data Loaders for Labeled and Unlabeled Data

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels  # Now labels are provided for all data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = self.data[idx]
        y = self.labels[idx]
        return X, y

# %%
# Training data loader
train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False) #TODO adjust Shuffle training data? 
full_train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)
# Validation data loader
val_dataset = TimeSeriesDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Test data loader
test_dataset = TimeSeriesDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Instantiate and Train the Conditional VAE

# %%
def evaluate_model(model, data_loader):
    model.eval()
    total_loss = 0
    total_correct = 0
    total_samples = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for data, target in data_loader:
            data = data.to(device)
            target = target.to(device)

            # Forward pass
            x_rec, class_logits = model(data)
            
            # Compute classification loss
            loss = criterion(class_logits, target)
            total_loss += loss.item() * data.size(0)

            # Compute accuracy
            preds = class_logits.argmax(dim=1)
            total_correct += (preds == target).sum().item()
            total_samples += data.size(0)

    avg_loss = total_loss / total_samples
    avg_acc = total_correct / total_samples

    return avg_loss, avg_acc

# %%
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
model_name="CondVAE_model"
save_dir="./"
# Instantiate the model
num_param = 1    # Since we have univariate time series

num_classes = 2  # Normal and Anomaly
scale_flag = 0   # Use Sigmoid activation in the decoder

results = {}

# Start k-fold cross-validation
print('Starting k-fold cross-validation...')
time_start = time.time()
for fold, (train_idx, val2_idx) in enumerate(skf.split(np.zeros(len(y_train_tensor)), y_train_tensor.cpu().numpy())):
    print(f'Fold {fold+1}/{k_folds}')
    
    # Create data loaders for the current fold
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val2_subsampler = torch.utils.data.SubsetRandomSampler(val2_idx)
    
    train_loader = DataLoader(full_train_dataset, batch_size=batch_size, sampler=train_subsampler)
    val2_loader = DataLoader(full_train_dataset, batch_size=batch_size, sampler=val2_subsampler)
    
    # Initialize the model for this fold
    model = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
    
    # Define optimizer
    optimizer = optim.Adam(model.parameters(), lr=train_learning_rate)
    
    # Train the model 
    model = train_model(
    model,
    optimizer,
    train_loader,
    num_epochs=train_num_epochs,
    save=False, # TODO: True
    save_dir=save_dir,
    model_name=model_name)
    
    # Evaluate the model on validation data
    val_loss, val_acc = evaluate_model(model, val2_loader)
    
    # Save the results for this fold
    results[fold] = {'val_loss': val_loss, 'val_acc': val_acc}
    
    print(f'Fold {fold+1} Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}')

time_end = time.time()

buffer = io.BytesIO()
torch.save(model.state_dict(), buffer)
# Out:
# Starting k-fold cross-validation...
# Fold 1/5
# Epoch [1/50], Total Loss: 158.0458, Rec Loss: 78.7237, KL Div: 0.7649, Class Loss: 78.5571
# Epoch [2/50], Total Loss: 49.1008, Rec Loss: 19.8983, KL Div: 0.2737, Class Loss: 28.9288
# Epoch [3/50], Total Loss: 44.2956, Rec Loss: 19.1690, KL Div: 0.2018, Class Loss: 24.9247
# Epoch [4/50], Total Loss: 41.0148, Rec Loss: 18.8841, KL Div: 0.1682, Class Loss: 21.9625
# Epoch [5/50], Total Loss: 38.5201, Rec Loss: 18.5088, KL Div: 0.1353, Class Loss: 19.8760
# Epoch [6/50], Total Loss: 36.0143, Rec Loss: 18.1237, KL Div: 0.0932, Class Loss: 17.7974
# Epoch [7/50], Total Loss: 34.1872, Rec Loss: 17.9632, KL Div: 0.0679, Class Loss: 16.1561
# Epoch [8/50], Total Loss: 32.6325, Rec Loss: 17.7849, KL Div: 0.0492, Class Loss: 14.7985
# Epoch [9/50], Total Loss: 31.2248, Rec Loss: 17.8210, KL Div: 0.0406, Class Loss: 13.3632
# Epoch [10/50], Total Loss: 30.0344, Rec Loss: 17.7064, KL Div: 0.0343, Class Loss: 12.2938
# Epoch [11/50], Total Loss: 29.0908, Rec Loss: 17.6718, KL Div: 0.0309, Class Loss: 11.3881
# Epoch [12/50], Total Loss: 28.3151, Rec Loss: 17.7325, KL Div: 0.0280, Class Loss: 10.5546
# Epoch [13/50], Total Loss: 27.5056, Rec Loss: 17.7061, KL Div: 0.0287, Class Loss: 9.7708
# Epoch [14/50], Total Loss: 26.8789, Rec Loss: 17.6950, KL Div: 0.0276, Class Loss: 9.1563
# Epoch [15/50], Total Loss: 26.1429, Rec Loss: 17.6237, KL Div: 0.0299, Class Loss: 8.4893
# Epoch [16/50], Total Loss: 25.5813, Rec Loss: 17.6600, KL Div: 0.0286, Class Loss: 7.8927
# Epoch [17/50], Total Loss: 25.2963, Rec Loss: 17.6516, KL Div: 0.0245, Class Loss: 7.6202
# Epoch [18/50], Total Loss: 24.8189, Rec Loss: 17.6313, KL Div: 0.0260, Class Loss: 7.1616
# Epoch [19/50], Total Loss: 24.4850, Rec Loss: 17.6640, KL Div: 0.0248, Class Loss: 6.7963
# Epoch [20/50], Total Loss: 24.0429, Rec Loss: 17.6612, KL Div: 0.0247, Class Loss: 6.3570
# Epoch [21/50], Total Loss: 23.8027, Rec Loss: 17.6371, KL Div: 0.0252, Class Loss: 6.1404
# Epoch [22/50], Total Loss: 23.4037, Rec Loss: 17.6635, KL Div: 0.0249, Class Loss: 5.7152
# Epoch [23/50], Total Loss: 23.1311, Rec Loss: 17.6141, KL Div: 0.0232, Class Loss: 5.4939
# Epoch [24/50], Total Loss: 23.0758, Rec Loss: 17.6155, KL Div: 0.0261, Class Loss: 5.4342
# Epoch [25/50], Total Loss: 22.7528, Rec Loss: 17.6374, KL Div: 0.0219, Class Loss: 5.0936
# Epoch [26/50], Total Loss: 22.7229, Rec Loss: 17.7004, KL Div: 0.0238, Class Loss: 4.9988
# Epoch [27/50], Total Loss: 22.5904, Rec Loss: 17.6854, KL Div: 0.0209, Class Loss: 4.8841
# Epoch [28/50], Total Loss: 22.3008, Rec Loss: 17.5985, KL Div: 0.0216, Class Loss: 4.6808
# Epoch [29/50], Total Loss: 22.5470, Rec Loss: 17.6244, KL Div: 0.0232, Class Loss: 4.8993
# Epoch [30/50], Total Loss: 22.3187, Rec Loss: 17.6361, KL Div: 0.0204, Class Loss: 4.6622
# Epoch [31/50], Total Loss: 22.1874, Rec Loss: 17.6048, KL Div: 0.0187, Class Loss: 4.5638
# Epoch [32/50], Total Loss: 21.9951, Rec Loss: 17.6633, KL Div: 0.0232, Class Loss: 4.3086
# Epoch [33/50], Total Loss: 21.8863, Rec Loss: 17.6099, KL Div: 0.0199, Class Loss: 4.2566
# Epoch [34/50], Total Loss: 22.0428, Rec Loss: 17.6122, KL Div: 0.0192, Class Loss: 4.4114
# Epoch [35/50], Total Loss: 21.8178, Rec Loss: 17.5953, KL Div: 0.0174, Class Loss: 4.2051
# Epoch [36/50], Total Loss: 21.9043, Rec Loss: 17.5580, KL Div: 0.0197, Class Loss: 4.3266
# Epoch [37/50], Total Loss: 21.5453, Rec Loss: 17.5670, KL Div: 0.0172, Class Loss: 3.9611
# Epoch [38/50], Total Loss: 21.8643, Rec Loss: 17.5913, KL Div: 0.0187, Class Loss: 4.2543
# Epoch [39/50], Total Loss: 21.5750, Rec Loss: 17.5611, KL Div: 0.0161, Class Loss: 3.9977
# Epoch [40/50], Total Loss: 21.5866, Rec Loss: 17.5982, KL Div: 0.0149, Class Loss: 3.9735
# Epoch [41/50], Total Loss: 21.4862, Rec Loss: 17.6187, KL Div: 0.0166, Class Loss: 3.8509
# Epoch [42/50], Total Loss: 21.5840, Rec Loss: 17.5695, KL Div: 0.0193, Class Loss: 3.9952
# Epoch [43/50], Total Loss: 21.4388, Rec Loss: 17.5832, KL Div: 0.0162, Class Loss: 3.8394
# Epoch [44/50], Total Loss: 21.7366, Rec Loss: 17.6212, KL Div: 0.0157, Class Loss: 4.0996
# Epoch [45/50], Total Loss: 21.2584, Rec Loss: 17.6080, KL Div: 0.0181, Class Loss: 3.6324
# Epoch [46/50], Total Loss: 21.5242, Rec Loss: 17.5838, KL Div: 0.0180, Class Loss: 3.9224
# Epoch [47/50], Total Loss: 21.1821, Rec Loss: 17.5767, KL Div: 0.0155, Class Loss: 3.5899
# Epoch [48/50], Total Loss: 21.5410, Rec Loss: 17.6226, KL Div: 0.0139, Class Loss: 3.9046
# Epoch [49/50], Total Loss: 21.3932, Rec Loss: 17.6034, KL Div: 0.0135, Class Loss: 3.7763
# Epoch [50/50], Total Loss: 21.1952, Rec Loss: 17.5700, KL Div: 0.0168, Class Loss: 3.6085
# Time elapsed:  56.9285454750061
# Fold 1 Validation Loss: 0.0070, Validation Accuracy: 0.9979
# Fold 2/5
# Epoch [1/50], Total Loss: 161.4741, Rec Loss: 81.6743, KL Div: 0.9677, Class Loss: 78.8321
# Epoch [2/50], Total Loss: 48.6173, Rec Loss: 19.6296, KL Div: 0.2624, Class Loss: 28.7254
# Epoch [3/50], Total Loss: 44.1171, Rec Loss: 19.0903, KL Div: 0.2078, Class Loss: 24.8191
# Epoch [4/50], Total Loss: 40.9611, Rec Loss: 18.7492, KL Div: 0.1773, Class Loss: 22.0346
# Epoch [5/50], Total Loss: 38.1706, Rec Loss: 18.3011, KL Div: 0.1426, Class Loss: 19.7269
# Epoch [6/50], Total Loss: 36.0269, Rec Loss: 18.0335, KL Div: 0.1024, Class Loss: 17.8911
# Epoch [7/50], Total Loss: 34.1827, Rec Loss: 17.6998, KL Div: 0.0765, Class Loss: 16.4064
# Epoch [8/50], Total Loss: 32.7204, Rec Loss: 17.7013, KL Div: 0.0589, Class Loss: 14.9602
# Epoch [9/50], Total Loss: 31.3134, Rec Loss: 17.6548, KL Div: 0.0506, Class Loss: 13.6080
# Epoch [10/50], Total Loss: 30.1307, Rec Loss: 17.5122, KL Div: 0.0471, Class Loss: 12.5713
# Epoch [11/50], Total Loss: 29.1798, Rec Loss: 17.4647, KL Div: 0.0420, Class Loss: 11.6730
# Epoch [12/50], Total Loss: 28.3243, Rec Loss: 17.4573, KL Div: 0.0447, Class Loss: 10.8222
# Epoch [13/50], Total Loss: 27.3445, Rec Loss: 17.4602, KL Div: 0.0384, Class Loss: 9.8459
# Epoch [14/50], Total Loss: 26.4807, Rec Loss: 17.4341, KL Div: 0.0358, Class Loss: 9.0108
# Epoch [15/50], Total Loss: 25.8829, Rec Loss: 17.5007, KL Div: 0.0347, Class Loss: 8.3475
# Epoch [16/50], Total Loss: 25.0567, Rec Loss: 17.4927, KL Div: 0.0292, Class Loss: 7.5348
# Epoch [17/50], Total Loss: 24.5431, Rec Loss: 17.4866, KL Div: 0.0288, Class Loss: 7.0276
# Epoch [18/50], Total Loss: 23.8542, Rec Loss: 17.4638, KL Div: 0.0256, Class Loss: 6.3648
# Epoch [19/50], Total Loss: 23.4357, Rec Loss: 17.4889, KL Div: 0.0240, Class Loss: 5.9227
# Epoch [20/50], Total Loss: 23.2979, Rec Loss: 17.5061, KL Div: 0.0263, Class Loss: 5.7655
# Epoch [21/50], Total Loss: 22.8085, Rec Loss: 17.4548, KL Div: 0.0256, Class Loss: 5.3280
# Epoch [22/50], Total Loss: 22.7847, Rec Loss: 17.4091, KL Div: 0.0244, Class Loss: 5.3511
# Epoch [23/50], Total Loss: 22.3578, Rec Loss: 17.4147, KL Div: 0.0234, Class Loss: 4.9197
# Epoch [24/50], Total Loss: 22.1181, Rec Loss: 17.4852, KL Div: 0.0234, Class Loss: 4.6095
# Epoch [25/50], Total Loss: 22.2112, Rec Loss: 17.5230, KL Div: 0.0229, Class Loss: 4.6654
# Epoch [26/50], Total Loss: 21.9250, Rec Loss: 17.4689, KL Div: 0.0227, Class Loss: 4.4334
# Epoch [27/50], Total Loss: 21.7096, Rec Loss: 17.4582, KL Div: 0.0208, Class Loss: 4.2306
# Epoch [28/50], Total Loss: 21.6185, Rec Loss: 17.4012, KL Div: 0.0205, Class Loss: 4.1968
# Epoch [29/50], Total Loss: 21.7152, Rec Loss: 17.4539, KL Div: 0.0202, Class Loss: 4.2410
# Epoch [30/50], Total Loss: 21.4260, Rec Loss: 17.4528, KL Div: 0.0197, Class Loss: 3.9535
# Epoch [31/50], Total Loss: 21.5805, Rec Loss: 17.3877, KL Div: 0.0212, Class Loss: 4.1716
# Epoch [32/50], Total Loss: 21.6383, Rec Loss: 17.4396, KL Div: 0.0186, Class Loss: 4.1800
# Epoch [33/50], Total Loss: 21.4180, Rec Loss: 17.4166, KL Div: 0.0193, Class Loss: 3.9821
# Epoch [34/50], Total Loss: 21.2258, Rec Loss: 17.4129, KL Div: 0.0172, Class Loss: 3.7958
# Epoch [35/50], Total Loss: 21.2465, Rec Loss: 17.3921, KL Div: 0.0181, Class Loss: 3.8362
# Epoch [36/50], Total Loss: 21.2339, Rec Loss: 17.4337, KL Div: 0.0171, Class Loss: 3.7830
# Epoch [37/50], Total Loss: 21.1113, Rec Loss: 17.3973, KL Div: 0.0178, Class Loss: 3.6962
# Epoch [38/50], Total Loss: 21.0445, Rec Loss: 17.3973, KL Div: 0.0176, Class Loss: 3.6297
# Epoch [39/50], Total Loss: 21.3204, Rec Loss: 17.4341, KL Div: 0.0219, Class Loss: 3.8644
# Epoch [40/50], Total Loss: 21.1292, Rec Loss: 17.3963, KL Div: 0.0149, Class Loss: 3.7180
# Epoch [41/50], Total Loss: 20.9943, Rec Loss: 17.4054, KL Div: 0.0146, Class Loss: 3.5744
# Epoch [42/50], Total Loss: 21.2738, Rec Loss: 17.4272, KL Div: 0.0149, Class Loss: 3.8316
# Epoch [43/50], Total Loss: 20.8931, Rec Loss: 17.4253, KL Div: 0.0141, Class Loss: 3.4536
# Epoch [44/50], Total Loss: 20.9046, Rec Loss: 17.4379, KL Div: 0.0150, Class Loss: 3.4517
# Epoch [45/50], Total Loss: 20.9286, Rec Loss: 17.4361, KL Div: 0.0149, Class Loss: 3.4775
# Epoch [46/50], Total Loss: 20.9779, Rec Loss: 17.4792, KL Div: 0.0181, Class Loss: 3.4806
# Epoch [47/50], Total Loss: 20.9687, Rec Loss: 17.4331, KL Div: 0.0126, Class Loss: 3.5230
# Epoch [48/50], Total Loss: 20.8220, Rec Loss: 17.4342, KL Div: 0.0116, Class Loss: 3.3762
# Epoch [49/50], Total Loss: 20.9149, Rec Loss: 17.3755, KL Div: 0.0132, Class Loss: 3.5261
# Epoch [50/50], Total Loss: 20.7609, Rec Loss: 17.4274, KL Div: 0.0133, Class Loss: 3.3202
# Time elapsed:  58.48068642616272
# Fold 2 Validation Loss: 0.0121, Validation Accuracy: 0.9961
# Fold 3/5
# Epoch [1/50], Total Loss: 154.3879, Rec Loss: 75.4844, KL Div: 1.0043, Class Loss: 77.8991
# Epoch [2/50], Total Loss: 48.6252, Rec Loss: 19.6750, KL Div: 0.2376, Class Loss: 28.7126
# Epoch [3/50], Total Loss: 44.4747, Rec Loss: 18.9402, KL Div: 0.1840, Class Loss: 25.3505
# Epoch [4/50], Total Loss: 41.3425, Rec Loss: 18.5636, KL Div: 0.1580, Class Loss: 22.6209
# Epoch [5/50], Total Loss: 38.7145, Rec Loss: 18.1604, KL Div: 0.1137, Class Loss: 20.4403
# Epoch [6/50], Total Loss: 36.4230, Rec Loss: 17.8954, KL Div: 0.0784, Class Loss: 18.4492
# Epoch [7/50], Total Loss: 34.4695, Rec Loss: 17.7611, KL Div: 0.0671, Class Loss: 16.6414
# Epoch [8/50], Total Loss: 32.8537, Rec Loss: 17.6558, KL Div: 0.0554, Class Loss: 15.1425
# Epoch [9/50], Total Loss: 31.5399, Rec Loss: 17.6255, KL Div: 0.0482, Class Loss: 13.8662
# Epoch [10/50], Total Loss: 30.2973, Rec Loss: 17.6869, KL Div: 0.0420, Class Loss: 12.5684
# Epoch [11/50], Total Loss: 28.9939, Rec Loss: 17.5941, KL Div: 0.0405, Class Loss: 11.3593
# Epoch [12/50], Total Loss: 27.8283, Rec Loss: 17.5654, KL Div: 0.0320, Class Loss: 10.2308
# Epoch [13/50], Total Loss: 27.0944, Rec Loss: 17.5401, KL Div: 0.0309, Class Loss: 9.5234
# Epoch [14/50], Total Loss: 25.9666, Rec Loss: 17.5390, KL Div: 0.0272, Class Loss: 8.4004
# Epoch [15/50], Total Loss: 25.0892, Rec Loss: 17.5072, KL Div: 0.0256, Class Loss: 7.5563
# Epoch [16/50], Total Loss: 24.6517, Rec Loss: 17.4984, KL Div: 0.0250, Class Loss: 7.1284
# Epoch [17/50], Total Loss: 24.1322, Rec Loss: 17.5076, KL Div: 0.0237, Class Loss: 6.6008
# Epoch [18/50], Total Loss: 23.5702, Rec Loss: 17.5117, KL Div: 0.0234, Class Loss: 6.0351
# Epoch [19/50], Total Loss: 23.3127, Rec Loss: 17.5799, KL Div: 0.0196, Class Loss: 5.7132
# Epoch [20/50], Total Loss: 22.9760, Rec Loss: 17.5911, KL Div: 0.0195, Class Loss: 5.3654
# Epoch [21/50], Total Loss: 22.6918, Rec Loss: 17.5851, KL Div: 0.0199, Class Loss: 5.0869
# Epoch [22/50], Total Loss: 22.5004, Rec Loss: 17.4573, KL Div: 0.0226, Class Loss: 5.0205
# Epoch [23/50], Total Loss: 22.1792, Rec Loss: 17.5255, KL Div: 0.0202, Class Loss: 4.6334
# Epoch [24/50], Total Loss: 22.0975, Rec Loss: 17.5777, KL Div: 0.0195, Class Loss: 4.5002
# Epoch [25/50], Total Loss: 21.9345, Rec Loss: 17.5579, KL Div: 0.0188, Class Loss: 4.3578
# Epoch [26/50], Total Loss: 21.7267, Rec Loss: 17.4907, KL Div: 0.0208, Class Loss: 4.2153
# Epoch [27/50], Total Loss: 21.5397, Rec Loss: 17.5132, KL Div: 0.0175, Class Loss: 4.0090
# Epoch [28/50], Total Loss: 21.6473, Rec Loss: 17.4958, KL Div: 0.0173, Class Loss: 4.1342
# Epoch [29/50], Total Loss: 21.5049, Rec Loss: 17.4819, KL Div: 0.0187, Class Loss: 4.0044
# Epoch [30/50], Total Loss: 21.4317, Rec Loss: 17.5334, KL Div: 0.0168, Class Loss: 3.8815
# Epoch [31/50], Total Loss: 21.4960, Rec Loss: 17.5467, KL Div: 0.0153, Class Loss: 3.9341
# Epoch [32/50], Total Loss: 21.4327, Rec Loss: 17.5413, KL Div: 0.0172, Class Loss: 3.8741
# Epoch [33/50], Total Loss: 21.2721, Rec Loss: 17.4814, KL Div: 0.0183, Class Loss: 3.7724
# Epoch [34/50], Total Loss: 21.0595, Rec Loss: 17.4744, KL Div: 0.0154, Class Loss: 3.5696
# Epoch [35/50], Total Loss: 21.2256, Rec Loss: 17.4797, KL Div: 0.0134, Class Loss: 3.7324
# Epoch [36/50], Total Loss: 21.2090, Rec Loss: 17.5136, KL Div: 0.0149, Class Loss: 3.6806
# Epoch [37/50], Total Loss: 21.2773, Rec Loss: 17.5277, KL Div: 0.0157, Class Loss: 3.7340
# Epoch [38/50], Total Loss: 21.0077, Rec Loss: 17.5253, KL Div: 0.0154, Class Loss: 3.4669
# Epoch [39/50], Total Loss: 21.3736, Rec Loss: 17.5311, KL Div: 0.0153, Class Loss: 3.8272
# Epoch [40/50], Total Loss: 21.2117, Rec Loss: 17.4963, KL Div: 0.0144, Class Loss: 3.7009
# Epoch [41/50], Total Loss: 20.8796, Rec Loss: 17.4405, KL Div: 0.0147, Class Loss: 3.4245
# Epoch [42/50], Total Loss: 20.9430, Rec Loss: 17.4724, KL Div: 0.0161, Class Loss: 3.4545
# Epoch [43/50], Total Loss: 20.8983, Rec Loss: 17.5168, KL Div: 0.0144, Class Loss: 3.3670
# Epoch [44/50], Total Loss: 20.9033, Rec Loss: 17.4616, KL Div: 0.0158, Class Loss: 3.4259
# Epoch [45/50], Total Loss: 20.9414, Rec Loss: 17.4933, KL Div: 0.0139, Class Loss: 3.4342
# Epoch [46/50], Total Loss: 20.9349, Rec Loss: 17.4602, KL Div: 0.0135, Class Loss: 3.4612
# Epoch [47/50], Total Loss: 20.6721, Rec Loss: 17.4539, KL Div: 0.0124, Class Loss: 3.2058
# Epoch [48/50], Total Loss: 20.6680, Rec Loss: 17.4443, KL Div: 0.0129, Class Loss: 3.2107
# Epoch [49/50], Total Loss: 20.6822, Rec Loss: 17.4489, KL Div: 0.0130, Class Loss: 3.2203
# Epoch [50/50], Total Loss: 20.6245, Rec Loss: 17.5021, KL Div: 0.0125, Class Loss: 3.1098
# Time elapsed:  61.30239963531494
# Fold 3 Validation Loss: 0.0135, Validation Accuracy: 0.9968
# Fold 4/5
# Epoch [1/50], Total Loss: 162.9012, Rec Loss: 82.1132, KL Div: 0.7168, Class Loss: 80.0712
# Epoch [2/50], Total Loss: 47.6572, Rec Loss: 19.6095, KL Div: 0.2323, Class Loss: 27.8154
# Epoch [3/50], Total Loss: 43.9793, Rec Loss: 19.2742, KL Div: 0.2032, Class Loss: 24.5019
# Epoch [4/50], Total Loss: 40.7443, Rec Loss: 18.6550, KL Div: 0.1812, Class Loss: 21.9081
# Epoch [5/50], Total Loss: 38.0020, Rec Loss: 18.3103, KL Div: 0.1418, Class Loss: 19.5498
# Epoch [6/50], Total Loss: 35.8546, Rec Loss: 17.9829, KL Div: 0.0957, Class Loss: 17.7760
# Epoch [7/50], Total Loss: 33.6462, Rec Loss: 17.7511, KL Div: 0.0692, Class Loss: 15.8259
# Epoch [8/50], Total Loss: 31.9495, Rec Loss: 17.6336, KL Div: 0.0574, Class Loss: 14.2586
# Epoch [9/50], Total Loss: 30.3353, Rec Loss: 17.5566, KL Div: 0.0463, Class Loss: 12.7323
# Epoch [10/50], Total Loss: 29.1253, Rec Loss: 17.5665, KL Div: 0.0405, Class Loss: 11.5183
# Epoch [11/50], Total Loss: 27.7846, Rec Loss: 17.5551, KL Div: 0.0322, Class Loss: 10.1973
# Epoch [12/50], Total Loss: 26.4991, Rec Loss: 17.5045, KL Div: 0.0280, Class Loss: 8.9666
# Epoch [13/50], Total Loss: 25.8133, Rec Loss: 17.4894, KL Div: 0.0249, Class Loss: 8.2990
# Epoch [14/50], Total Loss: 25.0231, Rec Loss: 17.4941, KL Div: 0.0255, Class Loss: 7.5036
# Epoch [15/50], Total Loss: 24.5747, Rec Loss: 17.4998, KL Div: 0.0239, Class Loss: 7.0511
# Epoch [16/50], Total Loss: 23.8301, Rec Loss: 17.4661, KL Div: 0.0221, Class Loss: 6.3418
# Epoch [17/50], Total Loss: 23.5973, Rec Loss: 17.4749, KL Div: 0.0216, Class Loss: 6.1008
# Epoch [18/50], Total Loss: 23.3232, Rec Loss: 17.4752, KL Div: 0.0235, Class Loss: 5.8245
# Epoch [19/50], Total Loss: 22.9350, Rec Loss: 17.4732, KL Div: 0.0218, Class Loss: 5.4400
# Epoch [20/50], Total Loss: 22.6431, Rec Loss: 17.4790, KL Div: 0.0207, Class Loss: 5.1435
# Epoch [21/50], Total Loss: 22.4155, Rec Loss: 17.4914, KL Div: 0.0182, Class Loss: 4.9058
# Epoch [22/50], Total Loss: 22.1091, Rec Loss: 17.4803, KL Div: 0.0184, Class Loss: 4.6103
# Epoch [23/50], Total Loss: 22.0368, Rec Loss: 17.4310, KL Div: 0.0202, Class Loss: 4.5856
# Epoch [24/50], Total Loss: 21.9828, Rec Loss: 17.4649, KL Div: 0.0183, Class Loss: 4.4996
# Epoch [25/50], Total Loss: 21.6056, Rec Loss: 17.4271, KL Div: 0.0191, Class Loss: 4.1594
# Epoch [26/50], Total Loss: 21.8648, Rec Loss: 17.5635, KL Div: 0.0193, Class Loss: 4.2820
# Epoch [27/50], Total Loss: 21.5268, Rec Loss: 17.4421, KL Div: 0.0213, Class Loss: 4.0634
# Epoch [28/50], Total Loss: 21.6204, Rec Loss: 17.4793, KL Div: 0.0175, Class Loss: 4.1236
# Epoch [29/50], Total Loss: 21.6884, Rec Loss: 17.4026, KL Div: 0.0190, Class Loss: 4.2668
# Epoch [30/50], Total Loss: 21.3943, Rec Loss: 17.4536, KL Div: 0.0158, Class Loss: 3.9250
# Epoch [31/50], Total Loss: 21.4093, Rec Loss: 17.4465, KL Div: 0.0169, Class Loss: 3.9459
# Epoch [32/50], Total Loss: 21.2309, Rec Loss: 17.4263, KL Div: 0.0187, Class Loss: 3.7860
# Epoch [33/50], Total Loss: 21.3321, Rec Loss: 17.4785, KL Div: 0.0185, Class Loss: 3.8351
# Epoch [34/50], Total Loss: 21.1440, Rec Loss: 17.4511, KL Div: 0.0174, Class Loss: 3.6756
# Epoch [35/50], Total Loss: 21.2822, Rec Loss: 17.4522, KL Div: 0.0178, Class Loss: 3.8123
# Epoch [36/50], Total Loss: 21.1028, Rec Loss: 17.4499, KL Div: 0.0163, Class Loss: 3.6366
# Epoch [37/50], Total Loss: 21.0524, Rec Loss: 17.4607, KL Div: 0.0182, Class Loss: 3.5735
# Epoch [38/50], Total Loss: 21.0999, Rec Loss: 17.4270, KL Div: 0.0189, Class Loss: 3.6540
# Epoch [39/50], Total Loss: 20.9626, Rec Loss: 17.4152, KL Div: 0.0164, Class Loss: 3.5310
# Epoch [40/50], Total Loss: 21.2083, Rec Loss: 17.4275, KL Div: 0.0169, Class Loss: 3.7639
# Epoch [41/50], Total Loss: 21.0271, Rec Loss: 17.4364, KL Div: 0.0147, Class Loss: 3.5760
# Epoch [42/50], Total Loss: 20.9567, Rec Loss: 17.4327, KL Div: 0.0155, Class Loss: 3.5086
# Epoch [43/50], Total Loss: 21.2198, Rec Loss: 17.4085, KL Div: 0.0162, Class Loss: 3.7952
# Epoch [44/50], Total Loss: 21.1574, Rec Loss: 17.5743, KL Div: 0.0157, Class Loss: 3.5673
# Epoch [45/50], Total Loss: 20.8892, Rec Loss: 17.3968, KL Div: 0.0166, Class Loss: 3.4757
# Epoch [46/50], Total Loss: 20.8722, Rec Loss: 17.5021, KL Div: 0.0148, Class Loss: 3.3553
# Epoch [47/50], Total Loss: 20.9035, Rec Loss: 17.4803, KL Div: 0.0145, Class Loss: 3.4086
# Epoch [48/50], Total Loss: 20.8275, Rec Loss: 17.4717, KL Div: 0.0152, Class Loss: 3.3406
# Epoch [49/50], Total Loss: 21.0244, Rec Loss: 17.4600, KL Div: 0.0154, Class Loss: 3.5490
# Epoch [50/50], Total Loss: 20.7662, Rec Loss: 17.4074, KL Div: 0.0151, Class Loss: 3.3437
# Time elapsed:  57.71827840805054
# Fold 4 Validation Loss: 0.0110, Validation Accuracy: 0.9967
# Fold 5/5
# Epoch [1/50], Total Loss: 175.6638, Rec Loss: 84.8424, KL Div: 0.8362, Class Loss: 89.9852
# Epoch [2/50], Total Loss: 48.3973, Rec Loss: 19.4783, KL Div: 0.2376, Class Loss: 28.6815
# Epoch [3/50], Total Loss: 43.6798, Rec Loss: 18.8624, KL Div: 0.1922, Class Loss: 24.6252
# Epoch [4/50], Total Loss: 40.2610, Rec Loss: 18.3117, KL Div: 0.1749, Class Loss: 21.7744
# Epoch [5/50], Total Loss: 37.7832, Rec Loss: 18.0011, KL Div: 0.1374, Class Loss: 19.6447
# Epoch [6/50], Total Loss: 35.7300, Rec Loss: 17.6944, KL Div: 0.1044, Class Loss: 17.9311
# Epoch [7/50], Total Loss: 34.0793, Rec Loss: 17.4473, KL Div: 0.0809, Class Loss: 16.5510
# Epoch [8/50], Total Loss: 32.7072, Rec Loss: 17.4150, KL Div: 0.0579, Class Loss: 15.2343
# Epoch [9/50], Total Loss: 31.3782, Rec Loss: 17.3645, KL Div: 0.0495, Class Loss: 13.9641
# Epoch [10/50], Total Loss: 30.3125, Rec Loss: 17.2726, KL Div: 0.0418, Class Loss: 12.9981
# Epoch [11/50], Total Loss: 29.2070, Rec Loss: 17.2923, KL Div: 0.0421, Class Loss: 11.8726
# Epoch [12/50], Total Loss: 28.1606, Rec Loss: 17.3611, KL Div: 0.0440, Class Loss: 10.7555
# Epoch [13/50], Total Loss: 27.2631, Rec Loss: 17.1762, KL Div: 0.0392, Class Loss: 10.0478
# Epoch [14/50], Total Loss: 26.6339, Rec Loss: 17.2829, KL Div: 0.0395, Class Loss: 9.3116
# Epoch [15/50], Total Loss: 25.9313, Rec Loss: 17.2821, KL Div: 0.0406, Class Loss: 8.6086
# Epoch [16/50], Total Loss: 25.2847, Rec Loss: 17.2476, KL Div: 0.0381, Class Loss: 7.9990
# Epoch [17/50], Total Loss: 24.3663, Rec Loss: 17.2084, KL Div: 0.0367, Class Loss: 7.1212
# Epoch [18/50], Total Loss: 23.9643, Rec Loss: 17.1999, KL Div: 0.0339, Class Loss: 6.7305
# Epoch [19/50], Total Loss: 23.5748, Rec Loss: 17.2023, KL Div: 0.0352, Class Loss: 6.3372
# Epoch [20/50], Total Loss: 23.2769, Rec Loss: 17.2187, KL Div: 0.0323, Class Loss: 6.0260
# Epoch [21/50], Total Loss: 22.9409, Rec Loss: 17.2021, KL Div: 0.0356, Class Loss: 5.7032
# Epoch [22/50], Total Loss: 22.5157, Rec Loss: 17.2210, KL Div: 0.0287, Class Loss: 5.2659
# Epoch [23/50], Total Loss: 22.2108, Rec Loss: 17.2288, KL Div: 0.0260, Class Loss: 4.9560
# Epoch [24/50], Total Loss: 22.0402, Rec Loss: 17.1487, KL Div: 0.0269, Class Loss: 4.8646
# Epoch [25/50], Total Loss: 21.9294, Rec Loss: 17.2219, KL Div: 0.0259, Class Loss: 4.6816
# Epoch [26/50], Total Loss: 21.7472, Rec Loss: 17.1964, KL Div: 0.0236, Class Loss: 4.5272
# Epoch [27/50], Total Loss: 21.8455, Rec Loss: 17.2548, KL Div: 0.0269, Class Loss: 4.5637
# Epoch [28/50], Total Loss: 21.5857, Rec Loss: 17.1532, KL Div: 0.0258, Class Loss: 4.4067
# Epoch [29/50], Total Loss: 21.5705, Rec Loss: 17.2318, KL Div: 0.0264, Class Loss: 4.3122
# Epoch [30/50], Total Loss: 21.5296, Rec Loss: 17.1948, KL Div: 0.0218, Class Loss: 4.3131
# Epoch [31/50], Total Loss: 21.5750, Rec Loss: 17.2522, KL Div: 0.0234, Class Loss: 4.2993
# Epoch [32/50], Total Loss: 21.2512, Rec Loss: 17.1790, KL Div: 0.0208, Class Loss: 4.0514
# Epoch [33/50], Total Loss: 21.1407, Rec Loss: 17.1911, KL Div: 0.0273, Class Loss: 3.9223
# Epoch [34/50], Total Loss: 21.2856, Rec Loss: 17.1983, KL Div: 0.0209, Class Loss: 4.0665
# Epoch [35/50], Total Loss: 20.9391, Rec Loss: 17.1838, KL Div: 0.0199, Class Loss: 3.7354
# Epoch [36/50], Total Loss: 21.2892, Rec Loss: 17.1506, KL Div: 0.0181, Class Loss: 4.1205
# Epoch [37/50], Total Loss: 21.3764, Rec Loss: 17.1871, KL Div: 0.0181, Class Loss: 4.1712
# Epoch [38/50], Total Loss: 20.9323, Rec Loss: 17.1791, KL Div: 0.0186, Class Loss: 3.7346
# Epoch [39/50], Total Loss: 21.1116, Rec Loss: 17.2543, KL Div: 0.0229, Class Loss: 3.8344
# Epoch [40/50], Total Loss: 21.0375, Rec Loss: 17.2490, KL Div: 0.0182, Class Loss: 3.7704
# Epoch [41/50], Total Loss: 20.9694, Rec Loss: 17.1607, KL Div: 0.0238, Class Loss: 3.7849
# Epoch [42/50], Total Loss: 20.9409, Rec Loss: 17.1521, KL Div: 0.0159, Class Loss: 3.7730
# Epoch [43/50], Total Loss: 20.7123, Rec Loss: 17.1449, KL Div: 0.0161, Class Loss: 3.5513
# Epoch [44/50], Total Loss: 20.7708, Rec Loss: 17.1380, KL Div: 0.0181, Class Loss: 3.6147
# Epoch [45/50], Total Loss: 20.8253, Rec Loss: 17.1427, KL Div: 0.0186, Class Loss: 3.6640
# Epoch [46/50], Total Loss: 20.9724, Rec Loss: 17.1339, KL Div: 0.0156, Class Loss: 3.8230
# Epoch [47/50], Total Loss: 20.9435, Rec Loss: 17.1573, KL Div: 0.0184, Class Loss: 3.7679
# Epoch [48/50], Total Loss: 20.8746, Rec Loss: 17.1692, KL Div: 0.0168, Class Loss: 3.6886
# Epoch [49/50], Total Loss: 20.6822, Rec Loss: 17.1167, KL Div: 0.0192, Class Loss: 3.5463
# Epoch [50/50], Total Loss: 20.7800, Rec Loss: 17.1819, KL Div: 0.0230, Class Loss: 3.5751
# Time elapsed:  56.11078906059265
# Fold 5 Validation Loss: 0.0105, Validation Accuracy: 0.9967

# %%
def plot_training_loss(model_name, save_dir):
    training_traj = np.load(save_dir+model_name+"_training_loss.npz")

    total_loss = training_traj['training_total_loss']
    rec_loss = training_traj['training_rec_loss']
    kl_loss = training_traj['training_kl_loss']
    plt.figure(figsize=(15, 4))
    plt.subplot(1, 3, 1)
    plt.title("Total Loss", fontsize=12)
    plt.plot(range(len(total_loss)), total_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(1, 3, 2)
    plt.title("Reconstruction Loss", fontsize=12)
    plt.plot(range(len(total_loss)), rec_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.xlabel("Epochs of training", fontsize=12)
    plt.subplot(1, 3, 3)
    plt.title("KL Loss", fontsize=12)
    plt.plot(range(len(total_loss)), kl_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
#plot_training_loss(model_name, save_dir)

# %% [markdown]
# # Initialize 3 new models for fine-tuning

# %%
# Deserialize the model from the buffer
buffer.seek(0)  # Reset buffer pointer to the beginning
model_medium = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_medium.load_state_dict(torch.load(buffer))
model_medium = model_medium.to(device)

buffer.seek(0)  # Reset buffer pointer to the beginning
model_strong = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_strong.load_state_dict(torch.load(buffer))
model_strong = model_strong.to(device)
buffer.seek(0)  # Reset buffer pointer to the beginPrecision = 100.0%, recall = 0.41% and F1-score = 0.81%ing
model_random = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_random.load_state_dict(torch.load(buffer))
model_random = model_random.to(device)

# %% [markdown]
# # Verify the 3 new models

# %%
# Initialize a flag
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Initialize a flag
models_identical = True
original_state_dict = model_random.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Initialize a flag
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_strong.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Out:
# The saved and loaded models are identical.
# The saved and loaded models are identical.
# The saved and loaded models are identical.

# %% [markdown]
# # Evaluate the Model and Detect Anomalies

# %%
def compute_anomaly_scores(model, data_loader):
    model.eval()
    rec_errors = []
    anomaly_probs = []
    true_labels = []
    predictions = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.unsqueeze(1).to(device)
            y_batch = y_batch.to(device)

            x_rec, class_logits = model(X_batch)
            y_probs = F.softmax(class_logits, dim=1)

            # Reconstruction error
            rec_error = torch.mean((X_batch - x_rec) ** 2, dim=[1, 2])

            # Classification probability for anomaly class
            anomaly_prob = y_probs[:, 1]

            # Combine scores
            #anomaly_score = rec_error * anomaly_prob
            rec_errors.extend(rec_error.cpu().numpy())
            anomaly_probs.extend(anomaly_prob.cpu().numpy())
            true_labels.extend(y_batch.cpu().numpy())
            predictions.extend(torch.argmax(class_logits, dim=1).cpu().numpy())

    return np.array(rec_errors), np.array(anomaly_probs), np.array(true_labels), np.array(predictions)

# Compute anomaly scores
train_rec_errors, train_anomaly_probs, train_true_labels, train_predictions = compute_anomaly_scores(model, train_loader)
val_rec_errors, val_anomaly_probs, val_true_labels, val_predictions = compute_anomaly_scores(model, val_loader)
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model, test_loader)

#print(test_anomaly_scores)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 95.13%, recall = 80.37% and F1-score = 87.13%

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_anomaly_probs)), val_anomaly_probs, alpha=0.7, c=(val_true_labels!=val_predictions), cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(val_rec_errors, val_anomaly_probs, alpha=0.7, c=(val_true_labels==val_predictions), cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores with Reconstruction Errors")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(val_anomaly_probs, vert=False)
plt.title("Box Plot of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.show()

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(val_anomaly_probs, bins=20, alpha=0.7, edgecolor='black')
plt.title("Histogram of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_true_labels, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (true labels)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_predictions, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (predictions)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_anomaly_probs, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (anomalous probability)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(val_rec_errors, vert=False)
plt.title("Box Plot of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.show()

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(val_rec_errors, bins=20, alpha=0.7, edgecolor='black')
plt.title("Histogram of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Retrain

# %%
# Determine thresholds
#lower_percentile = 62.5
#upper_percentile = 37.5
#lower_threshold = np.percentile(val_anomaly_probs, lower_percentile)
#upper_threshold = np.percentile(val_anomaly_probs, upper_percentile)


# Select medium-score data
medium_score_indices = np.where((val_anomaly_probs >= 0.05) & (val_anomaly_probs <= 0.95))[0]
X_medium = X_val[medium_score_indices]
y_medium = y_val[medium_score_indices]
print("Medium-score data shape:", X_medium.shape, y_medium.shape)
X_medium_tensor = torch.tensor(X_medium).float()
y_medium_tensor = torch.tensor(y_medium).long()
# data loader
medium_dataset = TimeSeriesDataset(X_medium_tensor, y_medium_tensor)
medium_loader = DataLoader(medium_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Medium-score data shape: (185, 10) (185,)

# %%
# Determine thresholds
#lower_percentile = 12.5
#upper_percentile = 87.5
#lower_threshold = np.percentile(val_anomaly_probs, lower_percentile)
#upper_threshold = np.percentile(val_anomaly_probs, upper_percentile)

# Select strong-score data
strong_score_indices = np.where((val_anomaly_probs <= 0.01) | (val_anomaly_probs >= 0.99))[0]
X_strong = X_val[strong_score_indices]
y_strong = y_val[strong_score_indices]
print("Strong-score data shape:", X_strong.shape, y_strong.shape)
X_strong_tensor = torch.tensor(X_strong).float()
y_strong_tensor = torch.tensor(y_strong).long()
# data loader
strong_dataset = TimeSeriesDataset(X_strong_tensor, y_strong_tensor)
strong_loader = DataLoader(strong_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Strong-score data shape: (27873, 10) (27873,)

# %%
# Optional: Set a random seed for reproducibility
np.random.seed(42)

# Define the fraction of data to select
sample_fraction = 0.25
total_samples = len(val_anomaly_probs)
sample_size = int(sample_fraction * total_samples)

# Randomly select unique indices without replacement
random_score_indices = np.random.choice(total_samples, size=sample_size, replace=False)

# Select the corresponding data and labels
X_random = X_val[random_score_indices]
y_random = y_val[random_score_indices]
print("Random data shape:", X_random.shape, y_random.shape)
# Convert to PyTorch tensors
X_random_tensor = torch.tensor(X_random).float()
y_random_tensor = torch.tensor(y_random).long()

# Create the dataset and data loader
random_dataset = TimeSeriesDataset(X_random_tensor, y_random_tensor)
random_loader = DataLoader(random_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Random data shape: (7104, 10) (7104,)

# %%
# FInetune the model
model_name = "model_medium"
optimizer = optim.Adam(model_medium.parameters(), lr=finetune_learning_rate)
#optimizer = optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-7)
model_medium = train_model(model_medium, optimizer, medium_loader, num_epochs=finetune_num_epochs, model_name=
                           model_name, save_dir=save_dir, save=True)
plot_training_loss(model_name, save_dir)
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Out:
# Epoch [1/5], Total Loss: 1.8071, Rec Loss: 0.0983, KL Div: 0.0002, Class Loss: 1.7086
# Epoch [2/5], Total Loss: 1.7261, Rec Loss: 0.0929, KL Div: 0.0002, Class Loss: 1.6330
# Epoch [3/5], Total Loss: 1.6739, Rec Loss: 0.0902, KL Div: 0.0002, Class Loss: 1.5834
# Epoch [4/5], Total Loss: 1.6430, Rec Loss: 0.0885, KL Div: 0.0002, Class Loss: 1.5543
# Epoch [5/5], Total Loss: 1.6234, Rec Loss: 0.0842, KL Div: 0.0002, Class Loss: 1.5391
# Time elapsed:  0.06617903709411621
# Mismatch found at layer: encoder.fc_layers.0.weight
# The models are not identical.

# %%
optimizer = optim.Adam(model_strong.parameters(), lr=finetune_learning_rate)
model_name = "model_strong"
model_strong = train_model(model_strong, optimizer, strong_loader, num_epochs=finetune_num_epochs, model_name=model_name)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/5], Total Loss: 23.0048, Rec Loss: 21.2892, KL Div: 0.0104, Class Loss: 1.7052
# Epoch [2/5], Total Loss: 22.9164, Rec Loss: 21.2813, KL Div: 0.0083, Class Loss: 1.6269
# Epoch [3/5], Total Loss: 22.8979, Rec Loss: 21.2876, KL Div: 0.0074, Class Loss: 1.6029
# Epoch [4/5], Total Loss: 22.8446, Rec Loss: 21.2459, KL Div: 0.0070, Class Loss: 1.5917
# Epoch [5/5], Total Loss: 22.8457, Rec Loss: 21.2536, KL Div: 0.0067, Class Loss: 1.5854
# Time elapsed:  5.870558500289917

# %%
model_name = "model_random"
optimizer = optim.Adam(model_random.parameters(), lr=finetune_learning_rate)
model_random = train_model(model_random, optimizer, random_loader, num_epochs=finetune_num_epochs, model_name=model_name)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/5], Total Loss: 6.8305, Rec Loss: 5.5440, KL Div: 0.0035, Class Loss: 1.2831
# Epoch [2/5], Total Loss: 6.7431, Rec Loss: 5.5385, KL Div: 0.0033, Class Loss: 1.2012
# Epoch [3/5], Total Loss: 6.7125, Rec Loss: 5.5342, KL Div: 0.0030, Class Loss: 1.1753
# Epoch [4/5], Total Loss: 6.7016, Rec Loss: 5.5424, KL Div: 0.0029, Class Loss: 1.1563
# Epoch [5/5], Total Loss: 6.6838, Rec Loss: 5.5388, KL Div: 0.0028, Class Loss: 1.1422
# Time elapsed:  1.2193639278411865

# %%
# Combine data
expanded_medium_data = np.concatenate((X_train, X_medium), axis=0)
expanded_medium_labels = np.concatenate((y_train, y_medium), axis=0)
X_expanded_medium_tensor = torch.tensor(expanded_medium_data).float()
y_expanded_medium_tensor = torch.tensor(expanded_medium_labels).long()
# Create new dataset and loader
expanded_medium_dataset = TimeSeriesDataset(X_expanded_medium_tensor, y_expanded_medium_tensor)
expanded_medium_loader = DataLoader(expanded_medium_dataset, batch_size=batch_size, shuffle=False)
model2_medium = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)

# Define optimizer
model_name = "model2_medium"
optimizer = optim.Adam(model2_medium.parameters(), lr=train_learning_rate)
model2_medium = train_model(model2_medium, optimizer, expanded_medium_loader, num_epochs=train_num_epochs, model_name=model_name)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/50], Total Loss: 184.6929, Rec Loss: 90.0851, KL Div: 1.7436, Class Loss: 92.8642
# Epoch [2/50], Total Loss: 64.9301, Rec Loss: 24.1896, KL Div: 0.3049, Class Loss: 40.4356
# Epoch [3/50], Total Loss: 59.7825, Rec Loss: 23.6652, KL Div: 0.2465, Class Loss: 35.8708
# Epoch [4/50], Total Loss: 55.7556, Rec Loss: 23.0082, KL Div: 0.1922, Class Loss: 32.5552
# Epoch [5/50], Total Loss: 52.7095, Rec Loss: 22.5367, KL Div: 0.1317, Class Loss: 30.0412
# Epoch [6/50], Total Loss: 50.3894, Rec Loss: 22.2248, KL Div: 0.0967, Class Loss: 28.0679
# Epoch [7/50], Total Loss: 48.5054, Rec Loss: 22.1003, KL Div: 0.0764, Class Loss: 26.3287
# Epoch [8/50], Total Loss: 46.8241, Rec Loss: 22.0337, KL Div: 0.0590, Class Loss: 24.7314
# Epoch [9/50], Total Loss: 45.2437, Rec Loss: 21.9749, KL Div: 0.0472, Class Loss: 23.2215
# Epoch [10/50], Total Loss: 43.7969, Rec Loss: 21.9622, KL Div: 0.0428, Class Loss: 21.7919
# Epoch [11/50], Total Loss: 42.4364, Rec Loss: 21.9587, KL Div: 0.0399, Class Loss: 20.4378
# Epoch [12/50], Total Loss: 41.1044, Rec Loss: 21.9161, KL Div: 0.0359, Class Loss: 19.1525
# Epoch [13/50], Total Loss: 39.8944, Rec Loss: 21.9246, KL Div: 0.0335, Class Loss: 17.9362
# Epoch [14/50], Total Loss: 38.7266, Rec Loss: 21.9295, KL Div: 0.0312, Class Loss: 16.7659
# Epoch [15/50], Total Loss: 37.5946, Rec Loss: 21.9043, KL Div: 0.0296, Class Loss: 15.6606
# Epoch [16/50], Total Loss: 36.5179, Rec Loss: 21.8866, KL Div: 0.0284, Class Loss: 14.6028
# Epoch [17/50], Total Loss: 35.6031, Rec Loss: 21.9280, KL Div: 0.0283, Class Loss: 13.6468
# Epoch [18/50], Total Loss: 34.6747, Rec Loss: 21.8850, KL Div: 0.0272, Class Loss: 12.7626
# Epoch [19/50], Total Loss: 33.8313, Rec Loss: 21.8743, KL Div: 0.0274, Class Loss: 11.9296
# Epoch [20/50], Total Loss: 33.1325, Rec Loss: 21.8808, KL Div: 0.0276, Class Loss: 11.2241
# Epoch [21/50], Total Loss: 32.3989, Rec Loss: 21.8898, KL Div: 0.0287, Class Loss: 10.4804
# Epoch [22/50], Total Loss: 31.8392, Rec Loss: 21.8897, KL Div: 0.0268, Class Loss: 9.9227
# Epoch [23/50], Total Loss: 31.2654, Rec Loss: 21.8739, KL Div: 0.0277, Class Loss: 9.3638
# Epoch [24/50], Total Loss: 30.8088, Rec Loss: 21.8763, KL Div: 0.0285, Class Loss: 8.9040
# Epoch [25/50], Total Loss: 30.3783, Rec Loss: 21.8613, KL Div: 0.0268, Class Loss: 8.4902
# Epoch [26/50], Total Loss: 30.0314, Rec Loss: 21.8762, KL Div: 0.0252, Class Loss: 8.1301
# Epoch [27/50], Total Loss: 29.6831, Rec Loss: 21.8563, KL Div: 0.0272, Class Loss: 7.7996
# Epoch [28/50], Total Loss: 29.3961, Rec Loss: 21.8481, KL Div: 0.0262, Class Loss: 7.5218
# Epoch [29/50], Total Loss: 29.1964, Rec Loss: 21.8542, KL Div: 0.0268, Class Loss: 7.3154
# Epoch [30/50], Total Loss: 28.9880, Rec Loss: 21.8239, KL Div: 0.0263, Class Loss: 7.1378
# Epoch [31/50], Total Loss: 28.7978, Rec Loss: 21.8204, KL Div: 0.0257, Class Loss: 6.9517
# Epoch [32/50], Total Loss: 28.6594, Rec Loss: 21.8406, KL Div: 0.0250, Class Loss: 6.7938
# Epoch [33/50], Total Loss: 28.4679, Rec Loss: 21.8058, KL Div: 0.0251, Class Loss: 6.6370
# Epoch [34/50], Total Loss: 28.3735, Rec Loss: 21.8253, KL Div: 0.0247, Class Loss: 6.5235
# Epoch [35/50], Total Loss: 28.2555, Rec Loss: 21.8296, KL Div: 0.0245, Class Loss: 6.4014
# Epoch [36/50], Total Loss: 28.1509, Rec Loss: 21.8251, KL Div: 0.0233, Class Loss: 6.3025
# Epoch [37/50], Total Loss: 28.0796, Rec Loss: 21.8489, KL Div: 0.0247, Class Loss: 6.2060
# Epoch [38/50], Total Loss: 27.9776, Rec Loss: 21.8366, KL Div: 0.0243, Class Loss: 6.1167
# Epoch [39/50], Total Loss: 27.9009, Rec Loss: 21.8504, KL Div: 0.0217, Class Loss: 6.0288
# Epoch [40/50], Total Loss: 27.7909, Rec Loss: 21.8327, KL Div: 0.0221, Class Loss: 5.9361
# Epoch [41/50], Total Loss: 27.7190, Rec Loss: 21.8294, KL Div: 0.0247, Class Loss: 5.8648
# Epoch [42/50], Total Loss: 27.6238, Rec Loss: 21.8172, KL Div: 0.0217, Class Loss: 5.7848
# Epoch [43/50], Total Loss: 27.5504, Rec Loss: 21.8182, KL Div: 0.0219, Class Loss: 5.7103
# Epoch [44/50], Total Loss: 27.4840, Rec Loss: 21.8275, KL Div: 0.0207, Class Loss: 5.6358
# Epoch [45/50], Total Loss: 27.4298, Rec Loss: 21.8165, KL Div: 0.0200, Class Loss: 5.5933
# Epoch [46/50], Total Loss: 27.3412, Rec Loss: 21.8023, KL Div: 0.0234, Class Loss: 5.5156
# Epoch [47/50], Total Loss: 27.3116, Rec Loss: 21.8215, KL Div: 0.0220, Class Loss: 5.4681
# Epoch [48/50], Total Loss: 27.2118, Rec Loss: 21.7910, KL Div: 0.0191, Class Loss: 5.4016
# Epoch [49/50], Total Loss: 27.1893, Rec Loss: 21.8123, KL Div: 0.0213, Class Loss: 5.3557
# Epoch [50/50], Total Loss: 27.1244, Rec Loss: 21.8043, KL Div: 0.0203, Class Loss: 5.2999
# Time elapsed:  57.22523832321167

# %%
expanded_strong_data = np.concatenate((X_train, X_strong), axis=0)
expanded_strong_labels = np.concatenate((y_train, y_strong), axis=0)
X_expanded_strong_tensor = torch.tensor(expanded_strong_data).float()
y_expanded_strong_tensor = torch.tensor(expanded_strong_labels).long()
# Create new dataset and loader
expanded_strong_dataset = TimeSeriesDataset(X_expanded_strong_tensor, y_expanded_strong_tensor)
expanded_strong_loader = DataLoader(expanded_strong_dataset, batch_size=batch_size, shuffle=False)
model2_strong = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)

# Define optimizer
model_name = "model2_strong"
optimizer = optim.Adam(model2_strong.parameters(), lr=train_learning_rate)
model2_strong = train_model(model2_strong, optimizer, expanded_strong_loader, num_epochs=train_num_epochs, model_name="model2_strong")
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/50], Total Loss: 232.6409, Rec Loss: 118.6456, KL Div: 1.4647, Class Loss: 112.5306
# Epoch [2/50], Total Loss: 93.1039, Rec Loss: 46.1465, KL Div: 0.4175, Class Loss: 46.5399
# Epoch [3/50], Total Loss: 78.1773, Rec Loss: 44.0313, KL Div: 0.2170, Class Loss: 33.9289
# Epoch [4/50], Total Loss: 69.5079, Rec Loss: 43.4536, KL Div: 0.1122, Class Loss: 25.9422
# Epoch [5/50], Total Loss: 63.6103, Rec Loss: 43.2812, KL Div: 0.0785, Class Loss: 20.2506
# Epoch [6/50], Total Loss: 59.8268, Rec Loss: 43.2852, KL Div: 0.0657, Class Loss: 16.4759
# Epoch [7/50], Total Loss: 57.0454, Rec Loss: 43.2126, KL Div: 0.0595, Class Loss: 13.7733
# Epoch [8/50], Total Loss: 55.0085, Rec Loss: 43.1804, KL Div: 0.0506, Class Loss: 11.7775
# Epoch [9/50], Total Loss: 53.5721, Rec Loss: 43.1607, KL Div: 0.0504, Class Loss: 10.3610
# Epoch [10/50], Total Loss: 52.5699, Rec Loss: 43.1187, KL Div: 0.0471, Class Loss: 9.4041
# Epoch [11/50], Total Loss: 51.9376, Rec Loss: 43.1383, KL Div: 0.0448, Class Loss: 8.7545
# Epoch [12/50], Total Loss: 51.4270, Rec Loss: 43.1219, KL Div: 0.0449, Class Loss: 8.2602
# Epoch [13/50], Total Loss: 51.1235, Rec Loss: 43.1144, KL Div: 0.0441, Class Loss: 7.9650
# Epoch [14/50], Total Loss: 50.8194, Rec Loss: 43.0447, KL Div: 0.0447, Class Loss: 7.7299
# Epoch [15/50], Total Loss: 50.6776, Rec Loss: 43.1004, KL Div: 0.0430, Class Loss: 7.5342
# Epoch [16/50], Total Loss: 50.4607, Rec Loss: 43.0726, KL Div: 0.0386, Class Loss: 7.3494
# Epoch [17/50], Total Loss: 50.2925, Rec Loss: 43.0744, KL Div: 0.0374, Class Loss: 7.1806
# Epoch [18/50], Total Loss: 50.1573, Rec Loss: 43.0633, KL Div: 0.0372, Class Loss: 7.0567
# Epoch [19/50], Total Loss: 50.0268, Rec Loss: 43.0434, KL Div: 0.0384, Class Loss: 6.9450
# Epoch [20/50], Total Loss: 49.9513, Rec Loss: 43.0653, KL Div: 0.0342, Class Loss: 6.8518
# Epoch [21/50], Total Loss: 49.8388, Rec Loss: 43.0179, KL Div: 0.0321, Class Loss: 6.7888
# Epoch [22/50], Total Loss: 49.8257, Rec Loss: 43.0604, KL Div: 0.0380, Class Loss: 6.7272
# Epoch [23/50], Total Loss: 49.6894, Rec Loss: 42.9970, KL Div: 0.0322, Class Loss: 6.6602
# Epoch [24/50], Total Loss: 49.6923, Rec Loss: 43.0222, KL Div: 0.0346, Class Loss: 6.6355
# Epoch [25/50], Total Loss: 49.6089, Rec Loss: 43.0002, KL Div: 0.0318, Class Loss: 6.5769
# Epoch [26/50], Total Loss: 49.5708, Rec Loss: 43.0205, KL Div: 0.0352, Class Loss: 6.5152
# Epoch [27/50], Total Loss: 49.5227, Rec Loss: 43.0023, KL Div: 0.0325, Class Loss: 6.4878
# Epoch [28/50], Total Loss: 49.4729, Rec Loss: 43.0014, KL Div: 0.0301, Class Loss: 6.4414
# Epoch [29/50], Total Loss: 49.4308, Rec Loss: 43.0077, KL Div: 0.0292, Class Loss: 6.3939
# Epoch [30/50], Total Loss: 49.4161, Rec Loss: 43.0057, KL Div: 0.0308, Class Loss: 6.3797
# Epoch [31/50], Total Loss: 49.3764, Rec Loss: 43.0099, KL Div: 0.0291, Class Loss: 6.3375
# Epoch [32/50], Total Loss: 49.3245, Rec Loss: 42.9970, KL Div: 0.0271, Class Loss: 6.3003
# Epoch [33/50], Total Loss: 49.2650, Rec Loss: 42.9757, KL Div: 0.0269, Class Loss: 6.2624
# Epoch [34/50], Total Loss: 49.2644, Rec Loss: 43.0102, KL Div: 0.0309, Class Loss: 6.2233
# Epoch [35/50], Total Loss: 49.2158, Rec Loss: 42.9936, KL Div: 0.0311, Class Loss: 6.1910
# Epoch [36/50], Total Loss: 49.1740, Rec Loss: 42.9897, KL Div: 0.0293, Class Loss: 6.1550
# Epoch [37/50], Total Loss: 49.1007, Rec Loss: 42.9723, KL Div: 0.0223, Class Loss: 6.1060
# Epoch [38/50], Total Loss: 49.0761, Rec Loss: 42.9869, KL Div: 0.0268, Class Loss: 6.0625
# Epoch [39/50], Total Loss: 49.0296, Rec Loss: 42.9631, KL Div: 0.0326, Class Loss: 6.0339
# Epoch [40/50], Total Loss: 49.0263, Rec Loss: 42.9841, KL Div: 0.0303, Class Loss: 6.0119
# Epoch [41/50], Total Loss: 48.9937, Rec Loss: 43.0057, KL Div: 0.0241, Class Loss: 5.9638
# Epoch [42/50], Total Loss: 48.9422, Rec Loss: 42.9727, KL Div: 0.0272, Class Loss: 5.9423
# Epoch [43/50], Total Loss: 48.9019, Rec Loss: 42.9739, KL Div: 0.0250, Class Loss: 5.9030
# Epoch [44/50], Total Loss: 48.8868, Rec Loss: 42.9799, KL Div: 0.0260, Class Loss: 5.8810
# Epoch [45/50], Total Loss: 48.8176, Rec Loss: 42.9563, KL Div: 0.0250, Class Loss: 5.8362
# Epoch [46/50], Total Loss: 48.7904, Rec Loss: 42.9544, KL Div: 0.0322, Class Loss: 5.8037
# Epoch [47/50], Total Loss: 48.7747, Rec Loss: 42.9695, KL Div: 0.0225, Class Loss: 5.7827
# Epoch [48/50], Total Loss: 48.7252, Rec Loss: 42.9726, KL Div: 0.0249, Class Loss: 5.7277
# Epoch [49/50], Total Loss: 48.6827, Rec Loss: 42.9316, KL Div: 0.0276, Class Loss: 5.7235
# Epoch [50/50], Total Loss: 48.6567, Rec Loss: 42.9472, KL Div: 0.0256, Class Loss: 5.6839
# Time elapsed:  114.7305850982666

# %%
expanded_random_data = np.concatenate((X_train, X_random), axis=0)
expanded_random_labels = np.concatenate((y_train, y_random), axis=0)
X_expanded_random_tensor = torch.tensor(expanded_random_data).float()
y_expanded_random_tensor = torch.tensor(expanded_random_labels).long()
# Create new dataset and loader
expanded_random_dataset = TimeSeriesDataset(X_expanded_random_tensor, y_expanded_random_tensor)
expanded_random_loader = DataLoader(expanded_random_dataset, batch_size=batch_size, shuffle=False)
model2_random = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)

# Define optimizer
model_name = "model2_random"
optimizer = optim.Adam(model2_random.parameters(), lr=train_learning_rate)
model2_random = train_model(model2_random, optimizer, expanded_random_loader, num_epochs=train_num_epochs, model_name="model2_random")
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/50], Total Loss: 190.9454, Rec Loss: 92.9513, KL Div: 1.2488, Class Loss: 96.7453
# Epoch [2/50], Total Loss: 69.8917, Rec Loss: 30.8320, KL Div: 0.4041, Class Loss: 38.6557
# Epoch [3/50], Total Loss: 62.1811, Rec Loss: 29.8799, KL Div: 0.3663, Class Loss: 31.9349
# Epoch [4/50], Total Loss: 56.6099, Rec Loss: 29.0104, KL Div: 0.1892, Class Loss: 27.4104
# Epoch [5/50], Total Loss: 52.4917, Rec Loss: 28.5859, KL Div: 0.1167, Class Loss: 23.7890
# Epoch [6/50], Total Loss: 49.0383, Rec Loss: 28.3333, KL Div: 0.0801, Class Loss: 20.6249
# Epoch [7/50], Total Loss: 46.1663, Rec Loss: 28.2499, KL Div: 0.0642, Class Loss: 17.8522
# Epoch [8/50], Total Loss: 43.8566, Rec Loss: 28.2678, KL Div: 0.0629, Class Loss: 15.5259
# Epoch [9/50], Total Loss: 41.8494, Rec Loss: 28.2245, KL Div: 0.0597, Class Loss: 13.5652
# Epoch [10/50], Total Loss: 40.1324, Rec Loss: 28.1792, KL Div: 0.0647, Class Loss: 11.8885
# Epoch [11/50], Total Loss: 38.7511, Rec Loss: 28.1658, KL Div: 0.0601, Class Loss: 10.5252
# Epoch [12/50], Total Loss: 37.7220, Rec Loss: 28.1921, KL Div: 0.0581, Class Loss: 9.4718
# Epoch [13/50], Total Loss: 36.9666, Rec Loss: 28.2276, KL Div: 0.0662, Class Loss: 8.6728
# Epoch [14/50], Total Loss: 36.3553, Rec Loss: 28.2118, KL Div: 0.0486, Class Loss: 8.0949
# Epoch [15/50], Total Loss: 35.8664, Rec Loss: 28.1577, KL Div: 0.0558, Class Loss: 7.6529
# Epoch [16/50], Total Loss: 35.4822, Rec Loss: 28.0888, KL Div: 0.0571, Class Loss: 7.3363
# Epoch [17/50], Total Loss: 35.2547, Rec Loss: 28.1151, KL Div: 0.0556, Class Loss: 7.0840
# Epoch [18/50], Total Loss: 35.0691, Rec Loss: 28.1367, KL Div: 0.0462, Class Loss: 6.8862
# Epoch [19/50], Total Loss: 34.8617, Rec Loss: 28.0980, KL Div: 0.0482, Class Loss: 6.7155
# Epoch [20/50], Total Loss: 34.7616, Rec Loss: 28.1206, KL Div: 0.0585, Class Loss: 6.5825
# Epoch [21/50], Total Loss: 34.5853, Rec Loss: 28.0753, KL Div: 0.0451, Class Loss: 6.4649
# Epoch [22/50], Total Loss: 34.4985, Rec Loss: 28.0894, KL Div: 0.0415, Class Loss: 6.3675
# Epoch [23/50], Total Loss: 34.4242, Rec Loss: 28.0924, KL Div: 0.0438, Class Loss: 6.2880
# Epoch [24/50], Total Loss: 34.3568, Rec Loss: 28.1112, KL Div: 0.0383, Class Loss: 6.2072
# Epoch [25/50], Total Loss: 34.2860, Rec Loss: 28.1179, KL Div: 0.0373, Class Loss: 6.1308
# Epoch [26/50], Total Loss: 34.2450, Rec Loss: 28.1259, KL Div: 0.0415, Class Loss: 6.0776
# Epoch [27/50], Total Loss: 34.1246, Rec Loss: 28.0757, KL Div: 0.0370, Class Loss: 6.0119
# Epoch [28/50], Total Loss: 34.0813, Rec Loss: 28.0904, KL Div: 0.0360, Class Loss: 5.9549
# Epoch [29/50], Total Loss: 34.0230, Rec Loss: 28.0718, KL Div: 0.0381, Class Loss: 5.9130
# Epoch [30/50], Total Loss: 33.9885, Rec Loss: 28.0865, KL Div: 0.0409, Class Loss: 5.8612
# Epoch [31/50], Total Loss: 33.9406, Rec Loss: 28.0756, KL Div: 0.0422, Class Loss: 5.8228
# Epoch [32/50], Total Loss: 33.9140, Rec Loss: 28.1060, KL Div: 0.0287, Class Loss: 5.7793
# Epoch [33/50], Total Loss: 33.8579, Rec Loss: 28.0737, KL Div: 0.0322, Class Loss: 5.7520
# Epoch [34/50], Total Loss: 33.8379, Rec Loss: 28.0666, KL Div: 0.0399, Class Loss: 5.7314
# Epoch [35/50], Total Loss: 33.7560, Rec Loss: 28.0396, KL Div: 0.0309, Class Loss: 5.6855
# Epoch [36/50], Total Loss: 33.7393, Rec Loss: 28.0522, KL Div: 0.0345, Class Loss: 5.6525
# Epoch [37/50], Total Loss: 33.7303, Rec Loss: 28.0779, KL Div: 0.0396, Class Loss: 5.6128
# Epoch [38/50], Total Loss: 33.6767, Rec Loss: 28.0501, KL Div: 0.0337, Class Loss: 5.5929
# Epoch [39/50], Total Loss: 33.6445, Rec Loss: 28.0543, KL Div: 0.0326, Class Loss: 5.5575
# Epoch [40/50], Total Loss: 33.6394, Rec Loss: 28.0752, KL Div: 0.0355, Class Loss: 5.5287
# Epoch [41/50], Total Loss: 33.5832, Rec Loss: 28.0483, KL Div: 0.0395, Class Loss: 5.4953
# Epoch [42/50], Total Loss: 33.5599, Rec Loss: 28.0562, KL Div: 0.0341, Class Loss: 5.4696
# Epoch [43/50], Total Loss: 33.5027, Rec Loss: 28.0208, KL Div: 0.0295, Class Loss: 5.4524
# Epoch [44/50], Total Loss: 33.4744, Rec Loss: 28.0278, KL Div: 0.0301, Class Loss: 5.4165
# Epoch [45/50], Total Loss: 33.4137, Rec Loss: 27.9975, KL Div: 0.0287, Class Loss: 5.3875
# Epoch [46/50], Total Loss: 33.4693, Rec Loss: 28.0554, KL Div: 0.0445, Class Loss: 5.3694
# Epoch [47/50], Total Loss: 33.4519, Rec Loss: 28.0706, KL Div: 0.0302, Class Loss: 5.3511
# Epoch [48/50], Total Loss: 33.4301, Rec Loss: 28.0547, KL Div: 0.0294, Class Loss: 5.3460
# Epoch [49/50], Total Loss: 33.3636, Rec Loss: 28.0292, KL Div: 0.0274, Class Loss: 5.3070
# Epoch [50/50], Total Loss: 33.3579, Rec Loss: 28.0397, KL Div: 0.0281, Class Loss: 5.2901
# Time elapsed:  70.18600010871887

# %%
# Assuming you have already defined and initialized your models:
# model, model_medium, model_random, model_strong

# Dictionary of models with their names for easy reference
models = {
    'model': model,
    'model_medium': model_medium,
    'model_random': model_random,
    'model_strong': model_strong,
    'model2_medium': model2_medium,
    'model2_random': model2_random,
    'model2_strong': model2_strong
}

# Generate all possible unique pairs of models
model_pairs = list(combinations(models.items(), 2))

# Lists to keep track of identical and different model pairs
identical_pairs = []
different_pairs = []

# Function to compare two models
def compare_models(model1, model2, name1, name2):
    state_dict1 = model1.state_dict()
    state_dict2 = model2.state_dict()
    
    # First, check if both models have the same set of keys (layers)
    keys1 = set(state_dict1.keys())
    keys2 = set(state_dict2.keys())
    
    if keys1 != keys2:
        missing_in_1 = keys2 - keys1
        missing_in_2 = keys1 - keys2
        if missing_in_1:
            
            print(f"Model '{name1}' is missing layers: {missing_in_1}")
        if missing_in_2:
            
            print(f"Model '{name2}' is missing layers: {missing_in_2}")
        return False  # Layers mismatch implies models are different
    
    # Compare each parameter tensor
    for key in state_dict1:
        param1 = state_dict1[key]
        param2 = state_dict2[key]
        
        if not torch.equal(param1, param2):
            #print(f"Mismatch found in layer '{key}' between '{name1}' and '{name2}'.")
            return False  # Found a mismatch
    
    return True  # All parameters match

# Iterate through each pair and compare
for (name1, model1), (name2, model2_medium) in model_pairs:
    print(f"Comparing '{name1}' with '{name2}':")
    are_identical = compare_models(model1, model2_medium, name1, name2)
    
    if are_identical:
        identical_pairs.append((name1, name2))
        print(f"--> '{name1}' and '{name2}' are IDENTICAL.\n")
    else:
        different_pairs.append((name1, name2))
        print(f"--> '{name1}' and '{name2}' are DIFFERENT.\n")

# Summary of results
print("=== Comparison Summary ===\n")

if identical_pairs:
    print("Identical Model Pairs:")
    for name1, name2 in identical_pairs:
        print(f" - {name1} and {name2}")
else:
    print("No identical model pairs found.")

print()

if different_pairs:
    print("Different Model Pairs:")
    for name1, name2 in different_pairs:
        print(f" - {name1} and {name2}")
else:
    print("No different model pairs found.")
# Out:
# Comparing 'model' with 'model_medium':
# --> 'model' and 'model_medium' are DIFFERENT.
#
# Comparing 'model' with 'model_random':
# --> 'model' and 'model_random' are DIFFERENT.
#
# Comparing 'model' with 'model_strong':
# --> 'model' and 'model_strong' are DIFFERENT.
#
# Comparing 'model' with 'model2_medium':
# --> 'model' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model' with 'model2_random':
# --> 'model' and 'model2_random' are DIFFERENT.
#
# Comparing 'model' with 'model2_strong':
# --> 'model' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model_medium' with 'model_random':
# --> 'model_medium' and 'model_random' are DIFFERENT.
#
# Comparing 'model_medium' with 'model_strong':
# --> 'model_medium' and 'model_strong' are DIFFERENT.
#
# Comparing 'model_medium' with 'model2_medium':
# --> 'model_medium' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model_medium' with 'model2_random':
# --> 'model_medium' and 'model2_random' are DIFFERENT.
#
# Comparing 'model_medium' with 'model2_strong':
# --> 'model_medium' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model_random' with 'model_strong':
# --> 'model_random' and 'model_strong' are DIFFERENT.
#
# Comparing 'model_random' with 'model2_medium':
# --> 'model_random' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model_random' with 'model2_random':
# --> 'model_random' and 'model2_random' are DIFFERENT.
#
# Comparing 'model_random' with 'model2_strong':
# --> 'model_random' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model_strong' with 'model2_medium':
# --> 'model_strong' and 'model2_medium' are DIFFERENT.
#
# Comparing 'model_strong' with 'model2_random':
# --> 'model_strong' and 'model2_random' are DIFFERENT.
#
# Comparing 'model_strong' with 'model2_strong':
# --> 'model_strong' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model2_medium' with 'model2_random':
# --> 'model2_medium' and 'model2_random' are DIFFERENT.
#
# Comparing 'model2_medium' with 'model2_strong':
# --> 'model2_medium' and 'model2_strong' are DIFFERENT.
#
# Comparing 'model2_random' with 'model2_strong':
# --> 'model2_random' and 'model2_strong' are DIFFERENT.
#
# === Comparison Summary ===
#
# No identical model pairs found.
#
# Different Model Pairs:
#  - model and model_medium
#  - model and model_random
#  - model and model_strong
#  - model and model2_medium
#  - model and model2_random
#  - model and model2_strong
#  - model_medium and model_random
#  - model_medium and model_strong
#  - model_medium and model2_medium
#  - model_medium and model2_random
#  - model_medium and model2_strong
#  - model_random and model_strong
#  - model_random and model2_medium
#  - model_random and model2_random
#  - model_random and model2_strong
#  - model_strong and model2_medium
#  - model_strong and model2_random
#  - model_strong and model2_strong
#  - model2_medium and model2_random
#  - model2_medium and model2_strong
#  - model2_random and model2_strong

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_medium, test_loader)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 93.22%, recall = 83.9% and F1-score = 88.31%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_strong, test_loader)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 95.25%, recall = 79.71% and F1-score = 86.79%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_random, test_loader)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 94.31%, recall = 82.94% and F1-score = 88.26%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_medium, test_loader)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 93.58%, recall = 84.71% and F1-score = 88.92%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_strong, test_loader)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 93.58%, recall = 84.71% and F1-score = 88.92%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_random, test_loader)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 98.25%, recall = 78.38% and F1-score = 87.2%

# %%
## Define the scale factor
#scale = 2  # You can adjust this value
## Calculate the threshold
#threshold = np.mean(train_anomaly_scores) + scale * np.std(train_anomaly_scores)
#print(f"Anomaly Detection Threshold: {threshold}")
## Classify test data based on threshold
#threshold_predictions = (test_anomaly_scores > threshold).astype(int)
#
## Evaluate threshold-based predictions
#print("Threshold-based Classification Report:")
#print(classification_report(test_true_labels, threshold_predictions, target_names=['Normal', 'Anomaly']))
#
## Confusion matrix
#cm_threshold = confusion_matrix(test_true_labels, threshold_predictions)
#print("Threshold-based Confusion Matrix:")
#print(cm_threshold)

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_anomaly_scores[train_true_labels == 0], bins=50, alpha=0.6, label='Normal')
plt.hist(train_anomaly_scores[train_true_labels == 1], bins=50, alpha=0.6, label='Anomaly')
plt.title('Anomaly Score Distribution')
plt.xlabel('Anomaly Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.hist(train_anomaly_scores[train_true_labels == 0], bins=50, alpha=0.6, label='Normal')
#       3 plt.hist(train_anomaly_scores[train_true_labels == 1], bins=50, alpha=0.6, label='Anomaly')
#       4 plt.title('Anomaly Score Distribution')
#
# NameError: name 'train_anomaly_scores' is not defined

# %%
def plot_anomaly_scores_scatter(anomaly_scores, true_labels, threshold):
    plt.figure(figsize=(10, 6))
    plt.scatter(range(len(anomaly_scores)), anomaly_scores, c=true_labels, cmap='coolwarm', label='Data Point')
    plt.axhline(threshold, color='red', linestyle='--', label='Threshold')
    plt.title('Anomaly Scores Scatter Plot')
    plt.xlabel('Sample Index')
    plt.ylabel('Anomaly Score')
    plt.legend()
    plt.show()

# Call the function
plot_anomaly_scores_scatter(test_anomaly_scores, test_true_labels, threshold)

# %%
# Set plot style
sns.set(style='whitegrid')
def plot_anomaly_score_histogram(anomaly_scores, true_labels, threshold):
    plt.figure(figsize=(10, 6))
    sns.histplot(anomaly_scores[true_labels == 0], bins=50, color='green', label='Normal', kde=True, stat='density')
    sns.histplot(anomaly_scores[true_labels == 1], bins=50, color='red', label='Anomaly', kde=True, stat='density')
    plt.axvline(threshold, color='blue', linestyle='--', label='Threshold')
    plt.title('Histogram of Anomaly Scores')
    plt.xlabel('Anomaly Score')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

# Call the function
plot_anomaly_score_histogram(test_anomaly_scores, test_true_labels, threshold)

# %%
# Compute AUC-ROC
auc_score = roc_auc_score(test_true_labels, test_anomaly_scores)
print(f"AUC-ROC Score: {auc_score:.4f}")

# Compute Precision-Recall Curve
precision, recall, thresholds = precision_recall_curve(test_true_labels, test_anomaly_scores)
ap_score = average_precision_score(test_true_labels, test_anomaly_scores)
print(f"Average Precision Score: {ap_score:.4f}")

# %%
fpr, tpr, thresholds = roc_curve(test_true_labels, test_anomaly_scores)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_score:.4f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
# Classification report
print("Classification Report:")
print(classification_report(test_true_labels, test_predictions, target_names=['Normal', 'Anomaly']))

# Confusion matrix
cm = confusion_matrix(test_true_labels, test_predictions)
print("Confusion Matrix:")
print(cm)

# Compute AUC-ROC
auc_score = roc_auc_score(test_true_labels, test_anomaly_scores)
print(f"AUC-ROC Score: {auc_score:.4f}")

# %%
plt.figure(figsize=(10, 6))
plt.hist(test_anomaly_scores[test_true_labels == 0], bins=50, alpha=0.6, label='Normal')
plt.hist(test_anomaly_scores[test_true_labels == 1], bins=50, alpha=0.6, label='Anomaly')
plt.axvline(threshold, color='red', linestyle='--', label='Threshold')
plt.title('Anomaly Score Distribution with Threshold')
plt.xlabel('Anomaly Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()
