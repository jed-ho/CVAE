# %% [markdown]
# # Demonstration of anomaly detection with CVAE using DASHlink data
#
# **Author: Milad Memarzadeh (milad.memarzadeh@nasa.gov)**

# %% [markdown]
# # Demonstration of anomaly detection with CVAE using DASHlink data
#
# **Author: Milad Memarzadeh (milad.memarzadeh@nasa.gov)**

# %% [markdown]
# # Import Libraries

# %%
import os
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
import torch.nn.functional as F

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support, roc_curve, precision_recall_curve, average_precision_score
from sklearn.utils import shuffle
from source.modelsCondVAE import *
from source.utilsCondVAEs5 import *
from itertools import combinations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
k_folds = 5
train_learning_rate = 1e-4 #1e-3
finetune_learning_rate = 1e-5 #1e-4
train_num_epochs = 50
finetune_num_epochs = 5

latent_dim = 10
batch_size = 64
window_size = 8
save_dir="./CompressAE/A2/"+str(window_size)+"/"

# %% [markdown]
# # Load and preprocess data

# %%
X_train = np.load(os.path.join(save_dir, "z_train.npy"))
y_train = np.load(os.path.join(save_dir, "y_train.npy"))
X_val = np.load(os.path.join(save_dir, "z_val.npy"))
y_val = np.load(os.path.join(save_dir, "y_val.npy"))
X_test = np.load(os.path.join(save_dir, "z_test.npy"))
y_test = np.load(os.path.join(save_dir, "y_test.npy"))

X_train_tensor = torch.tensor(X_train).float()
y_train_tensor = torch.tensor(y_train).long()

X_val_tensor = torch.tensor(X_val).float()
y_val_tensor = torch.tensor(y_val).long()

X_test_tensor = torch.tensor(X_test).float()
y_test_tensor = torch.tensor(y_test).long()

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels  # Now labels are provided for all data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = self.data[idx]
        y = self.labels[idx]
        return X, y

# %%
train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False) #TODO adjust Shuffle training data? 
full_train_dataset = TimeSeriesDataset(X_train_tensor, y_train_tensor)

val_dataset = TimeSeriesDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


test_dataset = TimeSeriesDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Instantiate and Train the Conditional VAE

# %%
def evaluate_model(model, data_loader):
    model.eval()
    total_loss = 0
    total_correct = 0
    total_samples = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for data, target in data_loader:
            data = data.to(device)
            target = target.to(device)

            # Forward pass
            x_rec, class_logits = model(data)
            
            # Compute classification loss
            loss = criterion(class_logits, target)
            total_loss += loss.item() * data.size(0)

            # Compute accuracy
            preds = class_logits.argmax(dim=1)
            total_correct += (preds == target).sum().item()
            total_samples += data.size(0)

    avg_loss = total_loss / total_samples
    avg_acc = total_correct / total_samples

    return avg_loss, avg_acc

# %%
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)
num_param = 1    # Since we have univariate time series
num_classes = 2 
scale_flag = 0   # Use Sigmoid activation in the decoder

results = {}

print('Starting k-fold cross-validation...')
time_start = time.time()
for fold, (train_idx, val2_idx) in enumerate(skf.split(np.zeros(len(y_train_tensor)), y_train_tensor.cpu().numpy())):
    print(f'Fold {fold+1}/{k_folds}')
    model_name="CondVAE_model"+str(fold+1)
    # Create data loaders for the current fold
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val2_subsampler = torch.utils.data.SubsetRandomSampler(val2_idx)
    
    train_loader = DataLoader(full_train_dataset, batch_size=batch_size, sampler=train_subsampler)
    val2_loader = DataLoader(full_train_dataset, batch_size=batch_size, sampler=val2_subsampler)
    
    model = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
    optimizer = optim.Adam(model.parameters(), lr=train_learning_rate)
    
    model = train_model(
    model,
    optimizer,
    train_loader,
    num_epochs=train_num_epochs,
    save=True,
    save_dir=save_dir,
    model_name=model_name)
    
    # Evaluate the model on validation data
    val_loss, val_acc = evaluate_model(model, val2_loader)
    
    # Save the results for this fold
    results[fold] = {'val_loss': val_loss, 'val_acc': val_acc}
    
    print(f'Fold {fold+1} Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}')

time_end = time.time()
print(f'Total time taken for k-fold cross-validation: {time_end - time_start} seconds')
buffer = io.BytesIO()
torch.save(model.state_dict(), buffer)
# Out:
# Starting k-fold cross-validation...
# Fold 1/5
# Epoch [1/50], Total Loss: 3965.1426, Rec Loss: 3897.3467, KL Div: 14.8980, Class Loss: 52.8979
# Epoch [2/50], Total Loss: 3540.8488, Rec Loss: 3509.9242, KL Div: 0.1234, Class Loss: 30.8012
# Epoch [3/50], Total Loss: 3538.8298, Rec Loss: 3508.8421, KL Div: 0.1077, Class Loss: 29.8800
# Epoch [4/50], Total Loss: 3538.2535, Rec Loss: 3509.2487, KL Div: 0.0927, Class Loss: 28.9121
# Epoch [5/50], Total Loss: 3537.7007, Rec Loss: 3508.9960, KL Div: 0.0834, Class Loss: 28.6213
# Epoch [6/50], Total Loss: 3537.5066, Rec Loss: 3509.2937, KL Div: 0.0734, Class Loss: 28.1395
# Epoch [7/50], Total Loss: 3538.0163, Rec Loss: 3510.1350, KL Div: 0.0750, Class Loss: 27.8062
# Epoch [8/50], Total Loss: 3536.6424, Rec Loss: 3509.0707, KL Div: 0.0857, Class Loss: 27.4860
# Epoch [9/50], Total Loss: 3536.3554, Rec Loss: 3508.9707, KL Div: 0.0955, Class Loss: 27.2892
# Epoch [10/50], Total Loss: 3534.7334, Rec Loss: 3508.0414, KL Div: 0.0694, Class Loss: 26.6226
# Epoch [11/50], Total Loss: 3533.4930, Rec Loss: 3506.8293, KL Div: 0.1150, Class Loss: 26.5487
# Epoch [12/50], Total Loss: 3534.7220, Rec Loss: 3508.8284, KL Div: 0.1170, Class Loss: 25.7766
# Epoch [13/50], Total Loss: 3534.8054, Rec Loss: 3509.7409, KL Div: 0.1285, Class Loss: 24.9360
# Epoch [14/50], Total Loss: 3533.5422, Rec Loss: 3509.1813, KL Div: 0.1429, Class Loss: 24.2181
# Epoch [15/50], Total Loss: 3531.4584, Rec Loss: 3507.5626, KL Div: 0.1524, Class Loss: 23.7434
# Epoch [16/50], Total Loss: 3531.4710, Rec Loss: 3508.6268, KL Div: 0.1277, Class Loss: 22.7166
# Epoch [17/50], Total Loss: 3530.7353, Rec Loss: 3508.6123, KL Div: 0.1037, Class Loss: 22.0194
# Epoch [18/50], Total Loss: 3530.8289, Rec Loss: 3508.9793, KL Div: 0.1226, Class Loss: 21.7269
# Epoch [19/50], Total Loss: 3528.1752, Rec Loss: 3507.2883, KL Div: 0.1194, Class Loss: 20.7675
# Epoch [20/50], Total Loss: 3527.7116, Rec Loss: 3507.9808, KL Div: 0.0956, Class Loss: 19.6352
# Epoch [21/50], Total Loss: 3528.0965, Rec Loss: 3508.8494, KL Div: 0.0853, Class Loss: 19.1618
# Epoch [22/50], Total Loss: 3527.5306, Rec Loss: 3508.9148, KL Div: 0.0876, Class Loss: 18.5282
# Epoch [23/50], Total Loss: 3526.7854, Rec Loss: 3508.8479, KL Div: 0.1394, Class Loss: 17.7982
# Epoch [24/50], Total Loss: 3528.7408, Rec Loss: 3511.1740, KL Div: 0.0945, Class Loss: 17.4723
# Epoch [25/50], Total Loss: 3526.8214, Rec Loss: 3510.1339, KL Div: 0.0747, Class Loss: 16.6128
# Epoch [26/50], Total Loss: 3526.1092, Rec Loss: 3509.6688, KL Div: 0.0650, Class Loss: 16.3754
# Epoch [27/50], Total Loss: 3526.0310, Rec Loss: 3509.8198, KL Div: 0.0756, Class Loss: 16.1356
# Epoch [28/50], Total Loss: 3524.5552, Rec Loss: 3508.8239, KL Div: 0.0678, Class Loss: 15.6635
# Epoch [29/50], Total Loss: 3524.6455, Rec Loss: 3509.1551, KL Div: 0.0566, Class Loss: 15.4338
# Epoch [30/50], Total Loss: 3523.0584, Rec Loss: 3507.9915, KL Div: 0.0588, Class Loss: 15.0081
# Epoch [31/50], Total Loss: 3523.1267, Rec Loss: 3508.4650, KL Div: 0.0459, Class Loss: 14.6158
# Epoch [32/50], Total Loss: 3523.6985, Rec Loss: 3508.9191, KL Div: 0.0484, Class Loss: 14.7310
# Epoch [33/50], Total Loss: 3524.6278, Rec Loss: 3509.5898, KL Div: 0.0650, Class Loss: 14.9730
# Epoch [34/50], Total Loss: 3524.1227, Rec Loss: 3509.8069, KL Div: 0.0456, Class Loss: 14.2702
# Epoch [35/50], Total Loss: 3522.1329, Rec Loss: 3508.0451, KL Div: 0.0365, Class Loss: 14.0513
# Epoch [36/50], Total Loss: 3524.2841, Rec Loss: 3510.2584, KL Div: 0.0423, Class Loss: 13.9835
# Epoch [37/50], Total Loss: 3522.0846, Rec Loss: 3508.0207, KL Div: 0.0378, Class Loss: 14.0261
# Epoch [38/50], Total Loss: 3523.0768, Rec Loss: 3509.4242, KL Div: 0.0336, Class Loss: 13.6189
# Epoch [39/50], Total Loss: 3521.6803, Rec Loss: 3507.5857, KL Div: 0.0456, Class Loss: 14.0490
# Epoch [40/50], Total Loss: 3523.4093, Rec Loss: 3509.4533, KL Div: 0.0335, Class Loss: 13.9225
# Epoch [41/50], Total Loss: 3524.5943, Rec Loss: 3510.8340, KL Div: 0.0307, Class Loss: 13.7297
# Epoch [42/50], Total Loss: 3522.6645, Rec Loss: 3508.2991, KL Div: 0.0368, Class Loss: 14.3287
# Epoch [43/50], Total Loss: 3522.2467, Rec Loss: 3509.1390, KL Div: 0.0237, Class Loss: 13.0840
# Epoch [44/50], Total Loss: 3520.7863, Rec Loss: 3507.9056, KL Div: 0.0264, Class Loss: 12.8543
# Epoch [45/50], Total Loss: 3521.2666, Rec Loss: 3508.6087, KL Div: 0.0258, Class Loss: 12.6321
# Epoch [46/50], Total Loss: 3519.5248, Rec Loss: 3506.3425, KL Div: 0.0248, Class Loss: 13.1575
# Epoch [47/50], Total Loss: 3521.7437, Rec Loss: 3508.9746, KL Div: 0.0235, Class Loss: 12.7455
# Epoch [48/50], Total Loss: 3521.5229, Rec Loss: 3508.1041, KL Div: 0.0269, Class Loss: 13.3919
# Epoch [49/50], Total Loss: 3521.4937, Rec Loss: 3508.1127, KL Div: 0.0234, Class Loss: 13.3576
# Epoch [50/50], Total Loss: 3520.7128, Rec Loss: 3508.1222, KL Div: 0.0225, Class Loss: 12.5681
# Time elapsed:  109.01491260528564
# Fold 1 Validation Loss: 0.0395, Validation Accuracy: 0.9893
# Fold 2/5
# Epoch [1/50], Total Loss: 3981.7598, Rec Loss: 3918.3397, KL Div: 17.3005, Class Loss: 46.1197
# Epoch [2/50], Total Loss: 3527.3222, Rec Loss: 3496.0729, KL Div: 0.1256, Class Loss: 31.1238
# Epoch [3/50], Total Loss: 3524.8901, Rec Loss: 3495.0406, KL Div: 0.1265, Class Loss: 29.7230
# Epoch [4/50], Total Loss: 3523.7730, Rec Loss: 3494.4382, KL Div: 0.0987, Class Loss: 29.2361
# Epoch [5/50], Total Loss: 3523.5402, Rec Loss: 3494.6850, KL Div: 0.0902, Class Loss: 28.7650
# Epoch [6/50], Total Loss: 3521.3704, Rec Loss: 3492.7233, KL Div: 0.0927, Class Loss: 28.5544
# Epoch [7/50], Total Loss: 3522.9514, Rec Loss: 3494.7117, KL Div: 0.0851, Class Loss: 28.1546
# Epoch [8/50], Total Loss: 3521.2223, Rec Loss: 3493.2403, KL Div: 0.0788, Class Loss: 27.9033
# Epoch [9/50], Total Loss: 3521.7974, Rec Loss: 3494.2218, KL Div: 0.0882, Class Loss: 27.4874
# Epoch [10/50], Total Loss: 3519.6335, Rec Loss: 3492.7589, KL Div: 0.0689, Class Loss: 26.8057
# Epoch [11/50], Total Loss: 3520.9319, Rec Loss: 3494.4470, KL Div: 0.0858, Class Loss: 26.3990
# Epoch [12/50], Total Loss: 3522.4233, Rec Loss: 3496.5083, KL Div: 0.1087, Class Loss: 25.8062
# Epoch [13/50], Total Loss: 3519.0748, Rec Loss: 3493.6939, KL Div: 0.1057, Class Loss: 25.2752
# Epoch [14/50], Total Loss: 3516.2031, Rec Loss: 3491.8475, KL Div: 0.1001, Class Loss: 24.2555
# Epoch [15/50], Total Loss: 3516.2695, Rec Loss: 3492.7889, KL Div: 0.0828, Class Loss: 23.3977
# Epoch [16/50], Total Loss: 3517.0174, Rec Loss: 3494.2695, KL Div: 0.0789, Class Loss: 22.6690
# Epoch [17/50], Total Loss: 3517.4067, Rec Loss: 3495.2932, KL Div: 0.0874, Class Loss: 22.0261
# Epoch [18/50], Total Loss: 3514.6105, Rec Loss: 3493.6280, KL Div: 0.0739, Class Loss: 20.9085
# Epoch [19/50], Total Loss: 3513.7645, Rec Loss: 3493.0891, KL Div: 0.0804, Class Loss: 20.5949
# Epoch [20/50], Total Loss: 3515.1387, Rec Loss: 3494.8374, KL Div: 0.0769, Class Loss: 20.2244
# Epoch [21/50], Total Loss: 3514.1242, Rec Loss: 3493.5326, KL Div: 0.1299, Class Loss: 20.4616
# Epoch [22/50], Total Loss: 3512.6254, Rec Loss: 3493.1597, KL Div: 0.0841, Class Loss: 19.3816
# Epoch [23/50], Total Loss: 3511.7532, Rec Loss: 3492.8670, KL Div: 0.0719, Class Loss: 18.8143
# Epoch [24/50], Total Loss: 3510.5553, Rec Loss: 3491.6554, KL Div: 0.0825, Class Loss: 18.8173
# Epoch [25/50], Total Loss: 3511.4991, Rec Loss: 3493.8389, KL Div: 0.0652, Class Loss: 17.5950
# Epoch [26/50], Total Loss: 3510.5536, Rec Loss: 3492.9722, KL Div: 0.0754, Class Loss: 17.5060
# Epoch [27/50], Total Loss: 3511.9579, Rec Loss: 3494.3676, KL Div: 0.0754, Class Loss: 17.5148
# Epoch [28/50], Total Loss: 3511.5916, Rec Loss: 3495.2298, KL Div: 0.0651, Class Loss: 16.2967
# Epoch [29/50], Total Loss: 3510.1464, Rec Loss: 3493.4528, KL Div: 0.0733, Class Loss: 16.6203
# Epoch [30/50], Total Loss: 3509.6014, Rec Loss: 3493.4155, KL Div: 0.0553, Class Loss: 16.1306
# Epoch [31/50], Total Loss: 3507.4366, Rec Loss: 3491.6418, KL Div: 0.0573, Class Loss: 15.7374
# Epoch [32/50], Total Loss: 3508.8849, Rec Loss: 3493.4329, KL Div: 0.0538, Class Loss: 15.3982
# Epoch [33/50], Total Loss: 3510.6698, Rec Loss: 3495.4823, KL Div: 0.0483, Class Loss: 15.1392
# Epoch [34/50], Total Loss: 3507.8510, Rec Loss: 3493.0874, KL Div: 0.0493, Class Loss: 14.7143
# Epoch [35/50], Total Loss: 3508.8973, Rec Loss: 3493.6304, KL Div: 0.0543, Class Loss: 15.2125
# Epoch [36/50], Total Loss: 3507.6726, Rec Loss: 3492.6350, KL Div: 0.0573, Class Loss: 14.9804
# Epoch [37/50], Total Loss: 3507.6349, Rec Loss: 3493.1501, KL Div: 0.0426, Class Loss: 14.4423
# Epoch [38/50], Total Loss: 3507.1694, Rec Loss: 3492.2469, KL Div: 0.0513, Class Loss: 14.8713
# Epoch [39/50], Total Loss: 3507.7020, Rec Loss: 3493.8356, KL Div: 0.0423, Class Loss: 13.8240
# Epoch [40/50], Total Loss: 3507.0329, Rec Loss: 3493.0053, KL Div: 0.0487, Class Loss: 13.9789
# Epoch [41/50], Total Loss: 3509.4900, Rec Loss: 3495.4683, KL Div: 0.0429, Class Loss: 13.9789
# Epoch [42/50], Total Loss: 3506.4018, Rec Loss: 3492.7481, KL Div: 0.0401, Class Loss: 13.6136
# Epoch [43/50], Total Loss: 3508.1185, Rec Loss: 3494.2154, KL Div: 0.0405, Class Loss: 13.8627
# Epoch [44/50], Total Loss: 3507.4662, Rec Loss: 3492.8420, KL Div: 0.0462, Class Loss: 14.5780
# Epoch [45/50], Total Loss: 3507.3546, Rec Loss: 3493.0700, KL Div: 0.0425, Class Loss: 14.2421
# Epoch [46/50], Total Loss: 3505.5019, Rec Loss: 3491.6063, KL Div: 0.0398, Class Loss: 13.8558
# Epoch [47/50], Total Loss: 3507.6176, Rec Loss: 3493.9984, KL Div: 0.0380, Class Loss: 13.5812
# Epoch [48/50], Total Loss: 3506.7943, Rec Loss: 3493.2730, KL Div: 0.0357, Class Loss: 13.4856
# Epoch [49/50], Total Loss: 3506.9268, Rec Loss: 3493.5202, KL Div: 0.0373, Class Loss: 13.3694
# Epoch [50/50], Total Loss: 3506.5040, Rec Loss: 3492.7454, KL Div: 0.0369, Class Loss: 13.7217
# Time elapsed:  111.02079677581787
# Fold 2 Validation Loss: 0.0308, Validation Accuracy: 0.9924
# Fold 3/5
# Epoch [1/50], Total Loss: 3944.9968, Rec Loss: 3885.6899, KL Div: 13.8931, Class Loss: 45.4138
# Epoch [2/50], Total Loss: 3529.8817, Rec Loss: 3499.4219, KL Div: 0.1955, Class Loss: 30.2643
# Epoch [3/50], Total Loss: 3528.1958, Rec Loss: 3498.8042, KL Div: 0.1478, Class Loss: 29.2437
# Epoch [4/50], Total Loss: 3529.3148, Rec Loss: 3500.4347, KL Div: 0.1007, Class Loss: 28.7794
# Epoch [5/50], Total Loss: 3525.3560, Rec Loss: 3496.8441, KL Div: 0.0884, Class Loss: 28.4235
# Epoch [6/50], Total Loss: 3523.8166, Rec Loss: 3495.4408, KL Div: 0.0964, Class Loss: 28.2793
# Epoch [7/50], Total Loss: 3525.1505, Rec Loss: 3497.3559, KL Div: 0.0939, Class Loss: 27.7007
# Epoch [8/50], Total Loss: 3523.2836, Rec Loss: 3496.1452, KL Div: 0.1028, Class Loss: 27.0356
# Epoch [9/50], Total Loss: 3524.0949, Rec Loss: 3497.3872, KL Div: 0.1421, Class Loss: 26.5656
# Epoch [10/50], Total Loss: 3522.7726, Rec Loss: 3496.8281, KL Div: 0.1293, Class Loss: 25.8153
# Epoch [11/50], Total Loss: 3525.0515, Rec Loss: 3499.7553, KL Div: 0.1407, Class Loss: 25.1555
# Epoch [12/50], Total Loss: 3521.8298, Rec Loss: 3497.4395, KL Div: 0.1274, Class Loss: 24.2629
# Epoch [13/50], Total Loss: 3519.5827, Rec Loss: 3495.6272, KL Div: 0.1290, Class Loss: 23.8265
# Epoch [14/50], Total Loss: 3521.7015, Rec Loss: 3498.6240, KL Div: 0.1325, Class Loss: 22.9451
# Epoch [15/50], Total Loss: 3520.4241, Rec Loss: 3498.4813, KL Div: 0.1015, Class Loss: 21.8414
# Epoch [16/50], Total Loss: 3517.5696, Rec Loss: 3496.3625, KL Div: 0.1055, Class Loss: 21.1016
# Epoch [17/50], Total Loss: 3518.9277, Rec Loss: 3498.3262, KL Div: 0.1128, Class Loss: 20.4887
# Epoch [18/50], Total Loss: 3518.2054, Rec Loss: 3497.7931, KL Div: 0.1885, Class Loss: 20.2238
# Epoch [19/50], Total Loss: 3515.3170, Rec Loss: 3496.6892, KL Div: 0.0989, Class Loss: 18.5289
# Epoch [20/50], Total Loss: 3515.6324, Rec Loss: 3497.0634, KL Div: 0.1491, Class Loss: 18.4199
# Epoch [21/50], Total Loss: 3514.0210, Rec Loss: 3495.7062, KL Div: 0.1439, Class Loss: 18.1709
# Epoch [22/50], Total Loss: 3514.6352, Rec Loss: 3497.3731, KL Div: 0.0982, Class Loss: 17.1639
# Epoch [23/50], Total Loss: 3515.1641, Rec Loss: 3498.0787, KL Div: 0.0946, Class Loss: 16.9908
# Epoch [24/50], Total Loss: 3514.9185, Rec Loss: 3498.1900, KL Div: 0.1263, Class Loss: 16.6022
# Epoch [25/50], Total Loss: 3513.9804, Rec Loss: 3497.7265, KL Div: 0.1062, Class Loss: 16.1476
# Epoch [26/50], Total Loss: 3514.4690, Rec Loss: 3498.1836, KL Div: 0.1176, Class Loss: 16.1678
# Epoch [27/50], Total Loss: 3514.2345, Rec Loss: 3498.5644, KL Div: 0.0799, Class Loss: 15.5903
# Epoch [28/50], Total Loss: 3512.1477, Rec Loss: 3496.9799, KL Div: 0.0833, Class Loss: 15.0845
# Epoch [29/50], Total Loss: 3511.3399, Rec Loss: 3496.2330, KL Div: 0.0903, Class Loss: 15.0165
# Epoch [30/50], Total Loss: 3512.6050, Rec Loss: 3498.1828, KL Div: 0.0742, Class Loss: 14.3479
# Epoch [31/50], Total Loss: 3512.1935, Rec Loss: 3497.6227, KL Div: 0.0830, Class Loss: 14.4878
# Epoch [32/50], Total Loss: 3511.4536, Rec Loss: 3497.3906, KL Div: 0.0728, Class Loss: 13.9902
# Epoch [33/50], Total Loss: 3510.5882, Rec Loss: 3496.9083, KL Div: 0.0707, Class Loss: 13.6092
# Epoch [34/50], Total Loss: 3511.0307, Rec Loss: 3496.9194, KL Div: 0.0725, Class Loss: 14.0389
# Epoch [35/50], Total Loss: 3512.7991, Rec Loss: 3499.0502, KL Div: 0.0830, Class Loss: 13.6659
# Epoch [36/50], Total Loss: 3510.5715, Rec Loss: 3496.1527, KL Div: 0.0786, Class Loss: 14.3401
# Epoch [37/50], Total Loss: 3511.4708, Rec Loss: 3497.2634, KL Div: 0.0682, Class Loss: 14.1392
# Epoch [38/50], Total Loss: 3510.9831, Rec Loss: 3497.4574, KL Div: 0.0671, Class Loss: 13.4585
# Epoch [39/50], Total Loss: 3511.1639, Rec Loss: 3497.6845, KL Div: 0.0502, Class Loss: 13.4291
# Epoch [40/50], Total Loss: 3510.8671, Rec Loss: 3497.0107, KL Div: 0.0512, Class Loss: 13.8052
# Epoch [41/50], Total Loss: 3509.9247, Rec Loss: 3497.0590, KL Div: 0.0410, Class Loss: 12.8247
# Epoch [42/50], Total Loss: 3511.0709, Rec Loss: 3498.0095, KL Div: 0.0457, Class Loss: 13.0156
# Epoch [43/50], Total Loss: 3511.9505, Rec Loss: 3498.7278, KL Div: 0.0422, Class Loss: 13.1806
# Epoch [44/50], Total Loss: 3513.9938, Rec Loss: 3499.9817, KL Div: 0.0411, Class Loss: 13.9710
# Epoch [45/50], Total Loss: 3511.7299, Rec Loss: 3498.7506, KL Div: 0.0454, Class Loss: 12.9340
# Epoch [46/50], Total Loss: 3510.5299, Rec Loss: 3497.4511, KL Div: 0.0484, Class Loss: 13.0304
# Epoch [47/50], Total Loss: 3512.6739, Rec Loss: 3499.3853, KL Div: 0.0441, Class Loss: 13.2445
# Epoch [48/50], Total Loss: 3510.3491, Rec Loss: 3497.7159, KL Div: 0.0412, Class Loss: 12.5919
# Epoch [49/50], Total Loss: 3510.3244, Rec Loss: 3497.1305, KL Div: 0.0334, Class Loss: 13.1604
# Epoch [50/50], Total Loss: 3510.8167, Rec Loss: 3498.4717, KL Div: 0.0358, Class Loss: 12.3092
# Time elapsed:  112.05382585525513
# Fold 3 Validation Loss: 0.0367, Validation Accuracy: 0.9900
# Fold 4/5
# Epoch [1/50], Total Loss: 3962.8245, Rec Loss: 3902.3570, KL Div: 16.7379, Class Loss: 43.7297
# Epoch [2/50], Total Loss: 3544.5871, Rec Loss: 3514.0806, KL Div: 0.1455, Class Loss: 30.3611
# Epoch [3/50], Total Loss: 3541.5669, Rec Loss: 3512.0856, KL Div: 0.1437, Class Loss: 29.3376
# Epoch [4/50], Total Loss: 3542.6206, Rec Loss: 3513.9147, KL Div: 0.1165, Class Loss: 28.5894
# Epoch [5/50], Total Loss: 3540.1917, Rec Loss: 3511.8063, KL Div: 0.0939, Class Loss: 28.2916
# Epoch [6/50], Total Loss: 3540.6009, Rec Loss: 3512.3664, KL Div: 0.1025, Class Loss: 28.1319
# Epoch [7/50], Total Loss: 3538.7061, Rec Loss: 3511.2908, KL Div: 0.1072, Class Loss: 27.3081
# Epoch [8/50], Total Loss: 3540.4366, Rec Loss: 3513.4238, KL Div: 0.1273, Class Loss: 26.8855
# Epoch [9/50], Total Loss: 3537.6258, Rec Loss: 3511.8389, KL Div: 0.0992, Class Loss: 25.6877
# Epoch [10/50], Total Loss: 3536.1695, Rec Loss: 3511.1208, KL Div: 0.1037, Class Loss: 24.9449
# Epoch [11/50], Total Loss: 3537.1584, Rec Loss: 3512.4774, KL Div: 0.1107, Class Loss: 24.5703
# Epoch [12/50], Total Loss: 3535.6151, Rec Loss: 3512.3188, KL Div: 0.1080, Class Loss: 23.1883
# Epoch [13/50], Total Loss: 3533.8022, Rec Loss: 3511.2312, KL Div: 0.1021, Class Loss: 22.4689
# Epoch [14/50], Total Loss: 3532.6862, Rec Loss: 3511.1095, KL Div: 0.1345, Class Loss: 21.4421
# Epoch [15/50], Total Loss: 3531.5178, Rec Loss: 3510.6312, KL Div: 0.1392, Class Loss: 20.7474
# Epoch [16/50], Total Loss: 3531.7086, Rec Loss: 3511.5647, KL Div: 0.1392, Class Loss: 20.0046
# Epoch [17/50], Total Loss: 3530.9420, Rec Loss: 3511.0335, KL Div: 0.1462, Class Loss: 19.7623
# Epoch [18/50], Total Loss: 3530.5406, Rec Loss: 3511.5233, KL Div: 0.1269, Class Loss: 18.8904
# Epoch [19/50], Total Loss: 3531.8023, Rec Loss: 3513.5873, KL Div: 0.1114, Class Loss: 18.1036
# Epoch [20/50], Total Loss: 3527.1730, Rec Loss: 3509.3367, KL Div: 0.1201, Class Loss: 17.7162
# Epoch [21/50], Total Loss: 3529.5037, Rec Loss: 3512.3279, KL Div: 0.1268, Class Loss: 17.0490
# Epoch [22/50], Total Loss: 3528.1924, Rec Loss: 3511.5687, KL Div: 0.0753, Class Loss: 16.5484
# Epoch [23/50], Total Loss: 3528.2946, Rec Loss: 3512.3482, KL Div: 0.0779, Class Loss: 15.8685
# Epoch [24/50], Total Loss: 3528.2258, Rec Loss: 3512.4395, KL Div: 0.0830, Class Loss: 15.7032
# Epoch [25/50], Total Loss: 3526.4552, Rec Loss: 3510.9895, KL Div: 0.0756, Class Loss: 15.3901
# Epoch [26/50], Total Loss: 3526.1864, Rec Loss: 3511.1525, KL Div: 0.0577, Class Loss: 14.9762
# Epoch [27/50], Total Loss: 3527.9000, Rec Loss: 3512.7261, KL Div: 0.0866, Class Loss: 15.0873
# Epoch [28/50], Total Loss: 3526.0243, Rec Loss: 3511.8235, KL Div: 0.0653, Class Loss: 14.1355
# Epoch [29/50], Total Loss: 3525.2555, Rec Loss: 3510.7981, KL Div: 0.0730, Class Loss: 14.3844
# Epoch [30/50], Total Loss: 3528.0089, Rec Loss: 3513.3141, KL Div: 0.0766, Class Loss: 14.6181
# Epoch [31/50], Total Loss: 3527.1992, Rec Loss: 3512.6604, KL Div: 0.0781, Class Loss: 14.4607
# Epoch [32/50], Total Loss: 3524.8745, Rec Loss: 3510.8463, KL Div: 0.0668, Class Loss: 13.9614
# Epoch [33/50], Total Loss: 3526.4053, Rec Loss: 3512.7700, KL Div: 0.0653, Class Loss: 13.5700
# Epoch [34/50], Total Loss: 3525.3653, Rec Loss: 3512.3211, KL Div: 0.0538, Class Loss: 12.9904
# Epoch [35/50], Total Loss: 3524.3239, Rec Loss: 3510.9603, KL Div: 0.0574, Class Loss: 13.3061
# Epoch [36/50], Total Loss: 3524.6141, Rec Loss: 3511.1468, KL Div: 0.0550, Class Loss: 13.4123
# Epoch [37/50], Total Loss: 3525.3595, Rec Loss: 3511.6965, KL Div: 0.0553, Class Loss: 13.6078
# Epoch [38/50], Total Loss: 3523.0309, Rec Loss: 3510.2463, KL Div: 0.0491, Class Loss: 12.7355
# Epoch [39/50], Total Loss: 3523.4321, Rec Loss: 3510.6535, KL Div: 0.0469, Class Loss: 12.7316
# Epoch [40/50], Total Loss: 3524.6481, Rec Loss: 3511.3997, KL Div: 0.0452, Class Loss: 13.2032
# Epoch [41/50], Total Loss: 3525.2444, Rec Loss: 3512.2480, KL Div: 0.0481, Class Loss: 12.9483
# Epoch [42/50], Total Loss: 3524.8817, Rec Loss: 3511.7162, KL Div: 0.0442, Class Loss: 13.1213
# Epoch [43/50], Total Loss: 3525.6778, Rec Loss: 3513.1362, KL Div: 0.0376, Class Loss: 12.5040
# Epoch [44/50], Total Loss: 3524.5292, Rec Loss: 3511.4630, KL Div: 0.0403, Class Loss: 13.0259
# Epoch [45/50], Total Loss: 3523.6030, Rec Loss: 3511.0503, KL Div: 0.0396, Class Loss: 12.5131
# Epoch [46/50], Total Loss: 3524.1968, Rec Loss: 3511.6121, KL Div: 0.0323, Class Loss: 12.5524
# Epoch [47/50], Total Loss: 3522.6227, Rec Loss: 3510.0685, KL Div: 0.0361, Class Loss: 12.5181
# Epoch [48/50], Total Loss: 3525.7318, Rec Loss: 3513.4731, KL Div: 0.0371, Class Loss: 12.2216
# Epoch [49/50], Total Loss: 3524.5524, Rec Loss: 3512.1379, KL Div: 0.0337, Class Loss: 12.3808
# Epoch [50/50], Total Loss: 3524.4690, Rec Loss: 3511.8156, KL Div: 0.0314, Class Loss: 12.6221
# Time elapsed:  129.29459691047668
# Fold 4 Validation Loss: 0.0367, Validation Accuracy: 0.9894
# Fold 5/5
# Epoch [1/50], Total Loss: 3929.4285, Rec Loss: 3864.2490, KL Div: 14.8960, Class Loss: 50.2835
# Epoch [2/50], Total Loss: 3538.5436, Rec Loss: 3507.5572, KL Div: 0.1158, Class Loss: 30.8707
# Epoch [3/50], Total Loss: 3537.6324, Rec Loss: 3507.6612, KL Div: 0.1164, Class Loss: 29.8548
# Epoch [4/50], Total Loss: 3535.8777, Rec Loss: 3506.5834, KL Div: 0.0929, Class Loss: 29.2014
# Epoch [5/50], Total Loss: 3536.1185, Rec Loss: 3507.0829, KL Div: 0.0755, Class Loss: 28.9602
# Epoch [6/50], Total Loss: 3536.5497, Rec Loss: 3507.9556, KL Div: 0.0624, Class Loss: 28.5316
# Epoch [7/50], Total Loss: 3536.4974, Rec Loss: 3508.0818, KL Div: 0.0720, Class Loss: 28.3436
# Epoch [8/50], Total Loss: 3533.8605, Rec Loss: 3505.5490, KL Div: 0.0692, Class Loss: 28.2423
# Epoch [9/50], Total Loss: 3532.9374, Rec Loss: 3505.4156, KL Div: 0.0660, Class Loss: 27.4559
# Epoch [10/50], Total Loss: 3533.4795, Rec Loss: 3506.2300, KL Div: 0.0895, Class Loss: 27.1599
# Epoch [11/50], Total Loss: 3532.0235, Rec Loss: 3505.0331, KL Div: 0.1068, Class Loss: 26.8836
# Epoch [12/50], Total Loss: 3531.3258, Rec Loss: 3505.4713, KL Div: 0.1131, Class Loss: 25.7415
# Epoch [13/50], Total Loss: 3531.6842, Rec Loss: 3506.4985, KL Div: 0.1065, Class Loss: 25.0793
# Epoch [14/50], Total Loss: 3533.7417, Rec Loss: 3509.2326, KL Div: 0.1008, Class Loss: 24.4083
# Epoch [15/50], Total Loss: 3530.5159, Rec Loss: 3506.9656, KL Div: 0.1219, Class Loss: 23.4285
# Epoch [16/50], Total Loss: 3529.9734, Rec Loss: 3507.0736, KL Div: 0.1503, Class Loss: 22.7495
# Epoch [17/50], Total Loss: 3528.3220, Rec Loss: 3506.3073, KL Div: 0.1407, Class Loss: 21.8739
# Epoch [18/50], Total Loss: 3527.0134, Rec Loss: 3505.5971, KL Div: 0.1618, Class Loss: 21.2544
# Epoch [19/50], Total Loss: 3528.7107, Rec Loss: 3508.1001, KL Div: 0.1460, Class Loss: 20.4646
# Epoch [20/50], Total Loss: 3527.1524, Rec Loss: 3507.8936, KL Div: 0.1102, Class Loss: 19.1486
# Epoch [21/50], Total Loss: 3528.0173, Rec Loss: 3508.6729, KL Div: 0.1243, Class Loss: 19.2201
# Epoch [22/50], Total Loss: 3526.8712, Rec Loss: 3508.4091, KL Div: 0.1243, Class Loss: 18.3377
# Epoch [23/50], Total Loss: 3524.1272, Rec Loss: 3506.5116, KL Div: 0.1007, Class Loss: 17.5149
# Epoch [24/50], Total Loss: 3524.0608, Rec Loss: 3506.7761, KL Div: 0.1025, Class Loss: 17.1822
# Epoch [25/50], Total Loss: 3521.9489, Rec Loss: 3505.3048, KL Div: 0.0826, Class Loss: 16.5616
# Epoch [26/50], Total Loss: 3522.3600, Rec Loss: 3506.0705, KL Div: 0.0856, Class Loss: 16.2038
# Epoch [27/50], Total Loss: 3522.5400, Rec Loss: 3506.5978, KL Div: 0.0769, Class Loss: 15.8654
# Epoch [28/50], Total Loss: 3524.3361, Rec Loss: 3508.4750, KL Div: 0.0596, Class Loss: 15.8015
# Epoch [29/50], Total Loss: 3521.7090, Rec Loss: 3506.2384, KL Div: 0.0581, Class Loss: 15.4125
# Epoch [30/50], Total Loss: 3522.9234, Rec Loss: 3507.0885, KL Div: 0.0685, Class Loss: 15.7665
# Epoch [31/50], Total Loss: 3519.2984, Rec Loss: 3504.9431, KL Div: 0.0560, Class Loss: 14.2994
# Epoch [32/50], Total Loss: 3521.0233, Rec Loss: 3506.6418, KL Div: 0.0582, Class Loss: 14.3232
# Epoch [33/50], Total Loss: 3518.8537, Rec Loss: 3504.6486, KL Div: 0.0595, Class Loss: 14.1456
# Epoch [34/50], Total Loss: 3521.5617, Rec Loss: 3507.6587, KL Div: 0.0577, Class Loss: 13.8453
# Epoch [35/50], Total Loss: 3519.4338, Rec Loss: 3506.0148, KL Div: 0.0478, Class Loss: 13.3713
# Epoch [36/50], Total Loss: 3520.7354, Rec Loss: 3506.9184, KL Div: 0.0557, Class Loss: 13.7613
# Epoch [37/50], Total Loss: 3519.9348, Rec Loss: 3506.7595, KL Div: 0.0526, Class Loss: 13.1226
# Epoch [38/50], Total Loss: 3519.0793, Rec Loss: 3505.4070, KL Div: 0.0541, Class Loss: 13.6183
# Epoch [39/50], Total Loss: 3519.9102, Rec Loss: 3506.8470, KL Div: 0.0428, Class Loss: 13.0203
# Epoch [40/50], Total Loss: 3523.7173, Rec Loss: 3506.6275, KL Div: 0.0789, Class Loss: 17.0110
# Epoch [41/50], Total Loss: 3518.9868, Rec Loss: 3506.1134, KL Div: 0.0433, Class Loss: 12.8302
# Epoch [42/50], Total Loss: 3518.6155, Rec Loss: 3505.4782, KL Div: 0.0370, Class Loss: 13.1003
# Epoch [43/50], Total Loss: 3520.1839, Rec Loss: 3507.2356, KL Div: 0.0384, Class Loss: 12.9098
# Epoch [44/50], Total Loss: 3518.8876, Rec Loss: 3505.8314, KL Div: 0.0436, Class Loss: 13.0126
# Epoch [45/50], Total Loss: 3518.4347, Rec Loss: 3505.5888, KL Div: 0.0397, Class Loss: 12.8062
# Epoch [46/50], Total Loss: 3519.7173, Rec Loss: 3507.1802, KL Div: 0.0350, Class Loss: 12.5022
# Epoch [47/50], Total Loss: 3520.5173, Rec Loss: 3508.2423, KL Div: 0.0332, Class Loss: 12.2418
# Epoch [48/50], Total Loss: 3519.9657, Rec Loss: 3507.5585, KL Div: 0.0316, Class Loss: 12.3756
# Epoch [49/50], Total Loss: 3520.2480, Rec Loss: 3507.4622, KL Div: 0.0309, Class Loss: 12.7549
# Epoch [50/50], Total Loss: 3517.9440, Rec Loss: 3505.8554, KL Div: 0.0310, Class Loss: 12.0576
# Time elapsed:  119.4814305305481
# Fold 5 Validation Loss: 0.0421, Validation Accuracy: 0.9901
# Total time taken for k-fold cross-validation: 582.8603479862213 seconds

# %%
def plot_training_loss(model_name, save_dir):
    training_traj = np.load(save_dir+model_name+"_training_loss.npz")

    total_loss = training_traj['training_total_loss']
    rec_loss = training_traj['training_rec_loss']
    kl_loss = training_traj['training_kl_loss']
    class_loss = training_traj['training_class_loss']
    plt.figure(figsize=(16, 16))
    plt.suptitle(model_name, fontsize=16)
    plt.subplot(2, 2, 1)
    plt.title("Total Loss", fontsize=12)
    plt.plot(range(len(total_loss)), total_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(2, 2, 2)
    plt.title("Reconstruction Loss", fontsize=12)
    plt.plot(range(len(total_loss)), rec_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(2, 2, 3)
    plt.title("KL Loss", fontsize=12)
    plt.plot(range(len(total_loss)), kl_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.subplot(2, 2, 4)
    plt.title("Classification Loss", fontsize=12)
    plt.plot(range(len(total_loss)), class_loss)
    plt.tick_params(axis='both', which='major', labelsize=14)
    
for fold in range(k_folds):
    plot_training_loss("CondVAE_model"+str(fold+1), save_dir)

# %%
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Normal", "Anomalous"]).plot(cmap=plt.cm.Blues)

# %% [markdown]
# # Initialize 3 new models for fine-tuning

# %%
buffer.seek(0) 
model_medium = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_medium.load_state_dict(torch.load(buffer))
model_medium = model_medium.to(device)

buffer.seek(0)
model_strong = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_strong.load_state_dict(torch.load(buffer))
model_strong = model_strong.to(device)
buffer.seek(0)
model_random = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
model_random.load_state_dict(torch.load(buffer))
model_random = model_random.to(device)

# %% [markdown]
# # Verify the 3 new models

# %%
# Initialize a flag
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Initialize a flag
models_identical = True
original_state_dict = model_random.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Initialize a flag
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_strong.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Out:
# The saved and loaded models are identical.
# The saved and loaded models are identical.
# The saved and loaded models are identical.

# %% [markdown]
# # Evaluate the Model and Detect Anomalies

# %%
def compute_anomaly_scores(model, data_loader):
    model.eval()
    rec_errors = []
    anomaly_probs = []
    true_labels = []
    predictions = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.unsqueeze(1).to(device)
            y_batch = y_batch.to(device)

            x_rec, class_logits = model(X_batch)
            y_probs = F.softmax(class_logits, dim=1)

            # Reconstruction error
            rec_error = torch.mean((X_batch - x_rec) ** 2, dim=[1, 2])

            # Classification probability for anomaly class
            anomaly_prob = y_probs[:, 1]

            # Combine scores
            #anomaly_score = rec_error * anomaly_prob
            rec_errors.extend(rec_error.cpu().numpy())
            anomaly_probs.extend(anomaly_prob.cpu().numpy())
            true_labels.extend(y_batch.cpu().numpy())
            predictions.extend(torch.argmax(class_logits, dim=1).cpu().numpy())

    return np.array(rec_errors), np.array(anomaly_probs), np.array(true_labels), np.array(predictions)

# Compute anomaly scores
train_rec_errors, train_anomaly_probs, train_true_labels, train_predictions = compute_anomaly_scores(model, train_loader)
val_rec_errors, val_anomaly_probs, val_true_labels, val_predictions = compute_anomaly_scores(model, val_loader)
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model, test_loader)

plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 85.85%, recall = 54.85% and F1-score = 66.94%

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_anomaly_probs)), val_anomaly_probs, alpha=0.7, c=(val_true_labels!=val_predictions), cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(val_rec_errors, val_anomaly_probs, alpha=0.7, c=(val_true_labels==val_predictions), cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores with Reconstruction Errors")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(val_anomaly_probs, vert=False)
plt.title("Box Plot of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.show()

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(val_anomaly_probs, bins=20, alpha=0.7, edgecolor='black')
plt.title("Histogram of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_true_labels, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (true labels)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_predictions, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (predictions)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()
# Scatter Plot
plt.figure(figsize=(8, 6))
plt.scatter(range(len(val_rec_errors)), val_rec_errors, alpha=0.7, c=val_anomaly_probs, cmap='coolwarm')
plt.title("Scatter Plot of Validation Anomaly Scores (anomalous probability)")
plt.xlabel("Index")
plt.ylabel("Anomaly Score")
plt.show()

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(val_rec_errors, vert=False)
plt.title("Box Plot of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.show()

# Histogram
plt.figure(figsize=(8, 6))
plt.hist(val_rec_errors, bins=20, alpha=0.7, edgecolor='black')
plt.title("Histogram of Validation Anomaly Scores")
plt.xlabel("Anomaly Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Retrain

# %%
# Determine thresholds
#lower_percentile = 62.5
#upper_percentile = 37.5
#lower_threshold = np.percentile(val_anomaly_probs, lower_percentile)
#upper_threshold = np.percentile(val_anomaly_probs, upper_percentile)


# Select medium-score data
medium_score_indices = np.where((val_anomaly_probs >= 0.05) & (val_anomaly_probs <= 0.95))[0]
X_medium = X_val[medium_score_indices]
y_medium = y_val[medium_score_indices]
print("Medium-score data shape:", X_medium.shape, y_medium.shape)
X_medium_tensor = torch.tensor(X_medium).float()
y_medium_tensor = torch.tensor(y_medium).long()
# data loader
medium_dataset = TimeSeriesDataset(X_medium_tensor, y_medium_tensor)
medium_loader = DataLoader(medium_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Medium-score data shape: (1557, 8) (1557,)

# %%
# Determine thresholds
#lower_percentile = 12.5
#upper_percentile = 87.5
#lower_threshold = np.percentile(val_anomaly_probs, lower_percentile)
#upper_threshold = np.percentile(val_anomaly_probs, upper_percentile)

# Select strong-score data
strong_score_indices = np.where((val_anomaly_probs <= 0.01) | (val_anomaly_probs >= 0.99))[0]
X_strong = X_val[strong_score_indices]
y_strong = y_val[strong_score_indices]
print("Strong-score data shape:", X_strong.shape, y_strong.shape)
X_strong_tensor = torch.tensor(X_strong).float()
y_strong_tensor = torch.tensor(y_strong).long()
# data loader
strong_dataset = TimeSeriesDataset(X_strong_tensor, y_strong_tensor)
strong_loader = DataLoader(strong_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Strong-score data shape: (20080, 8) (20080,)

# %%
# Optional: Set a random seed for reproducibility
np.random.seed(42)

# Define the fraction of data to select
sample_fraction = 0.25
total_samples = len(val_anomaly_probs)
sample_size = int(sample_fraction * total_samples)

# Randomly select unique indices without replacement
random_score_indices = np.random.choice(total_samples, size=sample_size, replace=False)

# Select the corresponding data and labels
X_random = X_val[random_score_indices]
y_random = y_val[random_score_indices]
print("Random data shape:", X_random.shape, y_random.shape)
# Convert to PyTorch tensors
X_random_tensor = torch.tensor(X_random).float()
y_random_tensor = torch.tensor(y_random).long()

# Create the dataset and data loader
random_dataset = TimeSeriesDataset(X_random_tensor, y_random_tensor)
random_loader = DataLoader(random_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Random data shape: (7104, 8) (7104,)

# %%
# Finetune the model
model_name = "model_medium"
optimizer = optim.Adam(model_medium.parameters(), lr=finetune_learning_rate)
#optimizer = optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-7)
model_medium = train_model(model_medium, optimizer, medium_loader, num_epochs=finetune_num_epochs, model_name=
                           model_name, save_dir=save_dir, save=True)
plot_training_loss(model_name, save_dir)
models_identical = True
original_state_dict = model.state_dict()
loaded_state_dict = model_medium.state_dict()
# Compare each parameter
for key in original_state_dict:
    original_param = original_state_dict[key]
    loaded_param = loaded_state_dict[key]
    if not torch.equal(original_param, loaded_param):
        print(f"Mismatch found at layer: {key}")
        models_identical = False
        break

if models_identical:
    print("The saved and loaded models are identical.")
else:
    print("The models are not identical.")
# Out:
# Epoch [1/5], Total Loss: 275.7872, Rec Loss: 269.9523, KL Div: 0.0079, Class Loss: 5.8271
# Epoch [2/5], Total Loss: 275.4302, Rec Loss: 269.9155, KL Div: 0.0072, Class Loss: 5.5076
# Epoch [3/5], Total Loss: 275.4189, Rec Loss: 269.9043, KL Div: 0.0068, Class Loss: 5.5078
# Epoch [4/5], Total Loss: 275.3977, Rec Loss: 269.8945, KL Div: 0.0064, Class Loss: 5.4968
# Epoch [5/5], Total Loss: 275.3886, Rec Loss: 269.8916, KL Div: 0.0061, Class Loss: 5.4909
# Time elapsed:  0.8417675495147705
# Mismatch found at layer: encoder.fc_layers.0.weight
# The models are not identical.

# %%
optimizer = optim.Adam(model_strong.parameters(), lr=finetune_learning_rate)
model_name = "model_strong"
model_strong = train_model(model_strong, optimizer, strong_loader, num_epochs=finetune_num_epochs, model_name=model_name, save_dir=save_dir, save=True)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/5], Total Loss: 2911.0980, Rec Loss: 2904.5244, KL Div: 0.0127, Class Loss: 6.5609
# Epoch [2/5], Total Loss: 2910.9345, Rec Loss: 2904.4443, KL Div: 0.0111, Class Loss: 6.4791
# Epoch [3/5], Total Loss: 2910.9082, Rec Loss: 2904.4529, KL Div: 0.0102, Class Loss: 6.4451
# Epoch [4/5], Total Loss: 2910.8639, Rec Loss: 2904.4376, KL Div: 0.0095, Class Loss: 6.4167
# Epoch [5/5], Total Loss: 2910.8328, Rec Loss: 2904.4282, KL Div: 0.0096, Class Loss: 6.3949
# Time elapsed:  9.285954475402832

# %%
model_name = "model_random"
optimizer = optim.Adam(model_random.parameters(), lr=finetune_learning_rate)
model_random = train_model(model_random, optimizer, random_loader, num_epochs=finetune_num_epochs, model_name=model_name, save_dir=save_dir, save=True)
plot_training_loss(model_name, save_dir)
# Out:
# Epoch [1/5], Total Loss: 1086.3836, Rec Loss: 1082.7087, KL Div: 0.0067, Class Loss: 3.6682
# Epoch [2/5], Total Loss: 1086.2943, Rec Loss: 1082.6889, KL Div: 0.0059, Class Loss: 3.5995
# Epoch [3/5], Total Loss: 1086.2808, Rec Loss: 1082.6912, KL Div: 0.0059, Class Loss: 3.5836
# Epoch [4/5], Total Loss: 1086.2717, Rec Loss: 1082.6947, KL Div: 0.0059, Class Loss: 3.5710
# Epoch [5/5], Total Loss: 1086.2660, Rec Loss: 1082.6981, KL Div: 0.0058, Class Loss: 3.5621
# Time elapsed:  3.2422547340393066

# %%
## Combine data
#expanded_medium_data = np.concatenate((X_train, X_medium), axis=0)
#expanded_medium_labels = np.concatenate((y_train, y_medium), axis=0)
#X_expanded_medium_tensor = torch.tensor(expanded_medium_data).float()
#y_expanded_medium_tensor = torch.tensor(expanded_medium_labels).long()
## Create new dataset and loader
#expanded_medium_dataset = TimeSeriesDataset(X_expanded_medium_tensor, y_expanded_medium_tensor)
#expanded_medium_loader = DataLoader(expanded_medium_dataset, batch_size=batch_size, shuffle=False)
#model2_medium = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
#
## Define optimizer
#model_name = "model2_medium"
#optimizer = optim.Adam(model2_medium.parameters(), lr=train_learning_rate)
#model2_medium = train_model(model2_medium, optimizer, expanded_medium_loader, num_epochs=train_num_epochs, model_name=model_name, save_dir=save_dir, save=True)
#plot_training_loss(model_name, save_dir)

# %%
#expanded_strong_data = np.concatenate((X_train, X_strong), axis=0)
#expanded_strong_labels = np.concatenate((y_train, y_strong), axis=0)
#X_expanded_strong_tensor = torch.tensor(expanded_strong_data).float()
#y_expanded_strong_tensor = torch.tensor(expanded_strong_labels).long()
## Create new dataset and loader
#expanded_strong_dataset = TimeSeriesDataset(X_expanded_strong_tensor, y_expanded_strong_tensor)
#expanded_strong_loader = DataLoader(expanded_strong_dataset, batch_size=batch_size, shuffle=False)
#model2_strong = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
#
## Define optimizer
#model_name = "model2_strong"
#optimizer = optim.Adam(model2_strong.parameters(), lr=train_learning_rate)
#model2_strong = train_model(model2_strong, optimizer, expanded_strong_loader, num_epochs=train_num_epochs, model_name="model2_strong", save_dir=save_dir, save=True)
#plot_training_loss(model_name, save_dir)

# %%
#expanded_random_data = np.concatenate((X_train, X_random), axis=0)
#expanded_random_labels = np.concatenate((y_train, y_random), axis=0)
#X_expanded_random_tensor = torch.tensor(expanded_random_data).float()
#y_expanded_random_tensor = torch.tensor(expanded_random_labels).long()
## Create new dataset and loader
#expanded_random_dataset = TimeSeriesDataset(X_expanded_random_tensor, y_expanded_random_tensor)
#expanded_random_loader = DataLoader(expanded_random_dataset, batch_size=batch_size, shuffle=False)
#model2_random = VAE(latent_dim, num_param, window_size, num_classes, scale_flag).to(device)
#
## Define optimizer
#model_name = "model2_random"
#optimizer = optim.Adam(model2_random.parameters(), lr=train_learning_rate)
#model2_random = train_model(model2_random, optimizer, expanded_random_loader, num_epochs=train_num_epochs, model_name="model2_random", save_dir=save_dir, save=True)
#plot_training_loss(model_name, save_dir)

# %%
# Assuming you have already defined and initialized your models:
# model, model_medium, model_random, model_strong

# Dictionary of models with their names for easy reference
models = {
    'model': model,
    'model_medium': model_medium,
    'model_random': model_random,
    'model_strong': model_strong
    #'model2_medium': model2_medium,
    #'model2_random': model2_random,
    #'model2_strong': model2_strong
}

# Generate all possible unique pairs of models
model_pairs = list(combinations(models.items(), 2))

# Lists to keep track of identical and different model pairs
identical_pairs = []
different_pairs = []

# Function to compare two models
def compare_models(model1, model2, name1, name2):
    state_dict1 = model1.state_dict()
    state_dict2 = model2.state_dict()
    
    # First, check if both models have the same set of keys (layers)
    keys1 = set(state_dict1.keys())
    keys2 = set(state_dict2.keys())
    
    if keys1 != keys2:
        missing_in_1 = keys2 - keys1
        missing_in_2 = keys1 - keys2
        if missing_in_1:
            
            print(f"Model '{name1}' is missing layers: {missing_in_1}")
        if missing_in_2:
            
            print(f"Model '{name2}' is missing layers: {missing_in_2}")
        return False  # Layers mismatch implies models are different
    
    # Compare each parameter tensor
    for key in state_dict1:
        param1 = state_dict1[key]
        param2 = state_dict2[key]
        
        if not torch.equal(param1, param2):
            #print(f"Mismatch found in layer '{key}' between '{name1}' and '{name2}'.")
            return False  # Found a mismatch
    
    return True  # All parameters match

# Iterate through each pair and compare
for (name1, model1), (name2, model2_medium) in model_pairs:
    print(f"Comparing '{name1}' with '{name2}':")
    are_identical = compare_models(model1, model2_medium, name1, name2)
    
    if are_identical:
        identical_pairs.append((name1, name2))
        print(f"--> '{name1}' and '{name2}' are IDENTICAL.\n")
    else:
        different_pairs.append((name1, name2))
        print(f"--> '{name1}' and '{name2}' are DIFFERENT.\n")

# Summary of results
print("=== Comparison Summary ===\n")

if identical_pairs:
    print("Identical Model Pairs:")
    for name1, name2 in identical_pairs:
        print(f" - {name1} and {name2}")
else:
    print("No identical model pairs found.")

print()

if different_pairs:
    print("Different Model Pairs:")
    for name1, name2 in different_pairs:
        print(f" - {name1} and {name2}")
else:
    print("No different model pairs found.")
# Out:
# Comparing 'model' with 'model_medium':
# --> 'model' and 'model_medium' are DIFFERENT.
#
# Comparing 'model' with 'model_random':
# --> 'model' and 'model_random' are DIFFERENT.
#
# Comparing 'model' with 'model_strong':
# --> 'model' and 'model_strong' are DIFFERENT.
#
# Comparing 'model_medium' with 'model_random':
# --> 'model_medium' and 'model_random' are DIFFERENT.
#
# Comparing 'model_medium' with 'model_strong':
# --> 'model_medium' and 'model_strong' are DIFFERENT.
#
# Comparing 'model_random' with 'model_strong':
# --> 'model_random' and 'model_strong' are DIFFERENT.
#
# === Comparison Summary ===
#
# No identical model pairs found.
#
# Different Model Pairs:
#  - model and model_medium
#  - model and model_random
#  - model and model_strong
#  - model_medium and model_random
#  - model_medium and model_strong
#  - model_random and model_strong

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_medium, test_loader)

plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 81.29%, recall = 61.99% and F1-score = 70.34%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_strong, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 86.15%, recall = 53.53% and F1-score = 66.03%

# %%
test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model_random, test_loader)
plot_confusion_matrix(test_true_labels, test_predictions)
info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
                                                                np.round(info[1][1]*100, 2),
                                                                np.round(info[2][1]*100, 2)))
# Out:
# Precision = 84.59%, recall = 57.72% and F1-score = 68.62%

# %%
#test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_medium, test_loader)
#plot_confusion_matrix(test_true_labels, test_predictions)
#info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
#print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
#                                                                np.round(info[1][1]*100, 2),
#                                                                np.round(info[2][1]*100, 2)))

# %%
#test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_strong, test_loader)
#plot_confusion_matrix(test_true_labels, test_predictions)
#info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
#print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
#                                                                np.round(info[1][1]*100, 2),
#                                                                np.round(info[2][1]*100, 2)))

# %%
#test_rec_errors, test_anomaly_probs, test_true_labels, test_predictions = compute_anomaly_scores(model2_random, test_loader)
#plot_confusion_matrix(test_true_labels, test_predictions)
#info = precision_recall_fscore_support(test_true_labels, test_predictions, pos_label=1)
#print("Precision = {}%, recall = {}% and F1-score = {}%".format(np.round(info[0][1]*100, 2),
#                                                                np.round(info[1][1]*100, 2),
#                                                                np.round(info[2][1]*100, 2)))
